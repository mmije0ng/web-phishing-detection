# %%
import pandas as pd
import concurrent.futures

# %%
# 데이터셋 불러오기
df = pd.read_csv('dataset_B_05_2020.csv')

# 첫 번째 컬럼과 마지막 컬럼의 이름 찾기 (url, status)
first_column = df.columns[0]
last_column = df.columns[-1]

# url 컬럼과 status 컬럼만 추가
df = df[[first_column, last_column]]

# 결과 확인
print(df.head())
# Out:
#                                                  url      status
# 0              http://www.crestonwood.com/router.php  legitimate
# 1  http://shadetreetechnology.com/V4/validation/a...    phishing
# 2  https://support-appleld.com.secureupdate.duila...    phishing
# 3                                 http://rgipt.ac.in  legitimate
# 4  http://www.iracing.com/tracks/gateway-motorspo...  legitimate

# %%
# 정상 url 데이터 250개 추출
legitimate_df = df[df['status'] == 'legitimate'].head(250)

# %%
# 피싱 url 데이터 250개 추출
phishing_df = df[df['status'] == 'phishing'].head(250)

# %%
# 두 개의 데이터프레임을 하나로 결합
df = pd.concat([legitimate_df, phishing_df])

# 데이터프레임을 랜덤으로 섞기
df = df.sample(frac=1).reset_index(drop=True)

# %%
# 500개 데이터셋 결과 출력
print(df)
# Out:
#                                                    url      status
# 0    http://www.wealthdaily.com/articles/nokia-stoc...  legitimate
# 1    https://www.slideshare.net/gibsondaniel83/mark...  legitimate
# 2    http://www.game.co.uk/en/games/nintendo-switch...  legitimate
# 3            http://www.routeralley.com/guides/nat.pdf  legitimate
# 4    http://www.phoenixlocksmith-az.com/prole/?p[]=...    phishing
# ..                                                 ...         ...
# 495  http://signin.eday.co.uk.ws.edayisapi.dllsign....    phishing
# 496                        http://www.calculate.co.il/  legitimate
# 497                         http://www.codeboiler.net/  legitimate
# 498  http://www.orafaq.com/wiki/Roles_and_Responsib...  legitimate
# 499      https://www.hfunderground.com/wiki/Ionosphere  legitimate
#
# [500 rows x 2 columns]

# %%
# 라이브러리 임포트
import requests
import regex # pip install regex
import ipaddress # pip install ipaddress
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import content_based_features as cbf # 컨텐트 기반 피처 알고리즘 코드

# %%
# # 병렬 처리를 위해 ThreadPoolExecutor 설정
# def apply_function_in_parallel(df, func_name, col_name):
#     def wrapper(url):
#         result = func_name(url)
#         print(f"{url} - {col_name} 피처 완료")
#         return result

#     with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
#         results = list(executor.map(wrapper, df['url']))

#     df[col_name] = results
#     df.reset_index(drop=True, inplace=True)
#     if col_name in df.columns:
#         print(f"피처 '{col_name}' 추가 완료:")
#         print(df[[col_name]].head())
#     else:
#         print(f"피처 '{col_name}'이 데이터프레임에 존재하지 않습니다.")

# url 데이터에 대해 피처별 결과 생성 
def apply(df, func_name, col_name):
    results = []
    for url in df['url']:
        result = func_name(url)
        results.append(result)
        print(f"{url} - {col_name} 피처 완료")

    df[col_name] = results
    df.reset_index(drop=True, inplace=True)
    if col_name in df.columns:
        print(f"피처 '{col_name}' 추가 완료:")
        print(df[[col_name]].head())
    else:
        print(f"피처 '{col_name}'이 데이터프레임에 존재하지 않습니다.")

# %%
apply(df, cbf.use_right_click, 'RightClick')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - RightClick 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - RightClick 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856710>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854f40>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - RightClick 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c855480>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8572e0>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - RightClick 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c857160>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - RightClick 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - RightClick 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - RightClick 피처 완료
# http://www.dictionary.com/browse/tabloid - RightClick 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - RightClick 피처 완료
# http://www.thefreedictionary.com/compact+disc - RightClick 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8565f0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - RightClick 피처 완료
# http://vki.vipcentr.ru - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856890>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - RightClick 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - RightClick 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - RightClick 피처 완료
# http://www.chinadryer.cn/pa - RightClick 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - RightClick 피처 완료
# https://www.soul-flower.com/ - RightClick 피처 완료
# http://remontka.pro/mac-address/ - RightClick 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - RightClick 피처 완료
# https://www.haciserif.com.tr/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857070>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c854ee0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - RightClick 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854f70>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8569b0>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - RightClick 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - RightClick 피처 완료
# https://twitter.com/mimosagrillclt - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c854580>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - RightClick 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - RightClick 피처 완료
# http://www.2345daohang.com/ - RightClick 피처 완료
# http://bakeri-net.blogfa.com - RightClick 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857880>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857190>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - RightClick 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - RightClick 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - RightClick 피처 완료
# http://owl.li/9KyR30pXOCN - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8541c0>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - RightClick 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - RightClick 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c855000>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - RightClick 피처 완료
# https://www.luxuryloft.eu/ - RightClick 피처 완료
# https://www.sportsengine.com/solutions/ - RightClick 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8566e0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - RightClick 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - RightClick 피처 완료
# https://www.iplocation.net/mac-address - RightClick 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - RightClick 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - RightClick 피처 완료
# http://www.grafikerler.org/ - RightClick 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - RightClick 피처 완료
# https://www.metal-supply.dk/ - RightClick 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - RightClick 피처 완료
# https://www.facebook.com/thekeyboardcat - RightClick 피처 완료
# https://www.weightworld.se/ - RightClick 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - RightClick 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - RightClick 피처 완료
# http://securkenya.com/wp-content/dh1 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857b80>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - RightClick 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - RightClick 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c855d80>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - RightClick 피처 완료
# http://sophie-world.com/games/port-and-starboard - RightClick 피처 완료
# https://learn.sparkfun.com/tutorials/16 - RightClick 피처 완료
# http://signin-store-ws.frontieroption.com/ - RightClick 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - RightClick 피처 완료
# https://noreply-netelle.blogspot.com/ - RightClick 피처 완료
# https://www.off-the-road.de/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c838d00>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - RightClick 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - RightClick 피처 완료
# http://setaccess.webflow.io/ - RightClick 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - RightClick 피처 완료
# https://estacaoxxx.wordpress.com/ - RightClick 피처 완료
# http://www.arcanelegendsgame.com/ - RightClick 피처 완료
# https://www.ingame.de/ - RightClick 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - RightClick 피처 완료
# https://zmail221.appspot.com - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8557b0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8578b0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - RightClick 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - RightClick 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - RightClick 피처 완료
# https://www.alteredgamer.com/ - RightClick 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - RightClick 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - RightClick 피처 완료
# http://www.imdb.com/Title?3682448 - RightClick 피처 완료
# https://www.workiva.com/ - RightClick 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - RightClick 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - RightClick 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - RightClick 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854d90>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - RightClick 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - RightClick 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856740>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - RightClick 피처 완료
# https://www.unmannedtechshop.co.uk/ - RightClick 피처 완료
# https://www.annabelle.com.cy - RightClick 피처 완료
# https://www.provenancevineyards.com/ - RightClick 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - RightClick 피처 완료
# http://www.answers.com/Q/Digital_media_salary - RightClick 피처 완료
# http://betasusgirsenesende.blogspot.com - RightClick 피처 완료
# https://www.provenancevineyards.com/our-wines - RightClick 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - RightClick 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c83b550>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - RightClick 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - RightClick 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - RightClick 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - RightClick 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - RightClick 피처 완료
# https://mailserver67187.uc.r.appspot.com - RightClick 피처 완료
# http://www.astroresidential.co.uk/application/data/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - RightClick 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - RightClick 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - RightClick 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - RightClick 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8569e0>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - RightClick 피처 완료
# http://www.neutralsources.com/-/re.html - RightClick 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - RightClick 피처 완료
# http://judithleoni.com/telecom-de/index.php - RightClick 피처 완료
# http://www.definitions.net/definition/compact%20disc - RightClick 피처 완료
# http://press-preview.weebly.com - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c854640>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - RightClick 피처 완료
# https://www.facebook.com/imdbpro/ - RightClick 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856e30>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - RightClick 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - RightClick 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - RightClick 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - RightClick 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - RightClick 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c856da0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - RightClick 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - RightClick 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - RightClick 피처 완료
# https://www.markspcsolution.com/ - RightClick 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - RightClick 피처 완료
# http://www.price2india.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8555a0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c857910>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - RightClick 피처 완료
# https://scenari.software/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - RightClick 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c857880>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - RightClick 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - RightClick 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - RightClick 피처 완료
# https://www.drawdown.org/ - RightClick 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - RightClick 피처 완료
# https://chicowhitaker.wordpress.com/ - RightClick 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - RightClick 피처 완료
# http://www.liveatspencer68.com/ - RightClick 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - RightClick 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - RightClick 피처 완료
# http://dorkdiaries.co.uk - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857d90>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - RightClick 피처 완료
# https://www.voog.com/ - RightClick 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - RightClick 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857130>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - RightClick 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856ce0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - RightClick 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - RightClick 피처 완료
# http://satkom.id/img/clpds/index.php - RightClick 피처 완료
# http://www.cwa4501.org/ControlPanel - RightClick 피처 완료
# https://www.discogs.com/artist/Linkin+Park - RightClick 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - RightClick 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c856a70>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - RightClick 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - RightClick 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - RightClick 피처 완료
# https://www.chiostrodelbramante.it/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854130>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - RightClick 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - RightClick 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - RightClick 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf3df90>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - RightClick 피처 완료
# https://www.gadgetzone.com.my/ - RightClick 피처 완료
# https://www.corbaraweb.com/shop/it/ - RightClick 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - RightClick 피처 완료
# https://www.techlahoma.org/ - RightClick 피처 완료
# https://apshop.vn/ - RightClick 피처 완료
# http://www.dictionary.com/browse/traffic - RightClick 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - RightClick 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - RightClick 피처 완료
# https://www.metropolitandecor.com - RightClick 피처 완료
# http://www.helpathome.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - RightClick 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - RightClick 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - RightClick 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854130>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - RightClick 피처 완료
# http://www.pracadarepublicaembeja.net/men - RightClick 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf3e470>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - RightClick 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - RightClick 피처 완료
# http://vkaktivations23.bos.ru - RightClick 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - RightClick 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - RightClick 피처 완료
# http://vufd.hyperphp.com/amzn - RightClick 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - RightClick 피처 완료
# http://p30banksoal.blogfa.com - RightClick 피처 완료
# https://bit.ly/39vDK97 - RightClick 피처 완료
# https://www.emploi-petrole.com/ - RightClick 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - RightClick 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - RightClick 피처 완료
# http://uniteddental.ca/new/trust/db/ - RightClick 피처 완료
# http://to-stromatadiko.gr/cache/ - RightClick 피처 완료
# http://enerclim.com/cs/ - RightClick 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - RightClick 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - RightClick 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - RightClick 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - RightClick 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - RightClick 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - RightClick 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - RightClick 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - RightClick 피처 완료
# http://67.199.68.195/intservices.htm - RightClick 피처 완료
# http://taste-s.blogspot.com/ - RightClick 피처 완료
# https://www.youtube.com/user/PING - RightClick 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3cf40>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - RightClick 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - RightClick 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - RightClick 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - RightClick 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - RightClick 피처 완료
# https://www.namecheap.com/domains/registration.aspx - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c83b610>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c83a890>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - RightClick 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - RightClick 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - RightClick 피처 완료
# http://www.enkiquotes.com/ - RightClick 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - RightClick 피처 완료
# http://dasisko.sk - RightClick 피처 완료
# http://www.inquirelive.co.uk/ - RightClick 피처 완료
# http://whatsappchat.zyns.com/ - RightClick 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - RightClick 피처 완료
# https://www.lebara.com.au/ - RightClick 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73c83b280>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - RightClick 피처 완료
# https://hublaalikes.com/login - RightClick 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - RightClick 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - RightClick 피처 완료
# https://www.chiefarchitect.com/ - RightClick 피처 완료
# http://securityxploded.com/router-password-kracker.php - RightClick 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - RightClick 피처 완료
# https://www.jobchannel.ch/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='maanprofessionals.nl', port=80): Max retries exceeded with url: /index.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8394e0>: Failed to resolve 'maanprofessionals.nl' ([Errno -5] No address associated with hostname)"))
# http://maanprofessionals.nl//index.html - RightClick 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - RightClick 피처 완료
# https://www.handshq.com/ - RightClick 피처 완료
# http://www.goodgame.hr/ - RightClick 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - RightClick 피처 완료
# http://www.ktplasmachinery.com/cs/ - RightClick 피처 완료
# https://www.recyclingcenters.org/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='mocabonitabresil.com', port=80): Max retries exceeded with url: /modules/We-Transfer/2020 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839c60>: Failed to resolve 'mocabonitabresil.com' ([Errno -2] Name or service not known)"))
# http://mocabonitabresil.com/modules/We-Transfer/2020 - RightClick 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - RightClick 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - RightClick 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - RightClick 피처 완료
# http://elexusbettgiris4.blogspot.com - RightClick 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - RightClick 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - RightClick 피처 완료
# http://artemisbetguncel.blogspot.com - RightClick 피처 완료
# https://www.facebook.com/savers - RightClick 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - RightClick 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - RightClick 피처 완료
# http://sjec.edu.in - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.nicaraguafood.org', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c83b430>: Failed to resolve 'www.nicaraguafood.org' ([Errno -2] Name or service not known)"))
# http://www.nicaraguafood.org/ - RightClick 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/aa4d130de38808b (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839c90>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - RightClick 피처 완료
# https://zipansion.com/3lqqn - RightClick 피처 완료
# http://www.speedcamupdates.com/ - RightClick 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - RightClick 피처 완료
# https://norecipes.com/japanese-curry-scratch - RightClick 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - RightClick 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='madeua.info', port=80): Max retries exceeded with url: /media/jsslider/drive/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c83ba90>: Failed to resolve 'madeua.info' ([Errno -2] Name or service not known)"))
# http://madeua.info/media/jsslider/drive/index.php - RightClick 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - RightClick 피처 완료
# https://www.101domain.com/ - RightClick 피처 완료
# https://www.hipertrofia.org/blog/ - RightClick 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - RightClick 피처 완료
# https://www.handlestore.com/ - RightClick 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - RightClick 피처 완료
# https://jamthomp.weebly.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='itxuye.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec73c83a320>, 'Connection to itxuye.com timed out. (connect timeout=10)'))
# https://itxuye.com/ - RightClick 피처 완료
# https://polarklimatsgserver.blogspot.com/ - RightClick 피처 완료
# http://www.srnonline.com/show-clocks - RightClick 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - RightClick 피처 완료
# http://www.linfo.org/osi_model.html - RightClick 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='doc.google.share.pressurecookerindia.com', port=80): Max retries exceeded with url: /clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839360>: Failed to resolve 'doc.google.share.pressurecookerindia.com' ([Errno -2] Name or service not known)"))
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - RightClick 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - RightClick 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - RightClick 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - RightClick 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c838e80>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - RightClick 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - RightClick 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - RightClick 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='illitrading.ro', port=80): Max retries exceeded with url: /doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8394e0>: Failed to resolve 'illitrading.ro' ([Errno -2] Name or service not known)"))
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - RightClick 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - RightClick 피처 완료
# https://www.blindkids.org/ - RightClick 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - RightClick 피처 완료
# https://russeprofilering.no/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='justlookapp.com', port=80): Max retries exceeded with url: /blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839630>: Failed to resolve 'justlookapp.com' ([Errno -2] Name or service not known)"))
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - RightClick 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - RightClick 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - RightClick 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='yanddcleaning.com.au', port=443): Max retries exceeded with url: /Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://yanddcleaning.com.au/Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae - RightClick 피처 완료
# http://stattrek.com/statistics/dictionary.aspx?definition=standard%20error - RightClick 피처 완료
# http://phpsecurity.readthedocs.io/en/latest/Transport-Layer-Security-(HTTPS-SSL-and-TLS).html - RightClick 피처 완료
# http://masterhealthcaregroup.com/wp-content/uploads/Office369/cfb7a0824144625b1067e3859bb85ffc/Login.php?websrc=59c275dc2e97dd3b896ed4ff2b82a8fd&dispatched=29&id=878485762 - RightClick 피처 완료
# http://zhanglab.ccmb.med.umich.edu/ThreaDom/ - RightClick 피처 완료
# https://www.jacobspillow.org/ - RightClick 피처 완료
# http://www.tech-faq.com/mms.html - RightClick 피처 완료
# http://ethpromo-giveaway.atspace.cc/ - RightClick 피처 완료
# ...
# https://www.kia.com/cz/dealer/pemmbrno/ - RightClick 피처 완료
# http://www.passiveaggressivehusband.com/break-up-with-a-passive-aggressive-man/ - RightClick 피처 완료
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - RightClick 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - RightClick 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - RightClick 피처 완료
# http://espace-client.net/canalsat-resiliation - RightClick 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - RightClick 피처 완료
# http://www.dictionary.com/browse/select-committee - RightClick 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8384f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - RightClick 피처 완료
# https://kywait.blogspot.com/ - RightClick 피처 완료
# http://sniz.porn - RightClick 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - RightClick 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - RightClick 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c838880>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - RightClick 피처 완료
# https://www.russianlovematch.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8399f0>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - RightClick 피처 완료
# http://www.casinocitytimes.com/ - RightClick 피처 완료
# https://app66560000.blogspot.com/ - RightClick 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - RightClick 피처 완료
# http://toppave.com.sg - RightClick 피처 완료
# https://bologna.babyloweb.eu/info/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - RightClick 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - RightClick 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - RightClick 피처 완료
# https://www.eliteprospects.com/ - RightClick 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - RightClick 피처 완료
# https://raphaelhammoud.wordpress.com/ - RightClick 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c838e50>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - RightClick 피처 완료
# https://www.sammonsfinancialgroup.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c8380a0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c839fc0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - RightClick 피처 완료
# http://bangla.plus - RightClick 피처 완료
# https://www.agri85.fr/V3/admin/red.php - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c83aec0>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - RightClick 피처 완료
# http://www.atmi.gr/ - RightClick 피처 완료
# http://botforbyks.blogspot.ru/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8384c0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - RightClick 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - RightClick 피처 완료
# http://www.abbreviations.com/term/16642 - RightClick 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - RightClick 피처 완료
# https://nozed-uname.firebaseapp.com/ - RightClick 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c83a0b0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - RightClick 피처 완료
# https://www.smart-wiki.net/ - RightClick 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8381f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - RightClick 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - RightClick 피처 완료
# http://energo-investment.hu - RightClick 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - RightClick 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - RightClick 피처 완료
# http://www.thefreedictionary.com/select+committee - RightClick 피처 완료
# http://barbo.sk - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - RightClick 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - RightClick 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - RightClick 피처 완료
# http://faceboook.bitballoon.com/ - RightClick 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - RightClick 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8571f0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857340>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c8559f0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - RightClick 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - RightClick 피처 완료
# http://app66560000.blogspot.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3d900>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857be0>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - RightClick 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - RightClick 피처 완료
# http://www.geocities.ws/steamcom/ - RightClick 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - RightClick 피처 완료
# http://www.mousebreaker.com/games/clicker - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c857f10>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - RightClick 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - RightClick 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - RightClick 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - RightClick 피처 완료
# http://ht.ly/wPX430q3I2o - RightClick 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - RightClick 피처 완료
# https://en.wikipedia.org/wiki/Gateway - RightClick 피처 완료
# http://www.minus40.info/ice/dracula-old.html - RightClick 피처 완료
# https://www.missfiga.com/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8557e0>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - RightClick 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - RightClick 피처 완료
# http://www.kreport.com/tmp/ - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c856650>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - RightClick 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8544f0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - RightClick 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - RightClick 피처 완료
# http://www.personalniyhoroskop.com/ - RightClick 피처 완료
# https://www.wordnik.com/words/blackletter - RightClick 피처 완료
# https://www.conceptcarz.com/ - RightClick 피처 완료
# https://sites.google.com/site/ilyasdxih - RightClick 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - RightClick 피처 완료
# RightClick HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3f700>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - RightClick 피처 완료
# http://www.calculate.co.il/ - RightClick 피처 완료
# http://www.codeboiler.net/ - RightClick 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - RightClick 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - RightClick 피처 완료
# 피처 'RightClick' 추가 완료:
#    RightClick
# 0          -1
# 1          -1
# 2          -1
# 3           1
# 4           1

# %%
apply(df, cbf.popup_window_text, 'popUpWidnow')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - popUpWidnow 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - popUpWidnow 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.routeralley.com', port=80): Read timed out. (read timeout=10)
# http://www.routeralley.com/guides/nat.pdf - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf599f0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - popUpWidnow 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf5a7d0>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf5af50>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - popUpWidnow 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf59ba0>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - popUpWidnow 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - popUpWidnow 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - popUpWidnow 피처 완료
# http://www.dictionary.com/browse/tabloid - popUpWidnow 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - popUpWidnow 피처 완료
# http://www.thefreedictionary.com/compact+disc - popUpWidnow 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c676fb0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - popUpWidnow 피처 완료
# http://vki.vipcentr.ru - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c79b160>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - popUpWidnow 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - popUpWidnow 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - popUpWidnow 피처 완료
# http://www.chinadryer.cn/pa - popUpWidnow 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - popUpWidnow 피처 완료
# https://www.soul-flower.com/ - popUpWidnow 피처 완료
# http://remontka.pro/mac-address/ - popUpWidnow 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - popUpWidnow 피처 완료
# https://www.haciserif.com.tr/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3cdf0>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf011b0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - popUpWidnow 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c453880>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c478220>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - popUpWidnow 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - popUpWidnow 피처 완료
# https://twitter.com/mimosagrillclt - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c478cd0>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - popUpWidnow 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.2345daohang.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c4786a0>, 'Connection to www.2345daohang.com timed out. (connect timeout=10)'))
# http://www.2345daohang.com/ - popUpWidnow 피처 완료
# http://bakeri-net.blogfa.com - popUpWidnow 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c3a2fb0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f7ac0>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - popUpWidnow 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - popUpWidnow 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - popUpWidnow 피처 완료
# http://owl.li/9KyR30pXOCN - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f57e0>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - popUpWidnow 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - popUpWidnow 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f4250>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - popUpWidnow 피처 완료
# /content/content_based_features.py:47: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - popUpWidnow 피처 완료
# https://www.sportsengine.com/solutions/ - popUpWidnow 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc9b250>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - popUpWidnow 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - popUpWidnow 피처 완료
# https://www.iplocation.net/mac-address - popUpWidnow 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - popUpWidnow 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - popUpWidnow 피처 완료
# http://www.grafikerler.org/ - popUpWidnow 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - popUpWidnow 피처 완료
# https://www.metal-supply.dk/ - popUpWidnow 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - popUpWidnow 피처 완료
# https://www.facebook.com/thekeyboardcat - popUpWidnow 피처 완료
# https://www.weightworld.se/ - popUpWidnow 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - popUpWidnow 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - popUpWidnow 피처 완료
# http://securkenya.com/wp-content/dh1 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c182ef0>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - popUpWidnow 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - popUpWidnow 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb57250>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - popUpWidnow 피처 완료
# http://sophie-world.com/games/port-and-starboard - popUpWidnow 피처 완료
# https://learn.sparkfun.com/tutorials/16 - popUpWidnow 피처 완료
# http://signin-store-ws.frontieroption.com/ - popUpWidnow 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - popUpWidnow 피처 완료
# https://noreply-netelle.blogspot.com/ - popUpWidnow 피처 완료
# https://www.off-the-road.de/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6246d0>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - popUpWidnow 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - popUpWidnow 피처 완료
# http://setaccess.webflow.io/ - popUpWidnow 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - popUpWidnow 피처 완료
# https://estacaoxxx.wordpress.com/ - popUpWidnow 피처 완료
# http://www.arcanelegendsgame.com/ - popUpWidnow 피처 완료
# https://www.ingame.de/ - popUpWidnow 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - popUpWidnow 피처 완료
# https://zmail221.appspot.com - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5517e0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5ce6e0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - popUpWidnow 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - popUpWidnow 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - popUpWidnow 피처 완료
# https://www.alteredgamer.com/ - popUpWidnow 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - popUpWidnow 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - popUpWidnow 피처 완료
# http://www.imdb.com/Title?3682448 - popUpWidnow 피처 완료
# https://www.workiva.com/ - popUpWidnow 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - popUpWidnow 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - popUpWidnow 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - popUpWidnow 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf7b8e0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - popUpWidnow 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - popUpWidnow 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf7a1a0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - popUpWidnow 피처 완료
# https://www.unmannedtechshop.co.uk/ - popUpWidnow 피처 완료
# https://www.annabelle.com.cy - popUpWidnow 피처 완료
# https://www.provenancevineyards.com/ - popUpWidnow 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - popUpWidnow 피처 완료
# http://www.answers.com/Q/Digital_media_salary - popUpWidnow 피처 완료
# http://betasusgirsenesende.blogspot.com - popUpWidnow 피처 완료
# https://www.provenancevineyards.com/our-wines - popUpWidnow 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - popUpWidnow 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bd452a0>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - popUpWidnow 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - popUpWidnow 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - popUpWidnow 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - popUpWidnow 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - popUpWidnow 피처 완료
# https://mailserver67187.uc.r.appspot.com - popUpWidnow 피처 완료
# http://www.astroresidential.co.uk/application/data/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - popUpWidnow 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - popUpWidnow 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - popUpWidnow 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - popUpWidnow 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5b2c80>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - popUpWidnow 피처 완료
# http://www.neutralsources.com/-/re.html - popUpWidnow 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - popUpWidnow 피처 완료
# http://judithleoni.com/telecom-de/index.php - popUpWidnow 피처 완료
# http://www.definitions.net/definition/compact%20disc - popUpWidnow 피처 완료
# http://press-preview.weebly.com - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf02e30>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - popUpWidnow 피처 완료
# https://www.facebook.com/imdbpro/ - popUpWidnow 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc9b820>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - popUpWidnow 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - popUpWidnow 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - popUpWidnow 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - popUpWidnow 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - popUpWidnow 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c654070>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - popUpWidnow 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - popUpWidnow 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - popUpWidnow 피처 완료
# https://www.markspcsolution.com/ - popUpWidnow 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - popUpWidnow 피처 완료
# http://www.price2india.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c0823b0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c082b30>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - popUpWidnow 피처 완료
# https://scenari.software/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - popUpWidnow 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c083760>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - popUpWidnow 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - popUpWidnow 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - popUpWidnow 피처 완료
# https://www.drawdown.org/ - popUpWidnow 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - popUpWidnow 피처 완료
# https://chicowhitaker.wordpress.com/ - popUpWidnow 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - popUpWidnow 피처 완료
# http://www.liveatspencer68.com/ - popUpWidnow 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - popUpWidnow 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - popUpWidnow 피처 완료
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - popUpWidnow 피처 완료
# http://dorkdiaries.co.uk - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f6470>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - popUpWidnow 피처 완료
# https://www.voog.com/ - popUpWidnow 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - popUpWidnow 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf31480>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - popUpWidnow 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf7fdf0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - popUpWidnow 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - popUpWidnow 피처 완료
# http://satkom.id/img/clpds/index.php - popUpWidnow 피처 완료
# http://www.cwa4501.org/ControlPanel - popUpWidnow 피처 완료
# https://www.discogs.com/artist/Linkin+Park - popUpWidnow 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - popUpWidnow 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf8df90>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - popUpWidnow 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - popUpWidnow 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - popUpWidnow 피처 완료
# https://www.chiostrodelbramante.it/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba89e10>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - popUpWidnow 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - popUpWidnow 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - popUpWidnow 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73beecfd0>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - popUpWidnow 피처 완료
# https://www.gadgetzone.com.my/ - popUpWidnow 피처 완료
# https://www.corbaraweb.com/shop/it/ - popUpWidnow 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - popUpWidnow 피처 완료
# https://www.techlahoma.org/ - popUpWidnow 피처 완료
# https://apshop.vn/ - popUpWidnow 피처 완료
# http://www.dictionary.com/browse/traffic - popUpWidnow 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - popUpWidnow 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - popUpWidnow 피처 완료
# https://www.metropolitandecor.com - popUpWidnow 피처 완료
# http://www.helpathome.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - popUpWidnow 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - popUpWidnow 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - popUpWidnow 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc0e2f0>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - popUpWidnow 피처 완료
# http://www.pracadarepublicaembeja.net/men - popUpWidnow 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bc0e920>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - popUpWidnow 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - popUpWidnow 피처 완료
# http://vkaktivations23.bos.ru - popUpWidnow 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - popUpWidnow 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - popUpWidnow 피처 완료
# http://vufd.hyperphp.com/amzn - popUpWidnow 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - popUpWidnow 피처 완료
# http://p30banksoal.blogfa.com - popUpWidnow 피처 완료
# https://bit.ly/39vDK97 - popUpWidnow 피처 완료
# https://www.emploi-petrole.com/ - popUpWidnow 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - popUpWidnow 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - popUpWidnow 피처 완료
# http://uniteddental.ca/new/trust/db/ - popUpWidnow 피처 완료
# http://to-stromatadiko.gr/cache/ - popUpWidnow 피처 완료
# http://enerclim.com/cs/ - popUpWidnow 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - popUpWidnow 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - popUpWidnow 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - popUpWidnow 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - popUpWidnow 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - popUpWidnow 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - popUpWidnow 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - popUpWidnow 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - popUpWidnow 피처 완료
# http://67.199.68.195/intservices.htm - popUpWidnow 피처 완료
# http://taste-s.blogspot.com/ - popUpWidnow 피처 완료
# https://www.youtube.com/user/PING - popUpWidnow 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b8d3d30>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - popUpWidnow 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - popUpWidnow 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - popUpWidnow 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - popUpWidnow 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - popUpWidnow 피처 완료
# https://www.namecheap.com/domains/registration.aspx - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839c60>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c83a950>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - popUpWidnow 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - popUpWidnow 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - popUpWidnow 피처 완료
# http://www.enkiquotes.com/ - popUpWidnow 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - popUpWidnow 피처 완료
# http://dasisko.sk - popUpWidnow 피처 완료
# http://www.inquirelive.co.uk/ - popUpWidnow 피처 완료
# http://whatsappchat.zyns.com/ - popUpWidnow 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - popUpWidnow 피처 완료
# https://www.lebara.com.au/ - popUpWidnow 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73c520e50>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - popUpWidnow 피처 완료
# https://hublaalikes.com/login - popUpWidnow 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - popUpWidnow 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - popUpWidnow 피처 완료
# https://www.chiefarchitect.com/ - popUpWidnow 피처 완료
# http://securityxploded.com/router-password-kracker.php - popUpWidnow 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - popUpWidnow 피처 완료
# https://www.jobchannel.ch/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='maanprofessionals.nl', port=80): Max retries exceeded with url: /index.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c081750>: Failed to resolve 'maanprofessionals.nl' ([Errno -5] No address associated with hostname)"))
# http://maanprofessionals.nl//index.html - popUpWidnow 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - popUpWidnow 피처 완료
# https://www.handshq.com/ - popUpWidnow 피처 완료
# http://www.goodgame.hr/ - popUpWidnow 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - popUpWidnow 피처 완료
# http://www.ktplasmachinery.com/cs/ - popUpWidnow 피처 완료
# https://www.recyclingcenters.org/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='mocabonitabresil.com', port=80): Max retries exceeded with url: /modules/We-Transfer/2020 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bec53f0>: Failed to resolve 'mocabonitabresil.com' ([Errno -2] Name or service not known)"))
# http://mocabonitabresil.com/modules/We-Transfer/2020 - popUpWidnow 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - popUpWidnow 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - popUpWidnow 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - popUpWidnow 피처 완료
# http://elexusbettgiris4.blogspot.com - popUpWidnow 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - popUpWidnow 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - popUpWidnow 피처 완료
# http://artemisbetguncel.blogspot.com - popUpWidnow 피처 완료
# https://www.facebook.com/savers - popUpWidnow 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - popUpWidnow 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - popUpWidnow 피처 완료
# http://sjec.edu.in - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.nicaraguafood.org', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c73ec20>: Failed to resolve 'www.nicaraguafood.org' ([Errno -2] Name or service not known)"))
# http://www.nicaraguafood.org/ - popUpWidnow 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/aa4d130de38808b (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c7a5690>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - popUpWidnow 피처 완료
# https://zipansion.com/3lqqn - popUpWidnow 피처 완료
# http://www.speedcamupdates.com/ - popUpWidnow 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - popUpWidnow 피처 완료
# https://norecipes.com/japanese-curry-scratch - popUpWidnow 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - popUpWidnow 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='madeua.info', port=80): Max retries exceeded with url: /media/jsslider/drive/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c73f970>: Failed to resolve 'madeua.info' ([Errno -2] Name or service not known)"))
# http://madeua.info/media/jsslider/drive/index.php - popUpWidnow 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - popUpWidnow 피처 완료
# https://www.101domain.com/ - popUpWidnow 피처 완료
# https://www.hipertrofia.org/blog/ - popUpWidnow 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - popUpWidnow 피처 완료
# https://www.handlestore.com/ - popUpWidnow 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - popUpWidnow 피처 완료
# https://jamthomp.weebly.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='itxuye.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec73c2ec3d0>, 'Connection to itxuye.com timed out. (connect timeout=10)'))
# https://itxuye.com/ - popUpWidnow 피처 완료
# https://polarklimatsgserver.blogspot.com/ - popUpWidnow 피처 완료
# http://www.srnonline.com/show-clocks - popUpWidnow 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - popUpWidnow 피처 완료
# http://www.linfo.org/osi_model.html - popUpWidnow 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='doc.google.share.pressurecookerindia.com', port=80): Max retries exceeded with url: /clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf6d870>: Failed to resolve 'doc.google.share.pressurecookerindia.com' ([Errno -2] Name or service not known)"))
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - popUpWidnow 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - popUpWidnow 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - popUpWidnow 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - popUpWidnow 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd88c10>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - popUpWidnow 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - popUpWidnow 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - popUpWidnow 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='illitrading.ro', port=80): Max retries exceeded with url: /doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6e6fb0>: Failed to resolve 'illitrading.ro' ([Errno -2] Name or service not known)"))
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - popUpWidnow 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - popUpWidnow 피처 완료
# https://www.blindkids.org/ - popUpWidnow 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - popUpWidnow 피처 완료
# https://russeprofilering.no/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='justlookapp.com', port=80): Max retries exceeded with url: /blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6e58d0>: Failed to resolve 'justlookapp.com' ([Errno -2] Name or service not known)"))
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - popUpWidnow 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - popUpWidnow 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - popUpWidnow 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - popUpWidnow 피처 완료
# ...
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - popUpWidnow 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - popUpWidnow 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - popUpWidnow 피처 완료
# http://espace-client.net/canalsat-resiliation - popUpWidnow 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - popUpWidnow 피처 완료
# http://www.dictionary.com/browse/select-committee - popUpWidnow 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73be6d810>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - popUpWidnow 피처 완료
# https://kywait.blogspot.com/ - popUpWidnow 피처 완료
# http://sniz.porn - popUpWidnow 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - popUpWidnow 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - popUpWidnow 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c643130>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - popUpWidnow 피처 완료
# https://www.russianlovematch.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba8a170>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - popUpWidnow 피처 완료
# http://www.casinocitytimes.com/ - popUpWidnow 피처 완료
# https://app66560000.blogspot.com/ - popUpWidnow 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - popUpWidnow 피처 완료
# http://toppave.com.sg - popUpWidnow 피처 완료
# https://bologna.babyloweb.eu/info/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - popUpWidnow 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - popUpWidnow 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - popUpWidnow 피처 완료
# https://www.eliteprospects.com/ - popUpWidnow 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - popUpWidnow 피처 완료
# https://raphaelhammoud.wordpress.com/ - popUpWidnow 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36ead0>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - popUpWidnow 피처 완료
# https://www.sammonsfinancialgroup.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c702da0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c7033a0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - popUpWidnow 피처 완료
# http://bangla.plus - popUpWidnow 피처 완료
# https://www.agri85.fr/V3/admin/red.php - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c283160>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - popUpWidnow 피처 완료
# http://www.atmi.gr/ - popUpWidnow 피처 완료
# http://botforbyks.blogspot.ru/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c2829e0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - popUpWidnow 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - popUpWidnow 피처 완료
# http://www.abbreviations.com/term/16642 - popUpWidnow 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - popUpWidnow 피처 완료
# https://nozed-uname.firebaseapp.com/ - popUpWidnow 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f7010>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - popUpWidnow 피처 완료
# https://www.smart-wiki.net/ - popUpWidnow 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c030640>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - popUpWidnow 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - popUpWidnow 피처 완료
# http://energo-investment.hu - popUpWidnow 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - popUpWidnow 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - popUpWidnow 피처 완료
# http://www.thefreedictionary.com/select+committee - popUpWidnow 피처 완료
# http://barbo.sk - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - popUpWidnow 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - popUpWidnow 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - popUpWidnow 피처 완료
# http://faceboook.bitballoon.com/ - popUpWidnow 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - popUpWidnow 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc3f130>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc5cf70>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bc5d7e0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - popUpWidnow 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - popUpWidnow 피처 완료
# http://app66560000.blogspot.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc5e980>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc5f190>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - popUpWidnow 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - popUpWidnow 피처 완료
# http://www.geocities.ws/steamcom/ - popUpWidnow 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - popUpWidnow 피처 완료
# http://www.mousebreaker.com/games/clicker - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73be2ba90>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - popUpWidnow 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - popUpWidnow 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - popUpWidnow 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - popUpWidnow 피처 완료
# http://ht.ly/wPX430q3I2o - popUpWidnow 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - popUpWidnow 피처 완료
# https://en.wikipedia.org/wiki/Gateway - popUpWidnow 피처 완료
# http://www.minus40.info/ice/dracula-old.html - popUpWidnow 피처 완료
# https://www.missfiga.com/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf68400>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - popUpWidnow 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - popUpWidnow 피처 완료
# http://www.kreport.com/tmp/ - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c5e0dc0>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - popUpWidnow 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf6b880>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - popUpWidnow 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - popUpWidnow 피처 완료
# http://www.personalniyhoroskop.com/ - popUpWidnow 피처 완료
# https://www.wordnik.com/words/blackletter - popUpWidnow 피처 완료
# https://www.conceptcarz.com/ - popUpWidnow 피처 완료
# https://sites.google.com/site/ilyasdxih - popUpWidnow 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - popUpWidnow 피처 완료
# popUpWidnow HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcca680>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - popUpWidnow 피처 완료
# http://www.calculate.co.il/ - popUpWidnow 피처 완료
# http://www.codeboiler.net/ - popUpWidnow 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - popUpWidnow 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - popUpWidnow 피처 완료
# 피처 'popUpWidnow' 추가 완료:
#    popUpWidnow
# 0            1
# 1            1
# 2           -1
# 3            1
# 4            1

# %%
apply(df, cbf.iFrame_redirection, 'Iframe')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Iframe 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Iframe 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9b130>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9baf0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Iframe 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd94580>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd94ca0>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Iframe 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd9bfd0>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Iframe 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Iframe 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Iframe 피처 완료
# http://www.dictionary.com/browse/tabloid - Iframe 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Iframe 피처 완료
# http://www.thefreedictionary.com/compact+disc - Iframe 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd99ba0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Iframe 피처 완료
# http://vki.vipcentr.ru - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9b280>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Iframe 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - Iframe 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Iframe 피처 완료
# http://www.chinadryer.cn/pa - Iframe 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Iframe 피처 완료
# https://www.soul-flower.com/ - Iframe 피처 완료
# http://remontka.pro/mac-address/ - Iframe 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Iframe 피처 완료
# https://www.haciserif.com.tr/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9a710>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd9be20>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Iframe 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd99a50>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcca710>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Iframe 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Iframe 피처 완료
# https://twitter.com/mimosagrillclt - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd9ada0>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Iframe 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Iframe 피처 완료
# http://www.2345daohang.com/ - Iframe 피처 완료
# http://bakeri-net.blogfa.com - Iframe 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9b340>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9a680>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Iframe 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Iframe 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Iframe 피처 완료
# http://owl.li/9KyR30pXOCN - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9ac20>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Iframe 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Iframe 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9ba00>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Iframe 피처 완료
# https://www.luxuryloft.eu/ - Iframe 피처 완료
# https://www.sportsengine.com/solutions/ - Iframe 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9beb0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Iframe 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Iframe 피처 완료
# https://www.iplocation.net/mac-address - Iframe 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Iframe 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Iframe 피처 완료
# http://www.grafikerler.org/ - Iframe 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Iframe 피처 완료
# https://www.metal-supply.dk/ - Iframe 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Iframe 피처 완료
# https://www.facebook.com/thekeyboardcat - Iframe 피처 완료
# https://www.weightworld.se/ - Iframe 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Iframe 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Iframe 피처 완료
# http://securkenya.com/wp-content/dh1 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9afe0>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Iframe 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Iframe 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccba00>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Iframe 피처 완료
# http://sophie-world.com/games/port-and-starboard - Iframe 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Iframe 피처 완료
# http://signin-store-ws.frontieroption.com/ - Iframe 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Iframe 피처 완료
# https://noreply-netelle.blogspot.com/ - Iframe 피처 완료
# https://www.off-the-road.de/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9afb0>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Iframe 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Iframe 피처 완료
# http://setaccess.webflow.io/ - Iframe 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Iframe 피처 완료
# https://estacaoxxx.wordpress.com/ - Iframe 피처 완료
# http://www.arcanelegendsgame.com/ - Iframe 피처 완료
# https://www.ingame.de/ - Iframe 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Iframe 피처 완료
# https://zmail221.appspot.com - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9b1c0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd95840>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Iframe 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Iframe 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Iframe 피처 완료
# https://www.alteredgamer.com/ - Iframe 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Iframe 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - Iframe 피처 완료
# http://www.imdb.com/Title?3682448 - Iframe 피처 완료
# https://www.workiva.com/ - Iframe 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Iframe 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Iframe 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Iframe 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf1930>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Iframe 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Iframe 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf2920>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Iframe 피처 완료
# https://www.unmannedtechshop.co.uk/ - Iframe 피처 완료
# https://www.annabelle.com.cy - Iframe 피처 완료
# https://www.provenancevineyards.com/ - Iframe 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Iframe 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Iframe 피처 완료
# http://betasusgirsenesende.blogspot.com - Iframe 피처 완료
# https://www.provenancevineyards.com/our-wines - Iframe 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Iframe 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bbab8e0>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Iframe 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Iframe 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Iframe 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Iframe 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Iframe 피처 완료
# https://mailserver67187.uc.r.appspot.com - Iframe 피처 완료
# http://www.astroresidential.co.uk/application/data/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Iframe 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Iframe 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Iframe 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Iframe 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccbdc0>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Iframe 피처 완료
# http://www.neutralsources.com/-/re.html - Iframe 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - Iframe 피처 완료
# http://judithleoni.com/telecom-de/index.php - Iframe 피처 완료
# http://www.definitions.net/definition/compact%20disc - Iframe 피처 완료
# http://press-preview.weebly.com - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bbab220>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Iframe 피처 완료
# https://www.facebook.com/imdbpro/ - Iframe 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbaae90>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Iframe 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Iframe 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Iframe 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Iframe 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Iframe 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bcf2560>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Iframe 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Iframe 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Iframe 피처 완료
# https://www.markspcsolution.com/ - Iframe 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - Iframe 피처 완료
# http://www.price2india.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bcf23e0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bbab910>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Iframe 피처 완료
# https://scenari.software/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Iframe 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73bcf2a10>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Iframe 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Iframe 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - Iframe 피처 완료
# https://www.drawdown.org/ - Iframe 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - Iframe 피처 완료
# https://chicowhitaker.wordpress.com/ - Iframe 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Iframe 피처 완료
# http://www.liveatspencer68.com/ - Iframe 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - Iframe 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com', port=80): Max retries exceeded with url: /update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bccb970>, 'Connection to www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com timed out. (connect timeout=10)'))
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Iframe 피처 완료
# http://dorkdiaries.co.uk - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbab520>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Iframe 피처 완료
# https://www.voog.com/ - Iframe 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - Iframe 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbaa7d0>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Iframe 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf28f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Iframe 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Iframe 피처 완료
# http://satkom.id/img/clpds/index.php - Iframe 피처 완료
# http://www.cwa4501.org/ControlPanel - Iframe 피처 완료
# https://www.discogs.com/artist/Linkin+Park - Iframe 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Iframe 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccbf70>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Iframe 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - Iframe 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Iframe 피처 완료
# https://www.chiostrodelbramante.it/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf2800>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Iframe 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Iframe 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - Iframe 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd95690>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Iframe 피처 완료
# https://www.gadgetzone.com.my/ - Iframe 피처 완료
# https://www.corbaraweb.com/shop/it/ - Iframe 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Iframe 피처 완료
# https://www.techlahoma.org/ - Iframe 피처 완료
# https://apshop.vn/ - Iframe 피처 완료
# http://www.dictionary.com/browse/traffic - Iframe 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Iframe 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Iframe 피처 완료
# https://www.metropolitandecor.com - Iframe 피처 완료
# http://www.helpathome.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Iframe 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Iframe 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Iframe 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf1de0>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Iframe 피처 완료
# http://www.pracadarepublicaembeja.net/men - Iframe 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccae30>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Iframe 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Iframe 피처 완료
# http://vkaktivations23.bos.ru - Iframe 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Iframe 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Iframe 피처 완료
# http://vufd.hyperphp.com/amzn - Iframe 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Iframe 피처 완료
# http://p30banksoal.blogfa.com - Iframe 피처 완료
# https://bit.ly/39vDK97 - Iframe 피처 완료
# https://www.emploi-petrole.com/ - Iframe 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Iframe 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Iframe 피처 완료
# http://uniteddental.ca/new/trust/db/ - Iframe 피처 완료
# http://to-stromatadiko.gr/cache/ - Iframe 피처 완료
# http://enerclim.com/cs/ - Iframe 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Iframe 피처 완료
# Iframe HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Iframe 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Iframe 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - Iframe 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - Iframe 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - Iframe 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - Iframe 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - Iframe 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - Iframe 피처 완료
# http://67.199.68.195/intservices.htm - Iframe 피처 완료
# http://taste-s.blogspot.com/ - Iframe 피처 완료
# https://www.youtube.com/user/PING - Iframe 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9be80>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - Iframe 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - Iframe 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - Iframe 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - Iframe 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - Iframe 피처 완료
# https://www.namecheap.com/domains/registration.aspx - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd99780>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73bd993c0>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - Iframe 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - Iframe 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - Iframe 피처 완료
# http://www.enkiquotes.com/ - Iframe 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - Iframe 피처 완료
# http://dasisko.sk - Iframe 피처 완료
# http://www.inquirelive.co.uk/ - Iframe 피처 완료
# http://whatsappchat.zyns.com/ - Iframe 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - Iframe 피처 완료
# https://www.lebara.com.au/ - Iframe 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73bd99570>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - Iframe 피처 완료
# https://hublaalikes.com/login - Iframe 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - Iframe 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - Iframe 피처 완료
# https://www.chiefarchitect.com/ - Iframe 피처 완료
# http://securityxploded.com/router-password-kracker.php - Iframe 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - Iframe 피처 완료
# https://www.jobchannel.ch/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='maanprofessionals.nl', port=80): Max retries exceeded with url: /index.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9a230>: Failed to resolve 'maanprofessionals.nl' ([Errno -5] No address associated with hostname)"))
# http://maanprofessionals.nl//index.html - Iframe 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - Iframe 피처 완료
# https://www.handshq.com/ - Iframe 피처 완료
# http://www.goodgame.hr/ - Iframe 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - Iframe 피처 완료
# http://www.ktplasmachinery.com/cs/ - Iframe 피처 완료
# https://www.recyclingcenters.org/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='mocabonitabresil.com', port=80): Max retries exceeded with url: /modules/We-Transfer/2020 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccbfd0>: Failed to resolve 'mocabonitabresil.com' ([Errno -2] Name or service not known)"))
# http://mocabonitabresil.com/modules/We-Transfer/2020 - Iframe 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - Iframe 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - Iframe 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - Iframe 피처 완료
# http://elexusbettgiris4.blogspot.com - Iframe 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - Iframe 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - Iframe 피처 완료
# http://artemisbetguncel.blogspot.com - Iframe 피처 완료
# https://www.facebook.com/savers - Iframe 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - Iframe 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - Iframe 피처 완료
# http://sjec.edu.in - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.nicaraguafood.org', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc8be0>: Failed to resolve 'www.nicaraguafood.org' ([Errno -2] Name or service not known)"))
# http://www.nicaraguafood.org/ - Iframe 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/aa4d130de38808b (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc9b10>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - Iframe 피처 완료
# https://zipansion.com/3lqqn - Iframe 피처 완료
# http://www.speedcamupdates.com/ - Iframe 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - Iframe 피처 완료
# https://norecipes.com/japanese-curry-scratch - Iframe 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - Iframe 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='madeua.info', port=80): Max retries exceeded with url: /media/jsslider/drive/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc92d0>: Failed to resolve 'madeua.info' ([Errno -2] Name or service not known)"))
# http://madeua.info/media/jsslider/drive/index.php - Iframe 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - Iframe 피처 완료
# https://www.101domain.com/ - Iframe 피처 완료
# https://www.hipertrofia.org/blog/ - Iframe 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - Iframe 피처 완료
# https://www.handlestore.com/ - Iframe 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - Iframe 피처 완료
# https://jamthomp.weebly.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='itxuye.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec73bcc8b80>, 'Connection to itxuye.com timed out. (connect timeout=10)'))
# https://itxuye.com/ - Iframe 피처 완료
# https://polarklimatsgserver.blogspot.com/ - Iframe 피처 완료
# http://www.srnonline.com/show-clocks - Iframe 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - Iframe 피처 완료
# http://www.linfo.org/osi_model.html - Iframe 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='doc.google.share.pressurecookerindia.com', port=80): Max retries exceeded with url: /clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc82b0>: Failed to resolve 'doc.google.share.pressurecookerindia.com' ([Errno -2] Name or service not known)"))
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - Iframe 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - Iframe 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - Iframe 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - Iframe 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcca5f0>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - Iframe 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - Iframe 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - Iframe 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='illitrading.ro', port=80): Max retries exceeded with url: /doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc8df0>: Failed to resolve 'illitrading.ro' ([Errno -2] Name or service not known)"))
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - Iframe 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - Iframe 피처 완료
# https://www.blindkids.org/ - Iframe 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - Iframe 피처 완료
# https://russeprofilering.no/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='justlookapp.com', port=80): Max retries exceeded with url: /blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccb910>: Failed to resolve 'justlookapp.com' ([Errno -2] Name or service not known)"))
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - Iframe 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - Iframe 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - Iframe 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='yanddcleaning.com.au', port=443): Max retries exceeded with url: /Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://yanddcleaning.com.au/Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae - Iframe 피처 완료
# http://stattrek.com/statistics/dictionary.aspx?definition=standard%20error - Iframe 피처 완료
# http://phpsecurity.readthedocs.io/en/latest/Transport-Layer-Security-(HTTPS-SSL-and-TLS).html - Iframe 피처 완료
# http://masterhealthcaregroup.com/wp-content/uploads/Office369/cfb7a0824144625b1067e3859bb85ffc/Login.php?websrc=59c275dc2e97dd3b896ed4ff2b82a8fd&dispatched=29&id=878485762 - Iframe 피처 완료
# http://zhanglab.ccmb.med.umich.edu/ThreaDom/ - Iframe 피처 완료
# https://www.jacobspillow.org/ - Iframe 피처 완료
# http://www.tech-faq.com/mms.html - Iframe 피처 완료
# http://ethpromo-giveaway.atspace.cc/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.cartaoitau.tk', port=443): Max retries exceeded with url: /card (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccb9a0>: Failed to resolve 'www.cartaoitau.tk' ([Errno -2] Name or service not known)"))
# https://www.cartaoitau.tk/card - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/14c06909f4e315e?cmd=_update&dispatch=14c06909f4e315e60&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccbeb0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/14c06909f4e315e?cmd=_update&dispatch=14c06909f4e315e60&locale=_US - Iframe 피처 완료
# http://www.columbusonlineauctions.com/cgi-bin/mnhistory.cgi?coa9/1 - Iframe 피처 완료
# ...
# http://raesewsart.com/esewsarlokcke/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.artediezvirtual.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc98a0>: Failed to resolve 'www.artediezvirtual.es' ([Errno -2] Name or service not known)"))
# http://www.artediezvirtual.es - Iframe 피처 완료
# https://www.forbes.com/profile/tory-burch/ - Iframe 피처 완료
# https://safirbetgiristikla.blogspot.com/ - Iframe 피처 완료
# https://www.kia.com/cz/dealer/pemmbrno/ - Iframe 피처 완료
# http://www.passiveaggressivehusband.com/break-up-with-a-passive-aggressive-man/ - Iframe 피처 완료
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - Iframe 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - Iframe 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - Iframe 피처 완료
# http://espace-client.net/canalsat-resiliation - Iframe 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - Iframe 피처 완료
# http://www.dictionary.com/browse/select-committee - Iframe 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccb460>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - Iframe 피처 완료
# https://kywait.blogspot.com/ - Iframe 피처 완료
# http://sniz.porn - Iframe 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - Iframe 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - Iframe 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bcc87c0>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - Iframe 피처 완료
# https://www.russianlovematch.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccb280>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - Iframe 피처 완료
# http://www.casinocitytimes.com/ - Iframe 피처 완료
# https://app66560000.blogspot.com/ - Iframe 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - Iframe 피처 완료
# http://toppave.com.sg - Iframe 피처 완료
# https://bologna.babyloweb.eu/info/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Iframe 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Iframe 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Iframe 피처 완료
# https://www.eliteprospects.com/ - Iframe 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - Iframe 피처 완료
# https://raphaelhammoud.wordpress.com/ - Iframe 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccb7f0>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Iframe 피처 완료
# https://www.sammonsfinancialgroup.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bccba90>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bcc8ac0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Iframe 피처 완료
# http://bangla.plus - Iframe 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bcc99c0>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Iframe 피처 완료
# http://www.atmi.gr/ - Iframe 피처 완료
# http://botforbyks.blogspot.ru/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bcca7d0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Iframe 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Iframe 피처 완료
# http://www.abbreviations.com/term/16642 - Iframe 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Iframe 피처 완료
# https://nozed-uname.firebaseapp.com/ - Iframe 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccae90>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Iframe 피처 완료
# https://www.smart-wiki.net/ - Iframe 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccace0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Iframe 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Iframe 피처 완료
# http://energo-investment.hu - Iframe 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Iframe 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Iframe 피처 완료
# http://www.thefreedictionary.com/select+committee - Iframe 피처 완료
# http://barbo.sk - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - Iframe 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Iframe 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Iframe 피처 완료
# http://faceboook.bitballoon.com/ - Iframe 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Iframe 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebcf70>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebea40>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bebe740>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Iframe 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Iframe 피처 완료
# http://app66560000.blogspot.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebf010>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebfa00>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Iframe 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Iframe 피처 완료
# http://www.geocities.ws/steamcom/ - Iframe 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Iframe 피처 완료
# http://www.mousebreaker.com/games/clicker - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bebdf30>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Iframe 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Iframe 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Iframe 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Iframe 피처 완료
# http://ht.ly/wPX430q3I2o - Iframe 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Iframe 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Iframe 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Iframe 피처 완료
# https://www.missfiga.com/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebebc0>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Iframe 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Iframe 피처 완료
# http://www.kreport.com/tmp/ - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bebf880>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Iframe 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bebfbe0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Iframe 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Iframe 피처 완료
# http://www.personalniyhoroskop.com/ - Iframe 피처 완료
# https://www.wordnik.com/words/blackletter - Iframe 피처 완료
# https://www.conceptcarz.com/ - Iframe 피처 완료
# https://sites.google.com/site/ilyasdxih - Iframe 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Iframe 피처 완료
# Iframe HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebd990>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Iframe 피처 완료
# http://www.calculate.co.il/ - Iframe 피처 완료
# http://www.codeboiler.net/ - Iframe 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Iframe 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Iframe 피처 완료
# 피처 'Iframe' 추가 완료:
#    Iframe
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1

# %%
apply(df, cbf.using_ip, 'having_IPhaving_IP_Address')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - having_IPhaving_IP_Address 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - having_IPhaving_IP_Address 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - having_IPhaving_IP_Address 피처 완료
# http://www.routeralley.com/guides/nat.pdf - having_IPhaving_IP_Address 피처 완료
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - having_IPhaving_IP_Address 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - having_IPhaving_IP_Address 피처 완료
# http://kprealtors.com/ve/ - having_IPhaving_IP_Address 피처 완료
# https://www.skecherstanio.pl/ - having_IPhaving_IP_Address 피처 완료
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - having_IPhaving_IP_Address 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - having_IPhaving_IP_Address 피처 완료
# https://instagramnotice-security.com/username.php - having_IPhaving_IP_Address 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - having_IPhaving_IP_Address 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - having_IPhaving_IP_Address 피처 완료
# http://www.dictionary.com/browse/tabloid - having_IPhaving_IP_Address 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - having_IPhaving_IP_Address 피처 완료
# http://www.thefreedictionary.com/compact+disc - having_IPhaving_IP_Address 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - having_IPhaving_IP_Address 피처 완료
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - having_IPhaving_IP_Address 피처 완료
# http://vki.vipcentr.ru - having_IPhaving_IP_Address 피처 완료
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - having_IPhaving_IP_Address 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - having_IPhaving_IP_Address 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - having_IPhaving_IP_Address 피처 완료
# http://www.chinadryer.cn/pa - having_IPhaving_IP_Address 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - having_IPhaving_IP_Address 피처 완료
# https://www.soul-flower.com/ - having_IPhaving_IP_Address 피처 완료
# http://remontka.pro/mac-address/ - having_IPhaving_IP_Address 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - having_IPhaving_IP_Address 피처 완료
# https://www.haciserif.com.tr/ - having_IPhaving_IP_Address 피처 완료
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - having_IPhaving_IP_Address 피처 완료
# https://myppbilling-acount.link/ - having_IPhaving_IP_Address 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - having_IPhaving_IP_Address 피처 완료
# http://beta.kenaidanceta.com/postamok/d39a2/source - having_IPhaving_IP_Address 피처 완료
# http://chat.whatsapp.com.madsuka.com/invite - having_IPhaving_IP_Address 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - having_IPhaving_IP_Address 피처 완료
# https://twitter.com/mimosagrillclt - having_IPhaving_IP_Address 피처 완료
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - having_IPhaving_IP_Address 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - having_IPhaving_IP_Address 피처 완료
# http://www.2345daohang.com/ - having_IPhaving_IP_Address 피처 완료
# http://bakeri-net.blogfa.com - having_IPhaving_IP_Address 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - having_IPhaving_IP_Address 피처 완료
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - having_IPhaving_IP_Address 피처 완료
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - having_IPhaving_IP_Address 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - having_IPhaving_IP_Address 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - having_IPhaving_IP_Address 피처 완료
# http://owl.li/9KyR30pXOCN - having_IPhaving_IP_Address 피처 완료
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - having_IPhaving_IP_Address 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - having_IPhaving_IP_Address 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - having_IPhaving_IP_Address 피처 완료
# https://www.luxuryloft.eu/ - having_IPhaving_IP_Address 피처 완료
# https://www.sportsengine.com/solutions/ - having_IPhaving_IP_Address 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - having_IPhaving_IP_Address 피처 완료
# http://www.j-net.cn/cms - having_IPhaving_IP_Address 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - having_IPhaving_IP_Address 피처 완료
# https://www.iplocation.net/mac-address - having_IPhaving_IP_Address 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - having_IPhaving_IP_Address 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - having_IPhaving_IP_Address 피처 완료
# http://www.grafikerler.org/ - having_IPhaving_IP_Address 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - having_IPhaving_IP_Address 피처 완료
# https://www.metal-supply.dk/ - having_IPhaving_IP_Address 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - having_IPhaving_IP_Address 피처 완료
# https://www.facebook.com/thekeyboardcat - having_IPhaving_IP_Address 피처 완료
# https://www.weightworld.se/ - having_IPhaving_IP_Address 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - having_IPhaving_IP_Address 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - having_IPhaving_IP_Address 피처 완료
# http://securkenya.com/wp-content/dh1 - having_IPhaving_IP_Address 피처 완료
# http://nagari.or.id/admin/crypt/ - having_IPhaving_IP_Address 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - having_IPhaving_IP_Address 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - having_IPhaving_IP_Address 피처 완료
# http://servicepaypal.serveirc.com/ - having_IPhaving_IP_Address 피처 완료
# http://sophie-world.com/games/port-and-starboard - having_IPhaving_IP_Address 피처 완료
# https://learn.sparkfun.com/tutorials/16 - having_IPhaving_IP_Address 피처 완료
# http://signin-store-ws.frontieroption.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - having_IPhaving_IP_Address 피처 완료
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - having_IPhaving_IP_Address 피처 완료
# https://noreply-netelle.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.off-the-road.de/ - having_IPhaving_IP_Address 피처 완료
# http://www.shellyfergusonphotography.com - having_IPhaving_IP_Address 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - having_IPhaving_IP_Address 피처 완료
# http://setaccess.webflow.io/ - having_IPhaving_IP_Address 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - having_IPhaving_IP_Address 피처 완료
# https://estacaoxxx.wordpress.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.arcanelegendsgame.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.ingame.de/ - having_IPhaving_IP_Address 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - having_IPhaving_IP_Address 피처 완료
# https://zmail221.appspot.com - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - having_IPhaving_IP_Address 피처 완료
# http://transcript.login.2016.getwetusa.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - having_IPhaving_IP_Address 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - having_IPhaving_IP_Address 피처 완료
# https://www.alteredgamer.com/ - having_IPhaving_IP_Address 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - having_IPhaving_IP_Address 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - having_IPhaving_IP_Address 피처 완료
# http://www.imdb.com/Title?3682448 - having_IPhaving_IP_Address 피처 완료
# https://www.workiva.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - having_IPhaving_IP_Address 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - having_IPhaving_IP_Address 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - having_IPhaving_IP_Address 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - having_IPhaving_IP_Address 피처 완료
# http://www.motoincontroepoca.com/blog/profile/ - having_IPhaving_IP_Address 피처 완료
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - having_IPhaving_IP_Address 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - having_IPhaving_IP_Address 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - having_IPhaving_IP_Address 피처 완료
# https://www.unmannedtechshop.co.uk/ - having_IPhaving_IP_Address 피처 완료
# https://www.annabelle.com.cy - having_IPhaving_IP_Address 피처 완료
# https://www.provenancevineyards.com/ - having_IPhaving_IP_Address 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - having_IPhaving_IP_Address 피처 완료
# http://www.answers.com/Q/Digital_media_salary - having_IPhaving_IP_Address 피처 완료
# http://betasusgirsenesende.blogspot.com - having_IPhaving_IP_Address 피처 완료
# https://www.provenancevineyards.com/our-wines - having_IPhaving_IP_Address 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - having_IPhaving_IP_Address 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - having_IPhaving_IP_Address 피처 완료
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - having_IPhaving_IP_Address 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - having_IPhaving_IP_Address 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - having_IPhaving_IP_Address 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - having_IPhaving_IP_Address 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - having_IPhaving_IP_Address 피처 완료
# https://mailserver67187.uc.r.appspot.com - having_IPhaving_IP_Address 피처 완료
# http://www.astroresidential.co.uk/application/data/ - having_IPhaving_IP_Address 피처 완료
# http://www.danoday.com/hotclock/ - having_IPhaving_IP_Address 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - having_IPhaving_IP_Address 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - having_IPhaving_IP_Address 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - having_IPhaving_IP_Address 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - having_IPhaving_IP_Address 피처 완료
# http://appleid.apple.com-app.es/ - having_IPhaving_IP_Address 피처 완료
# http://www.neutralsources.com/-/re.html - having_IPhaving_IP_Address 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - having_IPhaving_IP_Address 피처 완료
# http://judithleoni.com/telecom-de/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.definitions.net/definition/compact%20disc - having_IPhaving_IP_Address 피처 완료
# http://press-preview.weebly.com - having_IPhaving_IP_Address 피처 완료
# https://www.look.com.ua/ - having_IPhaving_IP_Address 피처 완료
# https://www.facebook.com/imdbpro/ - having_IPhaving_IP_Address 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - having_IPhaving_IP_Address 피처 완료
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - having_IPhaving_IP_Address 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - having_IPhaving_IP_Address 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - having_IPhaving_IP_Address 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - having_IPhaving_IP_Address 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - having_IPhaving_IP_Address 피처 완료
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - having_IPhaving_IP_Address 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - having_IPhaving_IP_Address 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - having_IPhaving_IP_Address 피처 완료
# https://www.markspcsolution.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - having_IPhaving_IP_Address 피처 완료
# http://www.price2india.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - having_IPhaving_IP_Address 피처 완료
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - having_IPhaving_IP_Address 피처 완료
# https://scenari.software/ - having_IPhaving_IP_Address 피처 완료
# http://html.house/l7ceeid6.html - having_IPhaving_IP_Address 피처 완료
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - having_IPhaving_IP_Address 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - having_IPhaving_IP_Address 피처 완료
# http://62.234.180.243/ - having_IPhaving_IP_Address 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - having_IPhaving_IP_Address 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - having_IPhaving_IP_Address 피처 완료
# https://www.drawdown.org/ - having_IPhaving_IP_Address 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - having_IPhaving_IP_Address 피처 완료
# https://chicowhitaker.wordpress.com/ - having_IPhaving_IP_Address 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - having_IPhaving_IP_Address 피처 완료
# http://www.liveatspencer68.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - having_IPhaving_IP_Address 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - having_IPhaving_IP_Address 피처 완료
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - having_IPhaving_IP_Address 피처 완료
# http://dorkdiaries.co.uk - having_IPhaving_IP_Address 피처 완료
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - having_IPhaving_IP_Address 피처 완료
# https://www.voog.com/ - having_IPhaving_IP_Address 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - having_IPhaving_IP_Address 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - having_IPhaving_IP_Address 피처 완료
# http://netarafta.com/fresh/onedri/one/index.php - having_IPhaving_IP_Address 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - having_IPhaving_IP_Address 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - having_IPhaving_IP_Address 피처 완료
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - having_IPhaving_IP_Address 피처 완료
# http://satkom.id/img/clpds/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.cwa4501.org/ControlPanel - having_IPhaving_IP_Address 피처 완료
# https://www.discogs.com/artist/Linkin+Park - having_IPhaving_IP_Address 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - having_IPhaving_IP_Address 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - having_IPhaving_IP_Address 피처 완료
# http://icloud.com.find.support-lphone.co/ - having_IPhaving_IP_Address 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - having_IPhaving_IP_Address 피처 완료
# https://www.chiostrodelbramante.it/ - having_IPhaving_IP_Address 피처 완료
# http://cns-international2.com/r.htm - having_IPhaving_IP_Address 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - having_IPhaving_IP_Address 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - having_IPhaving_IP_Address 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - having_IPhaving_IP_Address 피처 완료
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - having_IPhaving_IP_Address 피처 완료
# https://www.gadgetzone.com.my/ - having_IPhaving_IP_Address 피처 완료
# https://www.corbaraweb.com/shop/it/ - having_IPhaving_IP_Address 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - having_IPhaving_IP_Address 피처 완료
# https://www.techlahoma.org/ - having_IPhaving_IP_Address 피처 완료
# https://apshop.vn/ - having_IPhaving_IP_Address 피처 완료
# http://www.dictionary.com/browse/traffic - having_IPhaving_IP_Address 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - having_IPhaving_IP_Address 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - having_IPhaving_IP_Address 피처 완료
# https://www.metropolitandecor.com - having_IPhaving_IP_Address 피처 완료
# http://www.helpathome.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.crestonwood.com/router.php - having_IPhaving_IP_Address 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - having_IPhaving_IP_Address 피처 완료
# http://www.wwwxjj9988.com/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.pracadarepublicaembeja.net/men - having_IPhaving_IP_Address 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - having_IPhaving_IP_Address 피처 완료
# https://vktheme.ru/auth - having_IPhaving_IP_Address 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - having_IPhaving_IP_Address 피처 완료
# http://vkaktivations23.bos.ru - having_IPhaving_IP_Address 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - having_IPhaving_IP_Address 피처 완료
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - having_IPhaving_IP_Address 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - having_IPhaving_IP_Address 피처 완료
# http://vufd.hyperphp.com/amzn - having_IPhaving_IP_Address 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - having_IPhaving_IP_Address 피처 완료
# http://p30banksoal.blogfa.com - having_IPhaving_IP_Address 피처 완료
# https://bit.ly/39vDK97 - having_IPhaving_IP_Address 피처 완료
# https://www.emploi-petrole.com/ - having_IPhaving_IP_Address 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - having_IPhaving_IP_Address 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - having_IPhaving_IP_Address 피처 완료
# http://uniteddental.ca/new/trust/db/ - having_IPhaving_IP_Address 피처 완료
# http://to-stromatadiko.gr/cache/ - having_IPhaving_IP_Address 피처 완료
# http://enerclim.com/cs/ - having_IPhaving_IP_Address 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - having_IPhaving_IP_Address 피처 완료
# http://baby-lim.com/clovvy/ - having_IPhaving_IP_Address 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - having_IPhaving_IP_Address 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - having_IPhaving_IP_Address 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - having_IPhaving_IP_Address 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - having_IPhaving_IP_Address 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - having_IPhaving_IP_Address 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - having_IPhaving_IP_Address 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - having_IPhaving_IP_Address 피처 완료
# http://67.199.68.195/intservices.htm - having_IPhaving_IP_Address 피처 완료
# http://taste-s.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.youtube.com/user/PING - having_IPhaving_IP_Address 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - having_IPhaving_IP_Address 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - having_IPhaving_IP_Address 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - having_IPhaving_IP_Address 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - having_IPhaving_IP_Address 피처 완료
# https://www.namecheap.com/domains/registration.aspx - having_IPhaving_IP_Address 피처 완료
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - having_IPhaving_IP_Address 피처 완료
# http://202.77.121.186/kliping/ - having_IPhaving_IP_Address 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - having_IPhaving_IP_Address 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - having_IPhaving_IP_Address 피처 완료
# http://www.enkiquotes.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - having_IPhaving_IP_Address 피처 완료
# http://dasisko.sk - having_IPhaving_IP_Address 피처 완료
# http://www.inquirelive.co.uk/ - having_IPhaving_IP_Address 피처 완료
# http://whatsappchat.zyns.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - having_IPhaving_IP_Address 피처 완료
# https://www.lebara.com.au/ - having_IPhaving_IP_Address 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - having_IPhaving_IP_Address 피처 완료
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - having_IPhaving_IP_Address 피처 완료
# https://hublaalikes.com/login - having_IPhaving_IP_Address 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - having_IPhaving_IP_Address 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - having_IPhaving_IP_Address 피처 완료
# https://www.chiefarchitect.com/ - having_IPhaving_IP_Address 피처 완료
# http://securityxploded.com/router-password-kracker.php - having_IPhaving_IP_Address 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - having_IPhaving_IP_Address 피처 완료
# https://www.jobchannel.ch/ - having_IPhaving_IP_Address 피처 완료
# http://maanprofessionals.nl//index.html - having_IPhaving_IP_Address 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.handshq.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.goodgame.hr/ - having_IPhaving_IP_Address 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - having_IPhaving_IP_Address 피처 완료
# http://www.ktplasmachinery.com/cs/ - having_IPhaving_IP_Address 피처 완료
# https://www.recyclingcenters.org/ - having_IPhaving_IP_Address 피처 완료
# http://mocabonitabresil.com/modules/We-Transfer/2020 - having_IPhaving_IP_Address 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - having_IPhaving_IP_Address 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - having_IPhaving_IP_Address 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - having_IPhaving_IP_Address 피처 완료
# http://elexusbettgiris4.blogspot.com - having_IPhaving_IP_Address 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - having_IPhaving_IP_Address 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://artemisbetguncel.blogspot.com - having_IPhaving_IP_Address 피처 완료
# https://www.facebook.com/savers - having_IPhaving_IP_Address 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - having_IPhaving_IP_Address 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - having_IPhaving_IP_Address 피처 완료
# http://sjec.edu.in - having_IPhaving_IP_Address 피처 완료
# http://www.nicaraguafood.org/ - having_IPhaving_IP_Address 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - having_IPhaving_IP_Address 피처 완료
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - having_IPhaving_IP_Address 피처 완료
# https://zipansion.com/3lqqn - having_IPhaving_IP_Address 피처 완료
# http://www.speedcamupdates.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - having_IPhaving_IP_Address 피처 완료
# https://norecipes.com/japanese-curry-scratch - having_IPhaving_IP_Address 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - having_IPhaving_IP_Address 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - having_IPhaving_IP_Address 피처 완료
# http://madeua.info/media/jsslider/drive/index.php - having_IPhaving_IP_Address 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - having_IPhaving_IP_Address 피처 완료
# https://www.101domain.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.hipertrofia.org/blog/ - having_IPhaving_IP_Address 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - having_IPhaving_IP_Address 피처 완료
# https://www.handlestore.com/ - having_IPhaving_IP_Address 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - having_IPhaving_IP_Address 피처 완료
# https://jamthomp.weebly.com/ - having_IPhaving_IP_Address 피처 완료
# https://itxuye.com/ - having_IPhaving_IP_Address 피처 완료
# https://polarklimatsgserver.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.srnonline.com/show-clocks - having_IPhaving_IP_Address 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - having_IPhaving_IP_Address 피처 완료
# http://www.linfo.org/osi_model.html - having_IPhaving_IP_Address 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - having_IPhaving_IP_Address 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - having_IPhaving_IP_Address 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - having_IPhaving_IP_Address 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - having_IPhaving_IP_Address 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - having_IPhaving_IP_Address 피처 완료
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - having_IPhaving_IP_Address 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - having_IPhaving_IP_Address 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - having_IPhaving_IP_Address 피처 완료
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - having_IPhaving_IP_Address 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - having_IPhaving_IP_Address 피처 완료
# https://www.blindkids.org/ - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - having_IPhaving_IP_Address 피처 완료
# https://russeprofilering.no/ - having_IPhaving_IP_Address 피처 완료
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - having_IPhaving_IP_Address 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - having_IPhaving_IP_Address 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - having_IPhaving_IP_Address 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - having_IPhaving_IP_Address 피처 완료
# http://yanddcleaning.com.au/Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae - having_IPhaving_IP_Address 피처 완료
# http://stattrek.com/statistics/dictionary.aspx?definition=standard%20error - having_IPhaving_IP_Address 피처 완료
# http://phpsecurity.readthedocs.io/en/latest/Transport-Layer-Security-(HTTPS-SSL-and-TLS).html - having_IPhaving_IP_Address 피처 완료
# http://masterhealthcaregroup.com/wp-content/uploads/Office369/cfb7a0824144625b1067e3859bb85ffc/Login.php?websrc=59c275dc2e97dd3b896ed4ff2b82a8fd&dispatched=29&id=878485762 - having_IPhaving_IP_Address 피처 완료
# http://zhanglab.ccmb.med.umich.edu/ThreaDom/ - having_IPhaving_IP_Address 피처 완료
# https://www.jacobspillow.org/ - having_IPhaving_IP_Address 피처 완료
# http://www.tech-faq.com/mms.html - having_IPhaving_IP_Address 피처 완료
# http://ethpromo-giveaway.atspace.cc/ - having_IPhaving_IP_Address 피처 완료
# https://www.cartaoitau.tk/card - having_IPhaving_IP_Address 피처 완료
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/14c06909f4e315e?cmd=_update&dispatch=14c06909f4e315e60&locale=_US - having_IPhaving_IP_Address 피처 완료
# http://www.columbusonlineauctions.com/cgi-bin/mnhistory.cgi?coa9/1 - having_IPhaving_IP_Address 피처 완료
# http://pixel.baltic-dragon.ru/kr/english%20newchn/newchn/index.php?email=john.doe@example.com - having_IPhaving_IP_Address 피처 완료
# https://plus.google.com/+vh1 - having_IPhaving_IP_Address 피처 완료
# http://xbooks.to/ - having_IPhaving_IP_Address 피처 완료
# http://pjcm.net/1122//?sec=Christiane%20Tonke - having_IPhaving_IP_Address 피처 완료
# https://auth-verifycar-information-4234723.jangansedihdandiam.com/session/?view=login&appIdKey=0c8660d5d573e3d&country=US - having_IPhaving_IP_Address 피처 완료
# https://www.shopforaurelia.com/ - having_IPhaving_IP_Address 피처 완료
# http://201.163.98.162/crm/jssource/src_files/modules/Project/home/de102cc29dbc05509b7f97227/r1.php - having_IPhaving_IP_Address 피처 완료
# https://plantsmansgardentours.com/Library/o/index.php?m=dGVzdEB0ZXN0LnBs - having_IPhaving_IP_Address 피처 완료
# http://www.novell.com/documentation/oes11/dsfw_bp_lx/ - having_IPhaving_IP_Address 피처 완료
# https://amazon.co.jp.access.usid-9452.mixh.jp/ - having_IPhaving_IP_Address 피처 완료
# http://baghira-wupperwolf.de/images/banners/bbtonline/ - having_IPhaving_IP_Address 피처 완료
# http://www.internetserviceproviders.org/in/seattle/ - having_IPhaving_IP_Address 피처 완료
# http://www.gaudi.ch/GaudiLabs/?page_id=19 - having_IPhaving_IP_Address 피처 완료
# http://www.shadetreetechnology.com/V4/validation/efbe45e31b19a2f237879c43c1825c6b - having_IPhaving_IP_Address 피처 완료
# http://union-companies.000webhostapp.com/ - having_IPhaving_IP_Address 피처 완료
# https://sura.careervidi.com/mot?fg=Z4Nwk2pibWKclbF2k29kaHd1YKCWjJyepKZdaXy0j2lj/koenig-sandra@online.de - having_IPhaving_IP_Address 피처 완료
# https://beteebetgiris.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.vogella.com/tutorials/JavaAlgorithmsDijkstra/article.html - having_IPhaving_IP_Address 피처 완료
# https://bit.ly/2E6D7J1 - having_IPhaving_IP_Address 피처 완료
# https://www.parkwhiz.com/p/new-york-parking/map/ - having_IPhaving_IP_Address 피처 완료
# http://sloaneandhyde.com/drs/new2015/document.php/index.css - having_IPhaving_IP_Address 피처 완료
# http://www.chiomegaslo.com/ - having_IPhaving_IP_Address 피처 완료
# http://chemsbury.net/scotiabank.app.chemsbury.net/mxonlineV1/leap/signon/ScotiaWeb2.php - having_IPhaving_IP_Address 피처 완료
# https://www.sevenforums.com/drivers/210625-bluetooth-peripheral-device-driver-device-unplugged-not-found.html - having_IPhaving_IP_Address 피처 완료
# http://www.imdb.com/Title?0362165 - having_IPhaving_IP_Address 피처 완료
# https://onedrive.live.com/redir?resid=10CFFC6B51DB82AC%21153&authkey=%21ALqQ7O8Z1y7c_5w&page=View&wd=target%28Quick%20Notes.one%7Ccd13eb19-aaf3-4c93-a670-061989e18e00%2FAction%20Resources%20LLC%7Cf534fab2-d680-4611-955e-a0387fdb8b59%2F%29 - having_IPhaving_IP_Address 피처 완료
# http://www.hpcfactor.com/forums/forums/thread-view.asp?tid=15430&start=1 - having_IPhaving_IP_Address 피처 완료
# https://eye-lucir.com/?d= - having_IPhaving_IP_Address 피처 완료
# http://izvilagkft.hu/wp-content/languages/.../redirect/com.htm - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/Incorporation_of_the_Bill_of_Rights - having_IPhaving_IP_Address 피처 완료
# http://login.live.com.skyhigh9157.ms-office-365-email.skyhigh9157.myshn.net/ - having_IPhaving_IP_Address 피처 완료
# http://rockysite.net/mobile/Login-Acc.php - having_IPhaving_IP_Address 피처 완료
# https://domwin-pjf2hfmn.github.io/ - having_IPhaving_IP_Address 피처 완료
# https://www.saldo.ch/ - having_IPhaving_IP_Address 피처 완료
# http://restbetgir1.blogspot.com - having_IPhaving_IP_Address 피처 완료
# http://ru.dictionarist.com/iconoclast - having_IPhaving_IP_Address 피처 완료
# https://www.123formbuilder.com/form-4850478/ - having_IPhaving_IP_Address 피처 완료
# http://www.wikihow.com/Get-a-Free-Internet-Connection - having_IPhaving_IP_Address 피처 완료
# http://www.habfurdo.com/wp-content/plugins/bbpress/home/signin/Security/myaccount/signin/ - having_IPhaving_IP_Address 피처 완료
# https://uxohd.app.link/rgofF0wPL4 - having_IPhaving_IP_Address 피처 완료
# http://www.goepsa.com/Old%20Files/yahoo/IDCHECK.html - having_IPhaving_IP_Address 피처 완료
# http://www.fingerprinting.com/fingerprint-patterns.php - having_IPhaving_IP_Address 피처 완료
# https://www.net.com.br/ - having_IPhaving_IP_Address 피처 완료
# https://docs.google.com/forms/d/e/1FAIpQLSedi778KA_QpFW-6VseK02w_qghyAY4KrmhVAHDl-qBzUQytg/viewform - having_IPhaving_IP_Address 피처 완료
# http://www.latos.co.kr/js/erusr/united/ep/meniu1.htm?theinfored=2718ad761726asdg12765asd7612jgasd87612 - having_IPhaving_IP_Address 피처 완료
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/d77722bd1cf46a12214c17ad4b362a5c - having_IPhaving_IP_Address 피처 완료
# http://techteach.no - having_IPhaving_IP_Address 피처 완료
# https://3u8kstpg-97iuu3sdu.vercel.app/ - having_IPhaving_IP_Address 피처 완료
# http://www.mutuo.it - having_IPhaving_IP_Address 피처 완료
# http://verification.slashoffers.de/ - having_IPhaving_IP_Address 피처 완료
# https://viatraniver1972.blogspot.be - having_IPhaving_IP_Address 피처 완료
# http://www.sportshub.com.sg/Directions/Documents/Sports-Hub-Traffic-Brochure.pdf - having_IPhaving_IP_Address 피처 완료
# http://rgipt.ac.in - having_IPhaving_IP_Address 피처 완료
# https://sylviamclain-my.sharepoint.com/personal/sylvia_sylviamclain_com/_layouts/15/WopiFrame.aspx?guestaccesstoken=UPb1cRnmNypLjdqQCkkArBjkN2Rlitq4OTpLJlYYSoE%3d&docid=1_1c137d9cfdf0c4518a86e6db683563e30&wdFormId=%7B79C56373%2D6E2C%2D4F1C%2D9679%2D6C47534174D5%7D&action=formsubmit - having_IPhaving_IP_Address 피처 완료
# https://www.sriexecutive.com/ - having_IPhaving_IP_Address 피처 완료
# https://docs.google.com/forms/d/e/1FAIpQLSfDwn92QVW38Ss-20KziPdDCTGi6S6IH4nAsXeQlGTvdjh4eA/closedform - having_IPhaving_IP_Address 피처 완료
# http://www.iptvlinkusa.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.alterego.gr/ - having_IPhaving_IP_Address 피처 완료
# https://www.mummyandmini.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.vegapages.com/yahoo/yahoo/ - having_IPhaving_IP_Address 피처 완료
# http://taccs.hu - having_IPhaving_IP_Address 피처 완료
# https://arquitecturamanuelmojica.com/paymnt/DocuSign/DocuSign/u.php - having_IPhaving_IP_Address 피처 완료
# https://www.ourdocuments.gov/ - having_IPhaving_IP_Address 피처 완료
# https://www.ourbaku.com/index.php/%D0%97%D0%B0%D0%B3%D0%BB%D0%B0%D0%B2%D0%BD%D0%B0%D1%8F_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86%D0%B0 - having_IPhaving_IP_Address 피처 완료
# http://www.support-appleld.com.secureupdate.duilawyeryork.com/ap/f4b262b79226ecd/?cmd=_update&dispatch=f4b262b79226ecd21&locale=_ - having_IPhaving_IP_Address 피처 완료
# http://xh167894743.el.r.appspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://raesewsart.com/esewsarlokcke/ - having_IPhaving_IP_Address 피처 완료
# http://www.artediezvirtual.es - having_IPhaving_IP_Address 피처 완료
# https://www.forbes.com/profile/tory-burch/ - having_IPhaving_IP_Address 피처 완료
# https://safirbetgiristikla.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.kia.com/cz/dealer/pemmbrno/ - having_IPhaving_IP_Address 피처 완료
# http://www.passiveaggressivehusband.com/break-up-with-a-passive-aggressive-man/ - having_IPhaving_IP_Address 피처 완료
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - having_IPhaving_IP_Address 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - having_IPhaving_IP_Address 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - having_IPhaving_IP_Address 피처 완료
# http://espace-client.net/canalsat-resiliation - having_IPhaving_IP_Address 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - having_IPhaving_IP_Address 피처 완료
# http://www.dictionary.com/browse/select-committee - having_IPhaving_IP_Address 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - having_IPhaving_IP_Address 피처 완료
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - having_IPhaving_IP_Address 피처 완료
# https://kywait.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://sniz.porn - having_IPhaving_IP_Address 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - having_IPhaving_IP_Address 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - having_IPhaving_IP_Address 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - having_IPhaving_IP_Address 피처 완료
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - having_IPhaving_IP_Address 피처 완료
# https://www.russianlovematch.com/ - having_IPhaving_IP_Address 피처 완료
# http://m.hf695.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.casinocitytimes.com/ - having_IPhaving_IP_Address 피처 완료
# https://app66560000.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - having_IPhaving_IP_Address 피처 완료
# http://toppave.com.sg - having_IPhaving_IP_Address 피처 완료
# https://bologna.babyloweb.eu/info/ - having_IPhaving_IP_Address 피처 완료
# http://twowheelcool.com/twitter.com/index759b.html - having_IPhaving_IP_Address 피처 완료
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - having_IPhaving_IP_Address 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - having_IPhaving_IP_Address 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - having_IPhaving_IP_Address 피처 완료
# https://www.eliteprospects.com/ - having_IPhaving_IP_Address 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - having_IPhaving_IP_Address 피처 완료
# https://raphaelhammoud.wordpress.com/ - having_IPhaving_IP_Address 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - having_IPhaving_IP_Address 피처 완료
# http://gov.taxclaim08.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.sammonsfinancialgroup.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - having_IPhaving_IP_Address 피처 완료
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - having_IPhaving_IP_Address 피처 완료
# http://bangla.plus - having_IPhaving_IP_Address 피처 완료
# https://www.agri85.fr/V3/admin/red.php - having_IPhaving_IP_Address 피처 완료
# http://179.185.89.94/ - having_IPhaving_IP_Address 피처 완료
# http://www.atmi.gr/ - having_IPhaving_IP_Address 피처 완료
# http://botforbyks.blogspot.ru/ - having_IPhaving_IP_Address 피처 완료
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - having_IPhaving_IP_Address 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - having_IPhaving_IP_Address 피처 완료
# http://www.abbreviations.com/term/16642 - having_IPhaving_IP_Address 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - having_IPhaving_IP_Address 피처 완료
# https://nozed-uname.firebaseapp.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - having_IPhaving_IP_Address 피처 완료
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - having_IPhaving_IP_Address 피처 완료
# https://www.smart-wiki.net/ - having_IPhaving_IP_Address 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - having_IPhaving_IP_Address 피처 완료
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - having_IPhaving_IP_Address 피처 완료
# http://energo-investment.hu - having_IPhaving_IP_Address 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - having_IPhaving_IP_Address 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - having_IPhaving_IP_Address 피처 완료
# http://www.thefreedictionary.com/select+committee - having_IPhaving_IP_Address 피처 완료
# http://barbo.sk - having_IPhaving_IP_Address 피처 완료
# http://3.ly/uja - having_IPhaving_IP_Address 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - having_IPhaving_IP_Address 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - having_IPhaving_IP_Address 피처 완료
# http://faceboook.bitballoon.com/ - having_IPhaving_IP_Address 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - having_IPhaving_IP_Address 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - having_IPhaving_IP_Address 피처 완료
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - having_IPhaving_IP_Address 피처 완료
# http://www.nakamistrad.com/aa/test.php - having_IPhaving_IP_Address 피처 완료
# http://fredwilliams.publishpath.com/system-adminstrator - having_IPhaving_IP_Address 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - having_IPhaving_IP_Address 피처 완료
# http://app66560000.blogspot.com/ - having_IPhaving_IP_Address 피처 완료
# http://pay-pal-deutschland.zxc301.com/029188 - having_IPhaving_IP_Address 피처 완료
# http://maria.sgpermata.com/Main.htm - having_IPhaving_IP_Address 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - having_IPhaving_IP_Address 피처 완료
# http://www.cnc-club.ru/forum/index.php - having_IPhaving_IP_Address 피처 완료
# http://www.geocities.ws/steamcom/ - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - having_IPhaving_IP_Address 피처 완료
# http://www.mousebreaker.com/games/clicker - having_IPhaving_IP_Address 피처 완료
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - having_IPhaving_IP_Address 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - having_IPhaving_IP_Address 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - having_IPhaving_IP_Address 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - having_IPhaving_IP_Address 피처 완료
# http://ht.ly/wPX430q3I2o - having_IPhaving_IP_Address 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - having_IPhaving_IP_Address 피처 완료
# https://en.wikipedia.org/wiki/Gateway - having_IPhaving_IP_Address 피처 완료
# http://www.minus40.info/ice/dracula-old.html - having_IPhaving_IP_Address 피처 완료
# https://www.missfiga.com/ - having_IPhaving_IP_Address 피처 완료
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - having_IPhaving_IP_Address 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - having_IPhaving_IP_Address 피처 완료
# http://www.kreport.com/tmp/ - having_IPhaving_IP_Address 피처 완료
# http://www.ghbook.ir/index.php?lang=fa - having_IPhaving_IP_Address 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - having_IPhaving_IP_Address 피처 완료
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - having_IPhaving_IP_Address 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - having_IPhaving_IP_Address 피처 완료
# http://www.personalniyhoroskop.com/ - having_IPhaving_IP_Address 피처 완료
# https://www.wordnik.com/words/blackletter - having_IPhaving_IP_Address 피처 완료
# https://www.conceptcarz.com/ - having_IPhaving_IP_Address 피처 완료
# https://sites.google.com/site/ilyasdxih - having_IPhaving_IP_Address 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - having_IPhaving_IP_Address 피처 완료
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - having_IPhaving_IP_Address 피처 완료
# http://www.calculate.co.il/ - having_IPhaving_IP_Address 피처 완료
# http://www.codeboiler.net/ - having_IPhaving_IP_Address 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - having_IPhaving_IP_Address 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - having_IPhaving_IP_Address 피처 완료
# 피처 'having_IPhaving_IP_Address' 추가 완료:
#    having_IPhaving_IP_Address
# 0                          -1
# 1                          -1
# 2                          -1
# 3                          -1
# 4                          -1

# %%
apply(df, cbf.check_favicon, 'Favicon')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Favicon 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Favicon 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c446020>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c445450>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4454e0>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf9eb90>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Favicon 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf9d3f0>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Favicon 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Favicon 피처 완료
# http://www.dictionary.com/browse/tabloid - Favicon 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Favicon 피처 완료
# http://www.thefreedictionary.com/compact+disc - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4455d0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Favicon 피처 완료
# http://vki.vipcentr.ru - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1f41f0>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - Favicon 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - Favicon 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Favicon 피처 완료
# https://www.soul-flower.com/ - Favicon 피처 완료
# http://remontka.pro/mac-address/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Favicon 피처 완료
# https://www.haciserif.com.tr/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c374310>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73ba88f70>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Favicon 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5cb580>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5cbe80>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Favicon 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Favicon 피처 완료
# https://twitter.com/mimosagrillclt - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c608d00>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 410 Client Error: Gone for url: http://www.2345daohang.com/
# http://www.2345daohang.com/ - Favicon 피처 완료
# http://bakeri-net.blogfa.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbad600>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbacf10>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Favicon 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Favicon 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Favicon 피처 완료
# http://owl.li/9KyR30pXOCN - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc0e350>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Favicon 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Favicon 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5cc340>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Favicon 피처 완료
# /content/content_based_features.py:137: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - Favicon 피처 완료
# https://www.sportsengine.com/solutions/ - Favicon 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bafdd50>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Favicon 피처 완료
# https://www.iplocation.net/mac-address - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Favicon 피처 완료
# http://www.grafikerler.org/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Favicon 피처 완료
# https://www.metal-supply.dk/ - Favicon 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Favicon 피처 완료
# https://www.facebook.com/thekeyboardcat - Favicon 피처 완료
# https://www.weightworld.se/ - Favicon 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://securkenya.com/wp-content/dh1
# http://securkenya.com/wp-content/dh1 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0738e0>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b94b760>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - Favicon 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Favicon 피처 완료
# http://signin-store-ws.frontieroption.com/ - Favicon 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - Favicon 피처 완료
# https://www.off-the-road.de/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebe800>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Favicon 피처 완료
# https://estacaoxxx.wordpress.com/ - Favicon 피처 완료
# http://www.arcanelegendsgame.com/ - Favicon 피처 완료
# https://www.ingame.de/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 503 Server Error: Service Unavailable for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b458b20>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b458f10>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Favicon 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Favicon 피처 완료
# https://www.alteredgamer.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - Favicon 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Favicon 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Favicon 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Favicon 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf093c0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Favicon 피처 완료
# Favicon HTTP Exception Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Favicon 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c3d3ca0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Favicon 피처 완료
# https://www.unmannedtechshop.co.uk/ - Favicon 피처 완료
# https://www.annabelle.com.cy - Favicon 피처 완료
# https://www.provenancevineyards.com/ - Favicon 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Favicon 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b453cd0>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Favicon 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Favicon 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Favicon 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Favicon 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c227550>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Favicon 피처 완료
# http://www.neutralsources.com/-/re.html - Favicon 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - Favicon 피처 완료
# http://press-preview.weebly.com - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c226020>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Favicon 피처 완료
# https://www.facebook.com/imdbpro/ - Favicon 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c7a5780>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Favicon 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Favicon 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Favicon 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Favicon 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c5ff160>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Favicon 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Favicon 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Favicon 피처 완료
# https://www.markspcsolution.com/ - Favicon 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - Favicon 피처 완료
# http://www.price2india.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c36cf10>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c36db70>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Favicon 피처 완료
# https://scenari.software/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Favicon 피처 완료
# Favicon HTTP Exception Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c36f040>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - Favicon 피처 완료
# https://www.drawdown.org/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - Favicon 피처 완료
# https://chicowhitaker.wordpress.com/ - Favicon 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - Favicon 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 410 Client Error: Gone for url: http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Favicon 피처 완료
# http://dorkdiaries.co.uk - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc3c040>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Favicon 피처 완료
# https://www.voog.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba895d0>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba89bd0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - Favicon 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba8b8e0>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Favicon 피처 완료
# https://www.chiostrodelbramante.it/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73beb5720>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://noithatchauau.vn/1./db/box/
# http://www.noithatchauau.vn/1./db/box/ - Favicon 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b453700>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - Favicon 피처 완료
# https://www.corbaraweb.com/shop/it/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Favicon 피처 완료
# https://www.techlahoma.org/ - Favicon 피처 완료
# https://apshop.vn/ - Favicon 피처 완료
# http://www.dictionary.com/browse/traffic - Favicon 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Favicon 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Favicon 피처 완료
# https://www.metropolitandecor.com - Favicon 피처 완료
# http://www.helpathome.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Favicon 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Favicon 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36cee0>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - Favicon 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b84e860>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Favicon 피처 완료
# http://vkaktivations23.bos.ru - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Favicon 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Favicon 피처 완료
# http://vufd.hyperphp.com/amzn - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - Favicon 피처 완료
# https://bit.ly/39vDK97 - Favicon 피처 완료
# https://www.emploi-petrole.com/ - Favicon 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - Favicon 피처 완료
# http://enerclim.com/cs/ - Favicon 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Favicon 피처 완료
# Favicon HTTP Exception Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Favicon 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Favicon 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - Favicon 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - Favicon 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - Favicon 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://gpahb8bo-hbor35zkv.vercel.app/
# https://gpahb8bo-hbor35zkv.vercel.app/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://www.laviosaviaggi.com/ver/webapps/2635a/websrc
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - Favicon 피처 완료
# Favicon HTTP Exception Error: 400 Client Error: Bad Request for url: http://67.199.68.195/intservices.htm
# http://67.199.68.195/intservices.htm - Favicon 피처 완료
# http://taste-s.blogspot.com/ - Favicon 피처 완료
# https://www.youtube.com/user/PING - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4fcf40>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - Favicon 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://tlook-off365-signin.el.r.appspot.com/
# https://tlook-off365-signin.el.r.appspot.com/ - Favicon 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - Favicon 피처 완료
# https://www.namecheap.com/domains/registration.aspx - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c083dc0>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - Favicon 피처 완료
# ...
# http://m.hf695.com/ - Favicon 피처 완료
# http://www.casinocitytimes.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://app66560000.blogspot.com/
# https://app66560000.blogspot.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 410 Client Error: Gone for url: http://useful_english.enacademic.com/76401/latency_stage
# http://useful_english.enacademic.com/76401/latency_stage - Favicon 피처 완료
# http://toppave.com.sg - Favicon 피처 완료
# https://bologna.babyloweb.eu/info/ - Favicon 피처 완료
# Favicon HTTP Exception Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Favicon 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Favicon 피처 완료
# https://www.eliteprospects.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - Favicon 피처 완료
# https://raphaelhammoud.wordpress.com/ - Favicon 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5d19c0>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Favicon 피처 완료
# https://www.sammonsfinancialgroup.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bb35090>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bb34790>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Favicon 피처 완료
# http://bangla.plus - Favicon 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bb50ac0>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - Favicon 피처 완료
# http://botforbyks.blogspot.ru/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bb50940>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Favicon 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - Favicon 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Favicon 피처 완료
# https://nozed-uname.firebaseapp.com/ - Favicon 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bba41c0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Favicon 피처 완료
# https://www.smart-wiki.net/ - Favicon 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf9e110>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Favicon 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Favicon 피처 완료
# http://energo-investment.hu - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Favicon 피처 완료
# http://www.thefreedictionary.com/select+committee - Favicon 피처 완료
# http://barbo.sk - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - Favicon 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Favicon 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - Favicon 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Favicon 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd984f0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9aef0>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bd98190>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd9af20>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd98b80>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Favicon 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - Favicon 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Favicon 피처 완료
# Favicon HTTP Exception Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c164b20>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Favicon 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Favicon 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Favicon 피처 완료
# Favicon HTTP Exception Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Favicon 피처 완료
# http://ht.ly/wPX430q3I2o - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Favicon 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Favicon 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b45a290>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Favicon 피처 완료
# Favicon HTTP Exception Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b45a290>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Favicon 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bebd9f0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Favicon 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Favicon 피처 완료
# http://www.personalniyhoroskop.com/ - Favicon 피처 완료
# https://www.wordnik.com/words/blackletter - Favicon 피처 완료
# https://www.conceptcarz.com/ - Favicon 피처 완료
# https://sites.google.com/site/ilyasdxih - Favicon 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Favicon 피처 완료
# Favicon HTTP Exception Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c081e10>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Favicon 피처 완료
# http://www.calculate.co.il/ - Favicon 피처 완료
# http://www.codeboiler.net/ - Favicon 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Favicon 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Favicon 피처 완료
# 피처 'Favicon' 추가 완료:
#    Favicon
# 0       -1
# 1        1
# 2        0
# 3        1
# 4        1

# %%
apply(df, cbf.check_request_url, 'Request_URL')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Request_URL 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Request_URL 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba32f80>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba32800>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba30100>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b99dc30>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Request_URL 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73ba30e50>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Request_URL 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Request_URL 피처 완료
# http://www.dictionary.com/browse/tabloid - Request_URL 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Request_URL 피처 완료
# http://www.thefreedictionary.com/compact+disc - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bba5cc0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Request_URL 피처 완료
# http://vki.vipcentr.ru - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73badc6d0>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - Request_URL 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - Request_URL 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Request_URL 피처 완료
# https://www.soul-flower.com/ - Request_URL 피처 완료
# http://remontka.pro/mac-address/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Request_URL 피처 완료
# https://www.haciserif.com.tr/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c457d00>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c4744c0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Request_URL 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba88fa0>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba8b760>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Request_URL 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Request_URL 피처 완료
# https://twitter.com/mimosagrillclt - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73ba88eb0>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.2345daohang.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bf08f10>, 'Connection to www.2345daohang.com timed out. (connect timeout=10)'))
# http://www.2345daohang.com/ - Request_URL 피처 완료
# http://bakeri-net.blogfa.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba8aef0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcc9390>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Request_URL 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Request_URL 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Request_URL 피처 완료
# http://owl.li/9KyR30pXOCN - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4455a0>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Request_URL 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Request_URL 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c445fc0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Request_URL 피처 완료
# /content/content_based_features.py:177: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - Request_URL 피처 완료
# https://www.sportsengine.com/solutions/ - Request_URL 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c3a6e00>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Request_URL 피처 완료
# https://www.iplocation.net/mac-address - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Request_URL 피처 완료
# http://www.grafikerler.org/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Request_URL 피처 완료
# https://www.metal-supply.dk/ - Request_URL 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Request_URL 피처 완료
# https://www.facebook.com/thekeyboardcat - Request_URL 피처 완료
# https://www.weightworld.se/ - Request_URL 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://securkenya.com/wp-content/dh1
# http://securkenya.com/wp-content/dh1 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc59480>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9dde0>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - Request_URL 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Request_URL 피처 완료
# http://signin-store-ws.frontieroption.com/ - Request_URL 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - Request_URL 피처 완료
# https://www.off-the-road.de/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0d8b20>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Request_URL 피처 완료
# https://estacaoxxx.wordpress.com/ - Request_URL 피처 완료
# http://www.arcanelegendsgame.com/ - Request_URL 피처 완료
# https://www.ingame.de/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 500 Server Error: Internal Server Error for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b9397e0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b939e70>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Request_URL 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Request_URL 피처 완료
# https://www.alteredgamer.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - Request_URL 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Request_URL 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Request_URL 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Request_URL 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba20910>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Request_URL 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b9f9570>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Request_URL 피처 완료
# https://www.unmannedtechshop.co.uk/ - Request_URL 피처 완료
# https://www.annabelle.com.cy - Request_URL 피처 완료
# https://www.provenancevineyards.com/ - Request_URL 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Request_URL 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c7005e0>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Request_URL 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Request_URL 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Request_URL 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Request_URL 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5e5270>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Request_URL 피처 완료
# http://www.neutralsources.com/-/re.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection broken: IncompleteRead(6138 bytes read, 4102 more expected)', IncompleteRead(6138 bytes read, 4102 more expected))
# https://fas.org/sgp/crs/misc/R42078.pdf - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - Request_URL 피처 완료
# http://press-preview.weebly.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c520520>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Request_URL 피처 완료
# https://www.facebook.com/imdbpro/ - Request_URL 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c168fa0>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Request_URL 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Request_URL 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Request_URL 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Request_URL 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c523cd0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Request_URL 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Request_URL 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Request_URL 피처 완료
# https://www.markspcsolution.com/ - Request_URL 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - Request_URL 피처 완료
# http://www.price2india.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf0a0e0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73ba8b460>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Request_URL 피처 완료
# https://scenari.software/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73ba8b310>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - Request_URL 피처 완료
# https://www.drawdown.org/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - Request_URL 피처 완료
# https://chicowhitaker.wordpress.com/ - Request_URL 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - Request_URL 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 410 Client Error: Gone for url: http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Request_URL 피처 완료
# http://dorkdiaries.co.uk - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0fce50>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Request_URL 피처 완료
# https://www.voog.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bad0610>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bad0580>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - Request_URL 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bad2e30>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Request_URL 피처 완료
# https://www.chiostrodelbramante.it/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb53d60>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://noithatchauau.vn/1./db/box/
# http://www.noithatchauau.vn/1./db/box/ - Request_URL 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c79ba30>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - Request_URL 피처 완료
# https://www.corbaraweb.com/shop/it/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Request_URL 피처 완료
# https://www.techlahoma.org/ - Request_URL 피처 완료
# https://apshop.vn/ - Request_URL 피처 완료
# http://www.dictionary.com/browse/traffic - Request_URL 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Request_URL 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Request_URL 피처 완료
# https://www.metropolitandecor.com - Request_URL 피처 완료
# http://www.helpathome.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Request_URL 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Request_URL 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c2cd8d0>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - Request_URL 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c3789a0>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Request_URL 피처 완료
# http://vkaktivations23.bos.ru - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Request_URL 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Request_URL 피처 완료
# http://vufd.hyperphp.com/amzn - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - Request_URL 피처 완료
# https://bit.ly/39vDK97 - Request_URL 피처 완료
# https://www.emploi-petrole.com/ - Request_URL 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - Request_URL 피처 완료
# http://enerclim.com/cs/ - Request_URL 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Request_URL 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Request_URL 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - Request_URL 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - Request_URL 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - Request_URL 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://gpahb8bo-hbor35zkv.vercel.app/
# https://gpahb8bo-hbor35zkv.vercel.app/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.laviosaviaggi.com/ver/webapps/2635a/websrc
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 400 Client Error: Bad Request for url: http://67.199.68.195/intservices.htm
# http://67.199.68.195/intservices.htm - Request_URL 피처 완료
# http://taste-s.blogspot.com/ - Request_URL 피처 완료
# https://www.youtube.com/user/PING - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf083a0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - Request_URL 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://tlook-off365-signin.el.r.appspot.com/
# https://tlook-off365-signin.el.r.appspot.com/ - Request_URL 피처 완료
# ...
# http://useful_english.enacademic.com/76401/latency_stage - Request_URL 피처 완료
# http://toppave.com.sg - Request_URL 피처 완료
# https://bologna.babyloweb.eu/info/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Request_URL 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Request_URL 피처 완료
# https://www.eliteprospects.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - Request_URL 피처 완료
# https://raphaelhammoud.wordpress.com/ - Request_URL 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59e440>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Request_URL 피처 완료
# https://www.sammonsfinancialgroup.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c1f5300>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c1f5ea0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Request_URL 피처 완료
# http://bangla.plus - Request_URL 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bb36f20>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - Request_URL 피처 완료
# http://botforbyks.blogspot.ru/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bb350f0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Request_URL 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - Request_URL 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Request_URL 피처 완료
# https://nozed-uname.firebaseapp.com/ - Request_URL 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcca9e0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Request_URL 피처 완료
# https://www.smart-wiki.net/ - Request_URL 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73baccee0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Request_URL 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Request_URL 피처 완료
# http://energo-investment.hu - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Request_URL 피처 완료
# http://www.thefreedictionary.com/select+committee - Request_URL 피처 완료
# http://barbo.sk - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - Request_URL 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Request_URL 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - Request_URL 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Request_URL 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc9cd60>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c278d90>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c2794b0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c279c60>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1affa0>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Request_URL 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - Request_URL 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b99f040>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Request_URL 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Request_URL 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Request_URL 피처 완료
# http://ht.ly/wPX430q3I2o - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Request_URL 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Request_URL 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c75b550>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c75ac80>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Request_URL 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c7a73d0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Request_URL 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Request_URL 피처 완료
# http://www.personalniyhoroskop.com/ - Request_URL 피처 완료
# https://www.wordnik.com/words/blackletter - Request_URL 피처 완료
# https://www.conceptcarz.com/ - Request_URL 피처 완료
# https://sites.google.com/site/ilyasdxih - Request_URL 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Request_URL 피처 완료
# Request_URL HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c523040>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Request_URL 피처 완료
# http://www.calculate.co.il/ - Request_URL 피처 완료
# http://www.codeboiler.net/ - Request_URL 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Request_URL 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Request_URL 피처 완료
# 피처 'Request_URL' 추가 완료:
#    Request_URL
# 0           -1
# 1           -1
# 2            1
# 3            1
# 4            1

# %%
apply(df, cbf.check_url_of_anchor, 'URL_of_Anchor')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - URL_of_Anchor 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - URL_of_Anchor 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0db820>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0d87f0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0d9ea0>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bba5f60>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - URL_of_Anchor 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bba6950>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - URL_of_Anchor 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - URL_of_Anchor 피처 완료
# http://www.dictionary.com/browse/tabloid - URL_of_Anchor 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - URL_of_Anchor 피처 완료
# http://www.thefreedictionary.com/compact+disc - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36c0d0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - URL_of_Anchor 피처 완료
# http://vki.vipcentr.ru - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c376830>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - URL_of_Anchor 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - URL_of_Anchor 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - URL_of_Anchor 피처 완료
# https://www.soul-flower.com/ - URL_of_Anchor 피처 완료
# http://remontka.pro/mac-address/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - URL_of_Anchor 피처 완료
# https://www.haciserif.com.tr/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b45ace0>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b45a890>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - URL_of_Anchor 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c273f40>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c260790>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - URL_of_Anchor 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - URL_of_Anchor 피처 완료
# https://twitter.com/mimosagrillclt - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c2616f0>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 410 Client Error: Gone for url: http://www.2345daohang.com/
# http://www.2345daohang.com/ - URL_of_Anchor 피처 완료
# http://bakeri-net.blogfa.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1477c0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c147e80>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - URL_of_Anchor 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - URL_of_Anchor 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - URL_of_Anchor 피처 완료
# http://owl.li/9KyR30pXOCN - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc7a3e0>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - URL_of_Anchor 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - URL_of_Anchor 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb44940>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - URL_of_Anchor 피처 완료
# /content/content_based_features.py:240: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - URL_of_Anchor 피처 완료
# https://www.sportsengine.com/solutions/ - URL_of_Anchor 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8578b0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - URL_of_Anchor 피처 완료
# https://www.iplocation.net/mac-address - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - URL_of_Anchor 피처 완료
# http://www.grafikerler.org/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - URL_of_Anchor 피처 완료
# https://www.metal-supply.dk/ - URL_of_Anchor 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - URL_of_Anchor 피처 완료
# https://www.facebook.com/thekeyboardcat - URL_of_Anchor 피처 완료
# https://www.weightworld.se/ - URL_of_Anchor 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='securkenya.com', port=443): Read timed out. (read timeout=10)
# http://securkenya.com/wp-content/dh1 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c339090>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c339240>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - URL_of_Anchor 피처 완료
# https://learn.sparkfun.com/tutorials/16 - URL_of_Anchor 피처 완료
# http://signin-store-ws.frontieroption.com/ - URL_of_Anchor 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - URL_of_Anchor 피처 완료
# https://www.off-the-road.de/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6023e0>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - URL_of_Anchor 피처 완료
# https://estacaoxxx.wordpress.com/ - URL_of_Anchor 피처 완료
# http://www.arcanelegendsgame.com/ - URL_of_Anchor 피처 완료
# https://www.ingame.de/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 500 Server Error: Internal Server Error for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd94130>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd94970>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - URL_of_Anchor 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - URL_of_Anchor 피처 완료
# https://www.alteredgamer.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - URL_of_Anchor 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - URL_of_Anchor 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - URL_of_Anchor 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - URL_of_Anchor 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b45a0b0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - URL_of_Anchor 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd99030>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - URL_of_Anchor 피처 완료
# https://www.unmannedtechshop.co.uk/ - URL_of_Anchor 피처 완료
# https://www.annabelle.com.cy - URL_of_Anchor 피처 완료
# https://www.provenancevineyards.com/ - URL_of_Anchor 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - URL_of_Anchor 피처 완료
# http://www.answers.com/Q/Digital_media_salary - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c103430>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - URL_of_Anchor 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - URL_of_Anchor 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - URL_of_Anchor 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - URL_of_Anchor 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3cb50>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - URL_of_Anchor 피처 완료
# http://www.neutralsources.com/-/re.html - URL_of_Anchor 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - URL_of_Anchor 피처 완료
# http://press-preview.weebly.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c5384f0>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - URL_of_Anchor 피처 완료
# https://www.facebook.com/imdbpro/ - URL_of_Anchor 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42df30>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - URL_of_Anchor 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - URL_of_Anchor 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - URL_of_Anchor 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - URL_of_Anchor 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c608220>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - URL_of_Anchor 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - URL_of_Anchor 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - URL_of_Anchor 피처 완료
# https://www.markspcsolution.com/ - URL_of_Anchor 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - URL_of_Anchor 피처 완료
# http://www.price2india.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bc3efe0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bc3f1c0>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - URL_of_Anchor 피처 완료
# https://scenari.software/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73bc3c220>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - URL_of_Anchor 피처 완료
# https://www.drawdown.org/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - URL_of_Anchor 피처 완료
# https://chicowhitaker.wordpress.com/ - URL_of_Anchor 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - URL_of_Anchor 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 410 Client Error: Gone for url: http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - URL_of_Anchor 피처 완료
# http://dorkdiaries.co.uk - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd94520>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - URL_of_Anchor 피처 완료
# https://www.voog.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c7588e0>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3fa30>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - URL_of_Anchor 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3fac0>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - URL_of_Anchor 피처 완료
# https://www.chiostrodelbramante.it/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c839900>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://noithatchauau.vn/1./db/box/
# http://www.noithatchauau.vn/1./db/box/ - URL_of_Anchor 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf99210>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - URL_of_Anchor 피처 완료
# https://www.corbaraweb.com/shop/it/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - URL_of_Anchor 피처 완료
# https://www.techlahoma.org/ - URL_of_Anchor 피처 완료
# https://apshop.vn/ - URL_of_Anchor 피처 완료
# http://www.dictionary.com/browse/traffic - URL_of_Anchor 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - URL_of_Anchor 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - URL_of_Anchor 피처 완료
# https://www.metropolitandecor.com - URL_of_Anchor 피처 완료
# http://www.helpathome.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - URL_of_Anchor 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - URL_of_Anchor 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c523160>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - URL_of_Anchor 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c082290>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - URL_of_Anchor 피처 완료
# http://vkaktivations23.bos.ru - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - URL_of_Anchor 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - URL_of_Anchor 피처 완료
# http://vufd.hyperphp.com/amzn - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - URL_of_Anchor 피처 완료
# https://bit.ly/39vDK97 - URL_of_Anchor 피처 완료
# https://www.emploi-petrole.com/ - URL_of_Anchor 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - URL_of_Anchor 피처 완료
# http://enerclim.com/cs/ - URL_of_Anchor 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - URL_of_Anchor 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - URL_of_Anchor 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - URL_of_Anchor 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - URL_of_Anchor 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - URL_of_Anchor 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://gpahb8bo-hbor35zkv.vercel.app/
# https://gpahb8bo-hbor35zkv.vercel.app/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.laviosaviaggi.com/ver/webapps/2635a/websrc
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 400 Client Error: Bad Request for url: http://67.199.68.195/intservices.htm
# http://67.199.68.195/intservices.htm - URL_of_Anchor 피처 완료
# http://taste-s.blogspot.com/ - URL_of_Anchor 피처 완료
# https://www.youtube.com/user/PING - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b8cf100>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# ...
# http://toppave.com.sg - URL_of_Anchor 피처 완료
# https://bologna.babyloweb.eu/info/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - URL_of_Anchor 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - URL_of_Anchor 피처 완료
# https://www.eliteprospects.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - URL_of_Anchor 피처 완료
# https://raphaelhammoud.wordpress.com/ - URL_of_Anchor 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebd480>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - URL_of_Anchor 피처 완료
# https://www.sammonsfinancialgroup.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c730ac0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c731330>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - URL_of_Anchor 피처 완료
# http://bangla.plus - URL_of_Anchor 피처 완료
# https://www.agri85.fr/V3/admin/red.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c731c60>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - URL_of_Anchor 피처 완료
# http://botforbyks.blogspot.ru/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b8cdcf0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - URL_of_Anchor 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - URL_of_Anchor 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - URL_of_Anchor 피처 완료
# https://nozed-uname.firebaseapp.com/ - URL_of_Anchor 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8572e0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - URL_of_Anchor 피처 완료
# https://www.smart-wiki.net/ - URL_of_Anchor 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c374ee0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - URL_of_Anchor 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - URL_of_Anchor 피처 완료
# http://energo-investment.hu - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - URL_of_Anchor 피처 완료
# http://www.thefreedictionary.com/select+committee - URL_of_Anchor 피처 완료
# http://barbo.sk - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - URL_of_Anchor 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - URL_of_Anchor 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - URL_of_Anchor 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - URL_of_Anchor 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c1593c0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c523eb0>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c5208e0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c522d70>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c520d30>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - URL_of_Anchor 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - URL_of_Anchor 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c59c9a0>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - URL_of_Anchor 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - URL_of_Anchor 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - URL_of_Anchor 피처 완료
# http://ht.ly/wPX430q3I2o - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - URL_of_Anchor 피처 완료
# https://en.wikipedia.org/wiki/Gateway - URL_of_Anchor 피처 완료
# http://www.minus40.info/ice/dracula-old.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59ce20>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bf02530>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - URL_of_Anchor 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf00400>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - URL_of_Anchor 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - URL_of_Anchor 피처 완료
# http://www.personalniyhoroskop.com/ - URL_of_Anchor 피처 완료
# https://www.wordnik.com/words/blackletter - URL_of_Anchor 피처 완료
# https://www.conceptcarz.com/ - URL_of_Anchor 피처 완료
# https://sites.google.com/site/ilyasdxih - URL_of_Anchor 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - URL_of_Anchor 피처 완료
# URL_of_Anchor HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5211e0>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - URL_of_Anchor 피처 완료
# http://www.calculate.co.il/ - URL_of_Anchor 피처 완료
# http://www.codeboiler.net/ - URL_of_Anchor 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - URL_of_Anchor 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - URL_of_Anchor 피처 완료
# 피처 'URL_of_Anchor' 추가 완료:
#    URL_of_Anchor
# 0             -1
# 1             -1
# 2              0
# 3              1
# 4              1

# %%
apply(df, cbf.has_meta_tags, 'Links_in_tags')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Links_in_tags 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Links_in_tags 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c444d00>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4464a0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c15a1d0>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c444df0>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Links_in_tags 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c444400>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Links_in_tags 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Links_in_tags 피처 완료
# http://www.dictionary.com/browse/tabloid - Links_in_tags 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Links_in_tags 피처 완료
# http://www.thefreedictionary.com/compact+disc - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c522fe0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Links_in_tags 피처 완료
# http://vki.vipcentr.ru - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c080670>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - Links_in_tags 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - Links_in_tags 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Links_in_tags 피처 완료
# https://www.soul-flower.com/ - Links_in_tags 피처 완료
# http://remontka.pro/mac-address/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Links_in_tags 피처 완료
# https://www.haciserif.com.tr/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c857c10>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c1f43d0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Links_in_tags 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c40b040>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c40b850>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Links_in_tags 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Links_in_tags 피처 완료
# https://twitter.com/mimosagrillclt - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd94b20>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 410 Client Error: Gone for url: http://www.2345daohang.com/
# http://www.2345daohang.com/ - Links_in_tags 피처 완료
# http://bakeri-net.blogfa.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebfbb0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bebf070>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Links_in_tags 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Links_in_tags 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Links_in_tags 피처 완료
# http://owl.li/9KyR30pXOCN - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c374700>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Links_in_tags 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Links_in_tags 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c447940>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Links_in_tags 피처 완료
# /content/content_based_features.py:296: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - Links_in_tags 피처 완료
# https://www.sportsengine.com/solutions/ - Links_in_tags 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf1bd0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Links_in_tags 피처 완료
# https://www.iplocation.net/mac-address - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Links_in_tags 피처 완료
# http://www.grafikerler.org/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Links_in_tags 피처 완료
# https://www.metal-supply.dk/ - Links_in_tags 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Links_in_tags 피처 완료
# https://www.facebook.com/thekeyboardcat - Links_in_tags 피처 완료
# https://www.weightworld.se/ - Links_in_tags 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://securkenya.com/wp-content/dh1
# http://securkenya.com/wp-content/dh1 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b96c550>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be9c340>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - Links_in_tags 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Links_in_tags 피처 완료
# http://signin-store-ws.frontieroption.com/ - Links_in_tags 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - Links_in_tags 피처 완료
# https://www.off-the-road.de/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c4475b0>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Links_in_tags 피처 완료
# https://estacaoxxx.wordpress.com/ - Links_in_tags 피처 완료
# http://www.arcanelegendsgame.com/ - Links_in_tags 피처 완료
# https://www.ingame.de/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 500 Server Error: Internal Server Error for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c07e1a0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c07dba0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Links_in_tags 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Links_in_tags 피처 완료
# https://www.alteredgamer.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - Links_in_tags 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Links_in_tags 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Links_in_tags 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Links_in_tags 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bba7490>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Links_in_tags 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb5fac0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Links_in_tags 피처 완료
# https://www.unmannedtechshop.co.uk/ - Links_in_tags 피처 완료
# https://www.annabelle.com.cy - Links_in_tags 피처 완료
# https://www.provenancevineyards.com/ - Links_in_tags 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Links_in_tags 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bc3eb30>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Links_in_tags 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Links_in_tags 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Links_in_tags 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Links_in_tags 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c227e50>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Links_in_tags 피처 완료
# http://www.neutralsources.com/-/re.html - Links_in_tags 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - Links_in_tags 피처 완료
# http://press-preview.weebly.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c59ce80>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Links_in_tags 피처 완료
# https://www.facebook.com/imdbpro/ - Links_in_tags 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf09780>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Links_in_tags 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Links_in_tags 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Links_in_tags 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Links_in_tags 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bdef3d0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Links_in_tags 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Links_in_tags 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Links_in_tags 피처 완료
# https://www.markspcsolution.com/ - Links_in_tags 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - Links_in_tags 피처 완료
# http://www.price2india.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf3d030>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf3d570>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Links_in_tags 피처 완료
# https://scenari.software/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c7a5750>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - Links_in_tags 피처 완료
# https://www.drawdown.org/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - Links_in_tags 피처 완료
# https://chicowhitaker.wordpress.com/ - Links_in_tags 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - Links_in_tags 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 410 Client Error: Gone for url: http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Links_in_tags 피처 완료
# http://dorkdiaries.co.uk - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c758c70>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Links_in_tags 피처 완료
# https://www.voog.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be97f10>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be97c40>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - Links_in_tags 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be947c0>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Links_in_tags 피처 완료
# https://www.chiostrodelbramante.it/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be960e0>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://noithatchauau.vn/1./db/box/
# http://www.noithatchauau.vn/1./db/box/ - Links_in_tags 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bdf4340>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - Links_in_tags 피처 완료
# https://www.corbaraweb.com/shop/it/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Links_in_tags 피처 완료
# https://www.techlahoma.org/ - Links_in_tags 피처 완료
# https://apshop.vn/ - Links_in_tags 피처 완료
# http://www.dictionary.com/browse/traffic - Links_in_tags 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Links_in_tags 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Links_in_tags 피처 완료
# https://www.metropolitandecor.com - Links_in_tags 피처 완료
# http://www.helpathome.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Links_in_tags 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Links_in_tags 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c312560>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - Links_in_tags 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b9d0f10>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Links_in_tags 피처 완료
# http://vkaktivations23.bos.ru - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Links_in_tags 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Links_in_tags 피처 완료
# http://vufd.hyperphp.com/amzn - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - Links_in_tags 피처 완료
# https://bit.ly/39vDK97 - Links_in_tags 피처 완료
# https://www.emploi-petrole.com/ - Links_in_tags 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - Links_in_tags 피처 완료
# http://enerclim.com/cs/ - Links_in_tags 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Links_in_tags 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Links_in_tags 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - Links_in_tags 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - Links_in_tags 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - Links_in_tags 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://gpahb8bo-hbor35zkv.vercel.app/
# https://gpahb8bo-hbor35zkv.vercel.app/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.laviosaviaggi.com/ver/webapps/2635a/websrc
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 400 Client Error: Bad Request for url: http://67.199.68.195/intservices.htm
# http://67.199.68.195/intservices.htm - Links_in_tags 피처 완료
# http://taste-s.blogspot.com/ - Links_in_tags 피처 완료
# https://www.youtube.com/user/PING - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59d4b0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# ...
# Links_in_tags HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Links_in_tags 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Links_in_tags 피처 완료
# https://www.eliteprospects.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - Links_in_tags 피처 완료
# https://raphaelhammoud.wordpress.com/ - Links_in_tags 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6aeb00>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Links_in_tags 피처 완료
# https://www.sammonsfinancialgroup.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b93c130>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b93ca60>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Links_in_tags 피처 완료
# http://bangla.plus - Links_in_tags 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b93d030>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - Links_in_tags 피처 완료
# http://botforbyks.blogspot.ru/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccafe0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Links_in_tags 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - Links_in_tags 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Links_in_tags 피처 완료
# https://nozed-uname.firebaseapp.com/ - Links_in_tags 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c539120>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Links_in_tags 피처 완료
# https://www.smart-wiki.net/ - Links_in_tags 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b5d19f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Links_in_tags 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Links_in_tags 피처 완료
# http://energo-investment.hu - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Links_in_tags 피처 완료
# http://www.thefreedictionary.com/select+committee - Links_in_tags 피처 완료
# http://barbo.sk - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - Links_in_tags 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Links_in_tags 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - Links_in_tags 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Links_in_tags 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c7a7d30>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbe7550>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bbe7dc0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc84850>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc84f10>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Links_in_tags 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - Links_in_tags 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c6f7e80>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Links_in_tags 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Links_in_tags 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Links_in_tags 피처 완료
# http://ht.ly/wPX430q3I2o - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Links_in_tags 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Links_in_tags 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b99c0d0>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73b459750>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Links_in_tags 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73be14fa0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Links_in_tags 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Links_in_tags 피처 완료
# http://www.personalniyhoroskop.com/ - Links_in_tags 피처 완료
# https://www.wordnik.com/words/blackletter - Links_in_tags 피처 완료
# https://www.conceptcarz.com/ - Links_in_tags 피처 완료
# https://sites.google.com/site/ilyasdxih - Links_in_tags 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bccb5e0>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Links_in_tags 피처 완료
# http://www.calculate.co.il/ - Links_in_tags 피처 완료
# http://www.codeboiler.net/ - Links_in_tags 피처 완료
# Links_in_tags HTTP 요청 Error: HTTPConnectionPool(host='www.orafaq.com', port=80): Read timed out. (read timeout=10)
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Links_in_tags 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Links_in_tags 피처 완료
# 피처 'Links_in_tags' 추가 완료:
#    Links_in_tags
# 0             -1
# 1             -1
# 2              1
# 3              1
# 4              1

# %%
apply(df, cbf.check_sfh, 'SFH')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - SFH 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - SFH 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c21d570>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c21e410>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c6aea40>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c21e530>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - SFH 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c21fa00>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - SFH 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - SFH 피처 완료
# http://www.dictionary.com/browse/tabloid - SFH 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - SFH 피처 완료
# http://www.thefreedictionary.com/compact+disc - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc7d6f0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - SFH 피처 완료
# http://vki.vipcentr.ru - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd4f9d0>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - SFH 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - SFH 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - SFH 피처 완료
# https://www.soul-flower.com/ - SFH 피처 완료
# http://remontka.pro/mac-address/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - SFH 피처 완료
# https://www.haciserif.com.tr/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd4fd00>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c130040>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - SFH 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36d210>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36d900>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - SFH 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - SFH 피처 완료
# https://twitter.com/mimosagrillclt - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c83b280>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - SFH 피처 완료
# SFH HTTP 요청 Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - SFH 피처 완료
# SFH HTTP 요청 Error: 410 Client Error: Gone for url: http://www.2345daohang.com/
# http://www.2345daohang.com/ - SFH 피처 완료
# http://bakeri-net.blogfa.com - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c36ecb0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf3c4f0>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - SFH 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - SFH 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - SFH 피처 완료
# http://owl.li/9KyR30pXOCN - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf09630>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - SFH 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - SFH 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbe7730>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - SFH 피처 완료
# /content/content_based_features.py:324: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - SFH 피처 완료
# https://www.sportsengine.com/solutions/ - SFH 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c44bf70>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - SFH 피처 완료
# https://www.iplocation.net/mac-address - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - SFH 피처 완료
# http://www.grafikerler.org/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - SFH 피처 완료
# https://www.metal-supply.dk/ - SFH 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - SFH 피처 완료
# https://www.facebook.com/thekeyboardcat - SFH 피처 완료
# https://www.weightworld.se/ - SFH 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://securkenya.com/wp-content/dh1
# http://securkenya.com/wp-content/dh1 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba30b50>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c15a290>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - SFH 피처 완료
# https://learn.sparkfun.com/tutorials/16 - SFH 피처 완료
# http://signin-store-ws.frontieroption.com/ - SFH 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - SFH 피처 완료
# https://www.off-the-road.de/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73be25d50>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - SFH 피처 완료
# https://estacaoxxx.wordpress.com/ - SFH 피처 완료
# http://www.arcanelegendsgame.com/ - SFH 피처 완료
# https://www.ingame.de/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - SFH 피처 완료
# SFH HTTP 요청 Error: 500 Server Error: Internal Server Error for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c445060>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5ea3e0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - SFH 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - SFH 피처 완료
# https://www.alteredgamer.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - SFH 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - SFH 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - SFH 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - SFH 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c10b9a0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - SFH 피처 완료
# SFH HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - SFH 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bdeaa10>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - SFH 피처 완료
# https://www.unmannedtechshop.co.uk/ - SFH 피처 완료
# https://www.annabelle.com.cy - SFH 피처 완료
# https://www.provenancevineyards.com/ - SFH 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - SFH 피처 완료
# http://www.answers.com/Q/Digital_media_salary - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c36d030>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - SFH 피처 완료
# SFH HTTP 요청 Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - SFH 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - SFH 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - SFH 피처 완료
# SFH HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - SFH 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - SFH 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c73f370>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - SFH 피처 완료
# http://www.neutralsources.com/-/re.html - SFH 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - SFH 피처 완료
# http://press-preview.weebly.com - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c2fcd90>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - SFH 피처 완료
# https://www.facebook.com/imdbpro/ - SFH 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc5ebf0>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - SFH 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - SFH 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - SFH 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - SFH 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c0d9150>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - SFH 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - SFH 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - SFH 피처 완료
# https://www.markspcsolution.com/ - SFH 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - SFH 피처 완료
# http://www.price2india.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b7d1cf0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b7d1300>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - SFH 피처 완료
# https://scenari.software/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - SFH 피처 완료
# SFH HTTP 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73b7d13c0>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - SFH 피처 완료
# https://www.drawdown.org/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - SFH 피처 완료
# https://chicowhitaker.wordpress.com/ - SFH 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - SFH 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com', port=80): Max retries exceeded with url: /update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c71c7f0>, 'Connection to www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com timed out. (connect timeout=10)'))
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - SFH 피처 완료
# http://dorkdiaries.co.uk - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c71cf10>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - SFH 피처 완료
# https://www.voog.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c71d6c0>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba48cd0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - SFH 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba48a30>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - SFH 피처 완료
# https://www.chiostrodelbramante.it/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c71fd00>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.noithatchauau.vn', port=80): Read timed out. (read timeout=10)
# http://www.noithatchauau.vn/1./db/box/ - SFH 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b806d70>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - SFH 피처 완료
# https://www.corbaraweb.com/shop/it/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - SFH 피처 완료
# https://www.techlahoma.org/ - SFH 피처 완료
# https://apshop.vn/ - SFH 피처 완료
# http://www.dictionary.com/browse/traffic - SFH 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - SFH 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - SFH 피처 완료
# https://www.metropolitandecor.com - SFH 피처 완료
# http://www.helpathome.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - SFH 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - SFH 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c06fd60>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - SFH 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c06ff10>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - SFH 피처 완료
# http://vkaktivations23.bos.ru - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - SFH 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - SFH 피처 완료
# http://vufd.hyperphp.com/amzn - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - SFH 피처 완료
# https://bit.ly/39vDK97 - SFH 피처 완료
# https://www.emploi-petrole.com/ - SFH 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - SFH 피처 완료
# http://enerclim.com/cs/ - SFH 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - SFH 피처 완료
# SFH HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - SFH 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='metalinjection.net', port=443): Read timed out. (read timeout=10)
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - SFH 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - SFH 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - SFH 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://gpahb8bo-hbor35zkv.vercel.app/
# https://gpahb8bo-hbor35zkv.vercel.app/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.laviosaviaggi.com/ver/webapps/2635a/websrc
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - SFH 피처 완료
# SFH HTTP 요청 Error: 400 Client Error: Bad Request for url: http://67.199.68.195/intservices.htm
# http://67.199.68.195/intservices.htm - SFH 피처 완료
# http://taste-s.blogspot.com/ - SFH 피처 완료
# https://www.youtube.com/user/PING - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5206d0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - SFH 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://tlook-off365-signin.el.r.appspot.com/
# https://tlook-off365-signin.el.r.appspot.com/ - SFH 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - SFH 피처 완료
# https://www.namecheap.com/domains/registration.aspx - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59f070>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73bae4190>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - SFH 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - SFH 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - SFH 피처 완료
# http://www.enkiquotes.com/ - SFH 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://dasisko.sk/
# http://dasisko.sk - SFH 피처 완료
# http://www.inquirelive.co.uk/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://whatsappchat.zyns.com/
# http://whatsappchat.zyns.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.slant.co/topics/2404/~file-managers-for-windows
# https://www.slant.co/topics/2404/~file-managers-for-windows - SFH 피처 완료
# https://www.lebara.com.au/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.roku.com/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73c15a500>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - SFH 피처 완료
# https://hublaalikes.com/login - SFH 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - SFH 피처 완료
# ...
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bcf2650>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - SFH 피처 완료
# https://www.russianlovematch.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c082e30>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.casinocitytimes.com/
# http://www.casinocitytimes.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://app66560000.blogspot.com/
# https://app66560000.blogspot.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 410 Client Error: Gone for url: http://useful_english.enacademic.com/76401/latency_stage
# http://useful_english.enacademic.com/76401/latency_stage - SFH 피처 완료
# http://toppave.com.sg - SFH 피처 완료
# https://bologna.babyloweb.eu/info/ - SFH 피처 완료
# SFH HTTP 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - SFH 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - SFH 피처 완료
# SFH HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - SFH 피처 완료
# https://www.eliteprospects.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - SFH 피처 완료
# https://raphaelhammoud.wordpress.com/ - SFH 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bae3ca0>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - SFH 피처 완료
# https://www.sammonsfinancialgroup.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c7599c0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c75b700>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - SFH 피처 완료
# http://bangla.plus - SFH 피처 완료
# https://www.agri85.fr/V3/admin/red.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c758d90>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - SFH 피처 완료
# http://botforbyks.blogspot.ru/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c07e3e0>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - SFH 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - SFH 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - SFH 피처 완료
# https://nozed-uname.firebaseapp.com/ - SFH 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3ded0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - SFH 피처 완료
# https://www.smart-wiki.net/ - SFH 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c70ad10>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - SFH 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - SFH 피처 완료
# http://energo-investment.hu - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - SFH 피처 완료
# http://www.thefreedictionary.com/select+committee - SFH 피처 완료
# http://barbo.sk - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - SFH 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - SFH 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - SFH 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - SFH 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba04970>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba0b8e0>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c238190>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba0b700>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba04e50>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - SFH 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - SFH 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - SFH 피처 완료
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c375120>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - SFH 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - SFH 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - SFH 피처 완료
# SFH HTTP 요청 Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - SFH 피처 완료
# http://ht.ly/wPX430q3I2o - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - SFH 피처 완료
# https://en.wikipedia.org/wiki/Gateway - SFH 피처 완료
# http://www.minus40.info/ice/dracula-old.html - SFH 피처 완료
# SFH HTTP 요청 Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42d420>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - SFH 피처 완료
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c42c6d0>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - SFH 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c42ffd0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - SFH 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - SFH 피처 완료
# http://www.personalniyhoroskop.com/ - SFH 피처 완료
# https://www.wordnik.com/words/blackletter - SFH 피처 완료
# https://www.conceptcarz.com/ - SFH 피처 완료
# https://sites.google.com/site/ilyasdxih - SFH 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - SFH 피처 완료
# SFH HTTP 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5e3490>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - SFH 피처 완료
# http://www.calculate.co.il/ - SFH 피처 완료
# http://www.codeboiler.net/ - SFH 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - SFH 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - SFH 피처 완료
# 피처 'SFH' 추가 완료:
#    SFH
# 0    1
# 1   -1
# 2   -1
# 3    1
# 4    1

# %%
apply(df, cbf.check_submit_email, 'Submitting_to_email')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Submitting_to_email 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Submitting_to_email 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5e0e20>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5e1ea0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-italy.www1.biz/portaleTitolares11/
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c5e1e40>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c5e29b0>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Submitting_to_email 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c3808b0>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Submitting_to_email 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://alpreco.ro/wp-content/uploads/attractionvk.html
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Submitting_to_email 피처 완료
# http://www.dictionary.com/browse/tabloid - Submitting_to_email 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Submitting_to_email 피처 완료
# http://www.thefreedictionary.com/compact+disc - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=imsly.com
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba31d50>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Submitting_to_email 피처 완료
# http://vki.vipcentr.ru - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59f8b0>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://7d54v.app.link/yEnzR6hnj8
# https://7d54v.app.link/yEnzR6hnj8 - Submitting_to_email 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: 404 Not Found for url: http://www.chinadryer.cn/pa
# http://www.chinadryer.cn/pa - Submitting_to_email 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Submitting_to_email 피처 완료
# https://www.soul-flower.com/ - Submitting_to_email 피처 완료
# http://remontka.pro/mac-address/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Submitting_to_email 피처 완료
# https://www.haciserif.com.tr/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42e290>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec773fc51b0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Submitting_to_email 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c47eb90>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c47cbb0>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Submitting_to_email 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Submitting_to_email 피처 완료
# https://twitter.com/mimosagrillclt - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bccb970>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 406 Client Error: Not Acceptable for url: http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 410 Client Error: Gone for url: http://www.2345daohang.com/
# http://www.2345daohang.com/ - Submitting_to_email 피처 완료
# http://bakeri-net.blogfa.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.littlee.com.au/alibaba/login.alibaba.com.php
# http://littlee.com.au/alibaba/login.alibaba.com.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc84cd0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc849d0>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Submitting_to_email 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Submitting_to_email 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Submitting_to_email 피처 완료
# http://owl.li/9KyR30pXOCN - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bef9510>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Submitting_to_email 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Submitting_to_email 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc85480>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Submitting_to_email 피처 완료
# /content/content_based_features.py:359: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# https://www.luxuryloft.eu/ - Submitting_to_email 피처 완료
# https://www.sportsengine.com/solutions/ - Submitting_to_email 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73ba08ac0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Submitting_to_email 피처 완료
# https://www.iplocation.net/mac-address - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.henrikssonbygg.se/libraries/legacy/log/Update/
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Submitting_to_email 피처 완료
# http://www.grafikerler.org/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Submitting_to_email 피처 완료
# https://www.metal-supply.dk/ - Submitting_to_email 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Submitting_to_email 피처 완료
# https://www.facebook.com/thekeyboardcat - Submitting_to_email 피처 완료
# https://www.weightworld.se/ - Submitting_to_email 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=myappwiz.com
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://securkenya.com/wp-content/dh1
# http://securkenya.com/wp-content/dh1 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3ec80>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://immo.numeriklabs.com/region/CA-2.0/CA/
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://www.gmfs.co.za/js/Gdocs/s/
# http://www.gmfs.co.za/js/Gdocs/s/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec773fc4fa0>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# http://sophie-world.com/games/port-and-starboard - Submitting_to_email 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Submitting_to_email 피처 완료
# http://signin-store-ws.frontieroption.com/ - Submitting_to_email 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://noreply-netelle.blogspot.com/
# https://noreply-netelle.blogspot.com/ - Submitting_to_email 피처 완료
# https://www.off-the-road.de/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73baab430>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://setaccess.webflow.io/
# http://setaccess.webflow.io/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://skilful-courage-283714.nw.r.appspot.com/home.html
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Submitting_to_email 피처 완료
# https://estacaoxxx.wordpress.com/ - Submitting_to_email 피처 완료
# http://www.arcanelegendsgame.com/ - Submitting_to_email 피처 완료
# https://www.ingame.de/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 500 Server Error: Internal Server Error for url: https://zmail221.appspot.com/
# https://zmail221.appspot.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0ece80>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c0ed630>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Submitting_to_email 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Submitting_to_email 피처 완료
# https://www.alteredgamer.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# http://www.storybookalpacas.com/account4/index2.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.imdb.com/title/tt3682448/
# http://www.imdb.com/Title?3682448 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.workiva.com/
# https://www.workiva.com/ - Submitting_to_email 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Submitting_to_email 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Submitting_to_email 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Submitting_to_email 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3caf0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Submitting_to_email 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3e3b0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Submitting_to_email 피처 완료
# https://www.unmannedtechshop.co.uk/ - Submitting_to_email 피처 완료
# https://www.annabelle.com.cy - Submitting_to_email 피처 완료
# https://www.provenancevineyards.com/ - Submitting_to_email 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Submitting_to_email 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.blogger.com/blogin.g?blogspotURL=https://betasusgirsenesende.blogspot.com/&type=blog&bpli=1
# http://betasusgirsenesende.blogspot.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# https://www.provenancevineyards.com/our-wines - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://centromusicalpaternense.es:443/wp-includes/css/
# http://centromusicalpaternense.es/wp-includes/css - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c7a4d00>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://useful-maxim-276319.uc.r.appspot.com/off365.html
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 401 Client Error: Unauthorized for url: https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Submitting_to_email 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Submitting_to_email 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# https://mailserver67187.uc.r.appspot.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# http://www.astroresidential.co.uk/application/data/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Submitting_to_email 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Submitting_to_email 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73b44f880>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Submitting_to_email 피처 완료
# http://www.neutralsources.com/-/re.html - Submitting_to_email 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://judithleoni.com/telecom-de/index.php
# http://judithleoni.com/telecom-de/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/compact%20disc
# http://www.definitions.net/definition/compact%20disc - Submitting_to_email 피처 완료
# http://press-preview.weebly.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d720>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Submitting_to_email 피처 완료
# https://www.facebook.com/imdbpro/ - Submitting_to_email 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bcf3880>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Submitting_to_email 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Submitting_to_email 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Submitting_to_email 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Submitting_to_email 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c224dc0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Submitting_to_email 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Submitting_to_email 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Submitting_to_email 피처 완료
# https://www.markspcsolution.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.biology4kids.com', port=80): Max retries exceeded with url: /files/cell2_activetran.html (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c784a00>, 'Connection to www.biology4kids.com timed out. (connect timeout=10)'))
# http://www.biology4kids.com/files/cell2_activetran.html - Submitting_to_email 피처 완료
# http://www.price2india.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c2547f0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c2550f0>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Submitting_to_email 피처 완료
# https://scenari.software/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://goldcoastships.com/daum/daum/daaum/login.php
# http://goldcoastships.com/daum/daum/daaum/login.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c255d80>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://cartetitolare-it.www1.biz/portaleTitolares15/
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://elegant-meitner-d64348.netlify.app/
# http://elegant-meitner-d64348.netlify.app/ - Submitting_to_email 피처 완료
# https://www.drawdown.org/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://genius.com/Kendrick-lamar-dna-lyrics
# https://genius.com/Kendrick-lamar-dna-lyrics - Submitting_to_email 피처 완료
# https://chicowhitaker.wordpress.com/ - Submitting_to_email 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.liveatspencer68.com/
# http://www.liveatspencer68.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.definitions.net/definition/STANDARD%20ERROR
# http://www.definitions.net/definition/STANDARD%20ERROR - Submitting_to_email 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 410 Client Error: Gone for url: http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Submitting_to_email 피처 완료
# http://dorkdiaries.co.uk - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bff9630>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Submitting_to_email 피처 완료
# https://www.voog.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://electricitypak.com/fakt/css/data/16/
# http://electricitypak.com/fakt/css/data/16/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 500 Server Error: Internal Server Error for url: http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c255180>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bff8040>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://satkom.id/img/clpds/index.php
# http://satkom.id/img/clpds/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.cwa4501.org/ControlPanel
# http://www.cwa4501.org/ControlPanel - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.discogs.com/artist/Linkin+Park
# https://www.discogs.com/artist/Linkin+Park - Submitting_to_email 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bff8490>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://morganis.com.au/secure/rawfile/index.php
# http://morganis.com.au/secure/rawfile/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Submitting_to_email 피처 완료
# https://www.chiostrodelbramante.it/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bc7d300>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://noithatchauau.vn/1./db/box/
# http://www.noithatchauau.vn/1./db/box/ - Submitting_to_email 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c539150>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.gadgetzone.com.my/
# https://www.gadgetzone.com.my/ - Submitting_to_email 피처 완료
# https://www.corbaraweb.com/shop/it/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Submitting_to_email 피처 완료
# https://www.techlahoma.org/ - Submitting_to_email 피처 완료
# https://apshop.vn/ - Submitting_to_email 피처 완료
# http://www.dictionary.com/browse/traffic - Submitting_to_email 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Submitting_to_email 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Submitting_to_email 피처 완료
# https://www.metropolitandecor.com - Submitting_to_email 피처 완료
# http://www.helpathome.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Submitting_to_email 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://woodplc-com-dot-gl494903049.wl.r.appspot.com/
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Submitting_to_email 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62cd90>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.pracadarepublicaembeja.net/men
# http://www.pracadarepublicaembeja.net/men - Submitting_to_email 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73b4598a0>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Submitting_to_email 피처 완료
# http://vkaktivations23.bos.ru - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# http://batvrms.net/deliver/D2017HL/u.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Submitting_to_email 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Submitting_to_email 피처 완료
# http://vufd.hyperphp.com/amzn - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.apkbe.com/app/com.smartprojects.ramoptimization
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://p30banksoal.blogfa.com/
# http://p30banksoal.blogfa.com - Submitting_to_email 피처 완료
# https://bit.ly/39vDK97 - Submitting_to_email 피처 완료
# https://www.emploi-petrole.com/ - Submitting_to_email 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://uniteddental.ca/new/trust/db/
# http://uniteddental.ca/new/trust/db/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://to-stromatadiko.gr/cache/
# http://to-stromatadiko.gr/cache/ - Submitting_to_email 피처 완료
# http://enerclim.com/cs/ - Submitting_to_email 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Submitting_to_email 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Submitting_to_email 피처 완료
# ...
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Submitting_to_email 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 503 Server Error: Service Unavailable for url: http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg=
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Submitting_to_email 피처 완료
# https://www.eliteprospects.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.utefilm.no/signin/lik/emailprovider/signin
# http://utefilm.no/signin/lik/emailprovider/signin/ - Submitting_to_email 피처 완료
# https://raphaelhammoud.wordpress.com/ - Submitting_to_email 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c47d810>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Submitting_to_email 피처 완료
# https://www.sammonsfinancialgroup.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bbe76d0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c6bfbe0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Submitting_to_email 피처 완료
# http://bangla.plus - Submitting_to_email 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c47d6f0>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.atmi.gr/
# http://www.atmi.gr/ - Submitting_to_email 피처 완료
# http://botforbyks.blogspot.ru/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c6bd030>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Submitting_to_email 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.abbreviations.com/term/16642
# http://www.abbreviations.com/term/16642 - Submitting_to_email 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Submitting_to_email 피처 완료
# https://nozed-uname.firebaseapp.com/ - Submitting_to_email 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c08f370>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Submitting_to_email 피처 완료
# https://www.smart-wiki.net/ - Submitting_to_email 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bfef6d0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Submitting_to_email 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Submitting_to_email 피처 완료
# http://energo-investment.hu - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Submitting_to_email 피처 완료
# http://www.thefreedictionary.com/select+committee - Submitting_to_email 피처 완료
# http://barbo.sk - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - Submitting_to_email 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Submitting_to_email 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://faceboook.netlify.app/
# http://faceboook.bitballoon.com/ - Submitting_to_email 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Submitting_to_email 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c758f70>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbe6080>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bbe75e0>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://app66560000.blogspot.com/
# http://app66560000.blogspot.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbe5c30>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bbe74f0>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Submitting_to_email 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.geocities.ws/steamcom/
# http://www.geocities.ws/steamcom/ - Submitting_to_email 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.mousebreaker.com/games/clicker
# http://www.mousebreaker.com/games/clicker - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bebf700>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Submitting_to_email 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Submitting_to_email 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 400 Client Error: Bad Request for url: http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Submitting_to_email 피처 완료
# http://ht.ly/wPX430q3I2o - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://documentos.sfo2.digitaloceanspaces.com/ordem.html
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Submitting_to_email 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Submitting_to_email 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 402 Client Error: Payment Required for url: https://missfiga.com/
# https://www.missfiga.com/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf1b760>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://www.kreport.com/tmp/
# http://www.kreport.com/tmp/ - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bae70a0>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Submitting_to_email 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c243fd0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Submitting_to_email 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Submitting_to_email 피처 완료
# http://www.personalniyhoroskop.com/ - Submitting_to_email 피처 완료
# https://www.wordnik.com/words/blackletter - Submitting_to_email 피처 완료
# https://www.conceptcarz.com/ - Submitting_to_email 피처 완료
# https://sites.google.com/site/ilyasdxih - Submitting_to_email 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Submitting_to_email 피처 완료
# Submitting_to_email 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd97610>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Submitting_to_email 피처 완료
# http://www.calculate.co.il/ - Submitting_to_email 피처 완료
# http://www.codeboiler.net/ - Submitting_to_email 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Submitting_to_email 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Submitting_to_email 피처 완료
# 피처 'Submitting_to_email' 추가 완료:
#    Submitting_to_email
# 0                   -1
# 1                   -1
# 2                   -1
# 3                    1
# 4                    1

# %%
apply(df, cbf.check_redirect_count, 'Redirect')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - Redirect 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - Redirect 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb987c0>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb987c0>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - Redirect 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb98310>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bb99d50>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - Redirect 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf9c370>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - Redirect 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - Redirect 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - Redirect 피처 완료
# http://www.dictionary.com/browse/tabloid - Redirect 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - Redirect 피처 완료
# http://www.thefreedictionary.com/compact+disc - Redirect 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9aaa0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - Redirect 피처 완료
# http://vki.vipcentr.ru - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb99510>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - Redirect 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - Redirect 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - Redirect 피처 완료
# http://www.chinadryer.cn/pa - Redirect 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - Redirect 피처 완료
# https://www.soul-flower.com/ - Redirect 피처 완료
# http://remontka.pro/mac-address/ - Redirect 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - Redirect 피처 완료
# https://www.haciserif.com.tr/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9ae30>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf9e410>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - Redirect 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9bb80>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb99e40>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - Redirect 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - Redirect 피처 완료
# https://twitter.com/mimosagrillclt - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bb9b0a0>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - Redirect 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - Redirect 피처 완료
# http://www.2345daohang.com/ - Redirect 피처 완료
# http://bakeri-net.blogfa.com - Redirect 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9f1f0>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9e650>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - Redirect 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - Redirect 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - Redirect 피처 완료
# http://owl.li/9KyR30pXOCN - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9b280>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - Redirect 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - Redirect 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9ed70>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - Redirect 피처 완료
# https://www.luxuryloft.eu/ - Redirect 피처 완료
# https://www.sportsengine.com/solutions/ - Redirect 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb994b0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - Redirect 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - Redirect 피처 완료
# https://www.iplocation.net/mac-address - Redirect 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - Redirect 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - Redirect 피처 완료
# http://www.grafikerler.org/ - Redirect 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - Redirect 피처 완료
# https://www.metal-supply.dk/ - Redirect 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - Redirect 피처 완료
# https://www.facebook.com/thekeyboardcat - Redirect 피처 완료
# https://www.weightworld.se/ - Redirect 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - Redirect 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='securkenya.com', port=443): Read timed out. (read timeout=10)
# http://securkenya.com/wp-content/dh1 - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9b0a0>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - Redirect 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - Redirect 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9ff10>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - Redirect 피처 완료
# http://sophie-world.com/games/port-and-starboard - Redirect 피처 완료
# https://learn.sparkfun.com/tutorials/16 - Redirect 피처 완료
# http://signin-store-ws.frontieroption.com/ - Redirect 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - Redirect 피처 완료
# https://noreply-netelle.blogspot.com/ - Redirect 피처 완료
# https://www.off-the-road.de/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb98a60>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - Redirect 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - Redirect 피처 완료
# http://setaccess.webflow.io/ - Redirect 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - Redirect 피처 완료
# https://estacaoxxx.wordpress.com/ - Redirect 피처 완료
# http://www.arcanelegendsgame.com/ - Redirect 피처 완료
# https://www.ingame.de/ - Redirect 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - Redirect 피처 완료
# https://zmail221.appspot.com - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb99420>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb981f0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - Redirect 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - Redirect 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - Redirect 피처 완료
# https://www.alteredgamer.com/ - Redirect 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - Redirect 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - Redirect 피처 완료
# http://www.imdb.com/Title?3682448 - Redirect 피처 완료
# https://www.workiva.com/ - Redirect 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - Redirect 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - Redirect 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - Redirect 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bb9bdf0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - Redirect 피처 완료
# Redirect 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - Redirect 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - Redirect 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf9d000>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - Redirect 피처 완료
# https://www.unmannedtechshop.co.uk/ - Redirect 피처 완료
# https://www.annabelle.com.cy - Redirect 피처 완료
# https://www.provenancevineyards.com/ - Redirect 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - Redirect 피처 완료
# http://www.answers.com/Q/Digital_media_salary - Redirect 피처 완료
# http://betasusgirsenesende.blogspot.com - Redirect 피처 완료
# https://www.provenancevineyards.com/our-wines - Redirect 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - Redirect 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62e770>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - Redirect 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - Redirect 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - Redirect 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - Redirect 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - Redirect 피처 완료
# https://mailserver67187.uc.r.appspot.com - Redirect 피처 완료
# http://www.astroresidential.co.uk/application/data/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - Redirect 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - Redirect 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - Redirect 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - Redirect 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fac0>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - Redirect 피처 완료
# http://www.neutralsources.com/-/re.html - Redirect 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - Redirect 피처 완료
# http://judithleoni.com/telecom-de/index.php - Redirect 피처 완료
# http://www.definitions.net/definition/compact%20disc - Redirect 피처 완료
# http://press-preview.weebly.com - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62fb80>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - Redirect 피처 완료
# https://www.facebook.com/imdbpro/ - Redirect 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62ec20>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - Redirect 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - Redirect 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - Redirect 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - Redirect 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - Redirect 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62cca0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - Redirect 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - Redirect 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - Redirect 피처 완료
# https://www.markspcsolution.com/ - Redirect 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - Redirect 피처 완료
# http://www.price2india.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62db40>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62e290>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - Redirect 피처 완료
# https://scenari.software/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - Redirect 피처 완료
# Redirect 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - Redirect 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c62e9e0>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - Redirect 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - Redirect 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - Redirect 피처 완료
# https://www.drawdown.org/ - Redirect 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - Redirect 피처 완료
# https://chicowhitaker.wordpress.com/ - Redirect 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - Redirect 피처 완료
# http://www.liveatspencer68.com/ - Redirect 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - Redirect 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - Redirect 피처 완료
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - Redirect 피처 완료
# http://dorkdiaries.co.uk - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fbb0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - Redirect 피처 완료
# https://www.voog.com/ - Redirect 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - Redirect 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62ee60>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - Redirect 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c3d0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - Redirect 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - Redirect 피처 완료
# http://satkom.id/img/clpds/index.php - Redirect 피처 완료
# http://www.cwa4501.org/ControlPanel - Redirect 피처 완료
# https://www.discogs.com/artist/Linkin+Park - Redirect 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - Redirect 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f220>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - Redirect 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - Redirect 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - Redirect 피처 완료
# https://www.chiostrodelbramante.it/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f8b0>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - Redirect 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - Redirect 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - Redirect 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62f1f0>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - Redirect 피처 완료
# https://www.gadgetzone.com.my/ - Redirect 피처 완료
# https://www.corbaraweb.com/shop/it/ - Redirect 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - Redirect 피처 완료
# https://www.techlahoma.org/ - Redirect 피처 완료
# https://apshop.vn/ - Redirect 피처 완료
# http://www.dictionary.com/browse/traffic - Redirect 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - Redirect 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - Redirect 피처 완료
# https://www.metropolitandecor.com - Redirect 피처 완료
# http://www.helpathome.com/ - Redirect 피처 완료
# Redirect 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - Redirect 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - Redirect 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - Redirect 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fd00>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - Redirect 피처 완료
# http://www.pracadarepublicaembeja.net/men - Redirect 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62e500>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - Redirect 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - Redirect 피처 완료
# http://vkaktivations23.bos.ru - Redirect 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - Redirect 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - Redirect 피처 완료
# http://vufd.hyperphp.com/amzn - Redirect 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - Redirect 피처 완료
# http://p30banksoal.blogfa.com - Redirect 피처 완료
# https://bit.ly/39vDK97 - Redirect 피처 완료
# https://www.emploi-petrole.com/ - Redirect 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - Redirect 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - Redirect 피처 완료
# http://uniteddental.ca/new/trust/db/ - Redirect 피처 완료
# http://to-stromatadiko.gr/cache/ - Redirect 피처 완료
# http://enerclim.com/cs/ - Redirect 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - Redirect 피처 완료
# Redirect 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - Redirect 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - Redirect 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - Redirect 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - Redirect 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - Redirect 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - Redirect 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - Redirect 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - Redirect 피처 완료
# http://67.199.68.195/intservices.htm - Redirect 피처 완료
# http://taste-s.blogspot.com/ - Redirect 피처 완료
# https://www.youtube.com/user/PING - Redirect 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62cf40>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - Redirect 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - Redirect 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - Redirect 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - Redirect 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - Redirect 피처 완료
# https://www.namecheap.com/domains/registration.aspx - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c370>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c62f2b0>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - Redirect 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - Redirect 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - Redirect 피처 완료
# http://www.enkiquotes.com/ - Redirect 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - Redirect 피처 완료
# http://dasisko.sk - Redirect 피처 완료
# http://www.inquirelive.co.uk/ - Redirect 피처 완료
# http://whatsappchat.zyns.com/ - Redirect 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - Redirect 피처 완료
# https://www.lebara.com.au/ - Redirect 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73c62f3d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - Redirect 피처 완료
# https://hublaalikes.com/login - Redirect 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - Redirect 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - Redirect 피처 완료
# https://www.chiefarchitect.com/ - Redirect 피처 완료
# http://securityxploded.com/router-password-kracker.php - Redirect 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - Redirect 피처 완료
# https://www.jobchannel.ch/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='maanprofessionals.nl', port=80): Max retries exceeded with url: /index.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e920>: Failed to resolve 'maanprofessionals.nl' ([Errno -5] No address associated with hostname)"))
# http://maanprofessionals.nl//index.html - Redirect 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - Redirect 피처 완료
# https://www.handshq.com/ - Redirect 피처 완료
# http://www.goodgame.hr/ - Redirect 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - Redirect 피처 완료
# http://www.ktplasmachinery.com/cs/ - Redirect 피처 완료
# https://www.recyclingcenters.org/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='mocabonitabresil.com', port=80): Max retries exceeded with url: /modules/We-Transfer/2020 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62ed10>: Failed to resolve 'mocabonitabresil.com' ([Errno -2] Name or service not known)"))
# http://mocabonitabresil.com/modules/We-Transfer/2020 - Redirect 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - Redirect 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - Redirect 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - Redirect 피처 완료
# http://elexusbettgiris4.blogspot.com - Redirect 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - Redirect 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - Redirect 피처 완료
# http://artemisbetguncel.blogspot.com - Redirect 피처 완료
# https://www.facebook.com/savers - Redirect 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - Redirect 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - Redirect 피처 완료
# http://sjec.edu.in - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.nicaraguafood.org', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62d8a0>: Failed to resolve 'www.nicaraguafood.org' ([Errno -2] Name or service not known)"))
# http://www.nicaraguafood.org/ - Redirect 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/aa4d130de38808b (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c400>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - Redirect 피처 완료
# https://zipansion.com/3lqqn - Redirect 피처 완료
# http://www.speedcamupdates.com/ - Redirect 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - Redirect 피처 완료
# https://norecipes.com/japanese-curry-scratch - Redirect 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - Redirect 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='madeua.info', port=80): Max retries exceeded with url: /media/jsslider/drive/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62eec0>: Failed to resolve 'madeua.info' ([Errno -2] Name or service not known)"))
# http://madeua.info/media/jsslider/drive/index.php - Redirect 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - Redirect 피처 완료
# https://www.101domain.com/ - Redirect 피처 완료
# https://www.hipertrofia.org/blog/ - Redirect 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - Redirect 피처 완료
# https://www.handlestore.com/ - Redirect 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - Redirect 피처 완료
# https://jamthomp.weebly.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='itxuye.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec73c62ecb0>, 'Connection to itxuye.com timed out. (connect timeout=10)'))
# https://itxuye.com/ - Redirect 피처 완료
# https://polarklimatsgserver.blogspot.com/ - Redirect 피처 완료
# http://www.srnonline.com/show-clocks - Redirect 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - Redirect 피처 완료
# http://www.linfo.org/osi_model.html - Redirect 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='doc.google.share.pressurecookerindia.com', port=80): Max retries exceeded with url: /clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e9b0>: Failed to resolve 'doc.google.share.pressurecookerindia.com' ([Errno -2] Name or service not known)"))
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - Redirect 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - Redirect 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - Redirect 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - Redirect 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fbb0>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - Redirect 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - Redirect 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - Redirect 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='illitrading.ro', port=80): Max retries exceeded with url: /doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62de10>: Failed to resolve 'illitrading.ro' ([Errno -2] Name or service not known)"))
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - Redirect 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - Redirect 피처 완료
# https://www.blindkids.org/ - Redirect 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - Redirect 피처 완료
# https://russeprofilering.no/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='justlookapp.com', port=80): Max retries exceeded with url: /blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f670>: Failed to resolve 'justlookapp.com' ([Errno -2] Name or service not known)"))
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - Redirect 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - Redirect 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - Redirect 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='yanddcleaning.com.au', port=443): Max retries exceeded with url: /Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://yanddcleaning.com.au/Bank%20of%20America/app/ac125f5c244313f4da59f6d8d7597aae - Redirect 피처 완료
# http://stattrek.com/statistics/dictionary.aspx?definition=standard%20error - Redirect 피처 완료
# http://phpsecurity.readthedocs.io/en/latest/Transport-Layer-Security-(HTTPS-SSL-and-TLS).html - Redirect 피처 완료
# http://masterhealthcaregroup.com/wp-content/uploads/Office369/cfb7a0824144625b1067e3859bb85ffc/Login.php?websrc=59c275dc2e97dd3b896ed4ff2b82a8fd&dispatched=29&id=878485762 - Redirect 피처 완료
# http://zhanglab.ccmb.med.umich.edu/ThreaDom/ - Redirect 피처 완료
# https://www.jacobspillow.org/ - Redirect 피처 완료
# http://www.tech-faq.com/mms.html - Redirect 피처 완료
# http://ethpromo-giveaway.atspace.cc/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.cartaoitau.tk', port=443): Max retries exceeded with url: /card (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d7e0>: Failed to resolve 'www.cartaoitau.tk' ([Errno -2] Name or service not known)"))
# https://www.cartaoitau.tk/card - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/14c06909f4e315e?cmd=_update&dispatch=14c06909f4e315e60&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d6f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/14c06909f4e315e?cmd=_update&dispatch=14c06909f4e315e60&locale=_US - Redirect 피처 완료
# http://www.columbusonlineauctions.com/cgi-bin/mnhistory.cgi?coa9/1 - Redirect 피처 완료
# ...
# Redirect 요청 Error: HTTPConnectionPool(host='www.artediezvirtual.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e1d0>: Failed to resolve 'www.artediezvirtual.es' ([Errno -2] Name or service not known)"))
# http://www.artediezvirtual.es - Redirect 피처 완료
# https://www.forbes.com/profile/tory-burch/ - Redirect 피처 완료
# https://safirbetgiristikla.blogspot.com/ - Redirect 피처 완료
# https://www.kia.com/cz/dealer/pemmbrno/ - Redirect 피처 완료
# http://www.passiveaggressivehusband.com/break-up-with-a-passive-aggressive-man/ - Redirect 피처 완료
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - Redirect 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - Redirect 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - Redirect 피처 완료
# http://espace-client.net/canalsat-resiliation - Redirect 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - Redirect 피처 완료
# http://www.dictionary.com/browse/select-committee - Redirect 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62ce80>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - Redirect 피처 완료
# https://kywait.blogspot.com/ - Redirect 피처 완료
# http://sniz.porn - Redirect 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - Redirect 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - Redirect 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62ea10>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - Redirect 피처 완료
# https://www.russianlovematch.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62ee00>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - Redirect 피처 완료
# http://www.casinocitytimes.com/ - Redirect 피처 완료
# https://app66560000.blogspot.com/ - Redirect 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - Redirect 피처 완료
# http://toppave.com.sg - Redirect 피처 완료
# https://bologna.babyloweb.eu/info/ - Redirect 피처 완료
# Redirect 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - Redirect 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - Redirect 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - Redirect 피처 완료
# https://www.eliteprospects.com/ - Redirect 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - Redirect 피처 완료
# https://raphaelhammoud.wordpress.com/ - Redirect 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fa90>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - Redirect 피처 완료
# https://www.sammonsfinancialgroup.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62d1b0>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d7e0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - Redirect 피처 완료
# http://bangla.plus - Redirect 피처 완료
# https://www.agri85.fr/V3/admin/red.php - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62dd80>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - Redirect 피처 완료
# http://www.atmi.gr/ - Redirect 피처 완료
# http://botforbyks.blogspot.ru/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d480>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - Redirect 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - Redirect 피처 완료
# http://www.abbreviations.com/term/16642 - Redirect 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - Redirect 피처 완료
# https://nozed-uname.firebaseapp.com/ - Redirect 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62ee60>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - Redirect 피처 완료
# https://www.smart-wiki.net/ - Redirect 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62eda0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - Redirect 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - Redirect 피처 완료
# http://energo-investment.hu - Redirect 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - Redirect 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - Redirect 피처 완료
# http://www.thefreedictionary.com/select+committee - Redirect 피처 완료
# http://barbo.sk - Redirect 피처 완료
# http://3.ly/uja - Redirect 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - Redirect 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - Redirect 피처 완료
# http://faceboook.bitballoon.com/ - Redirect 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - Redirect 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e6b0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f250>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec773fc4490>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - Redirect 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - Redirect 피처 완료
# http://app66560000.blogspot.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e590>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f1c0>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - Redirect 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - Redirect 피처 완료
# http://www.geocities.ws/steamcom/ - Redirect 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - Redirect 피처 완료
# http://www.mousebreaker.com/games/clicker - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62cd60>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - Redirect 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - Redirect 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - Redirect 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - Redirect 피처 완료
# http://ht.ly/wPX430q3I2o - Redirect 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - Redirect 피처 완료
# https://en.wikipedia.org/wiki/Gateway - Redirect 피처 완료
# http://www.minus40.info/ice/dracula-old.html - Redirect 피처 완료
# https://www.missfiga.com/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f8e0>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - Redirect 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - Redirect 피처 완료
# http://www.kreport.com/tmp/ - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62e9e0>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - Redirect 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - Redirect 피처 완료
# Redirect 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62e890>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - Redirect 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - Redirect 피처 완료
# http://www.personalniyhoroskop.com/ - Redirect 피처 완료
# https://www.wordnik.com/words/blackletter - Redirect 피처 완료
# https://www.conceptcarz.com/ - Redirect 피처 완료
# https://sites.google.com/site/ilyasdxih - Redirect 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - Redirect 피처 완료
# Redirect 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62cc70>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - Redirect 피처 완료
# http://www.calculate.co.il/ - Redirect 피처 완료
# http://www.codeboiler.net/ - Redirect 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - Redirect 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - Redirect 피처 완료
# 피처 'Redirect' 추가 완료:
#    Redirect
# 0         1
# 1        -1
# 2        -1
# 3         1
# 4         1

# %%
apply(df, cbf.check_onmouseover_change, 'on_mouseover')
# Out:
# http://www.wealthdaily.com/articles/nokia-stock/2147 - on_mouseover 피처 완료
# https://www.slideshare.net/gibsondaniel83/market-segmentation-targeting-and-positioning - on_mouseover 피처 완료
# http://www.game.co.uk/en/games/nintendo-switch/nintendo-switch/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='no.access', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e560>: Failed to resolve 'no.access' ([Errno -2] Name or service not known)"))
# http://www.routeralley.com/guides/nat.pdf - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.phoenixlocksmith-az.com', port=80): Max retries exceeded with url: /prole/?p%5B%5D=prole (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62cf40>: Failed to resolve 'www.phoenixlocksmith-az.com' ([Errno -2] Name or service not known)"))
# http://www.phoenixlocksmith-az.com/prole/?p[]=prole - on_mouseover 피처 완료
# http://cartetitolare-italy.www1.biz/portaleTitolares11/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='kprealtors.com', port=80): Max retries exceeded with url: /ve/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c730>: Failed to resolve 'kprealtors.com' ([Errno -5] No address associated with hostname)"))
# http://kprealtors.com/ve/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.skecherstanio.pl', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62d8d0>: Failed to resolve 'www.skecherstanio.pl' ([Errno -2] Name or service not known)"))
# https://www.skecherstanio.pl/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de', port=443): Max retries exceeded with url: /7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1007)')))
# https://7426fbe0d8676fde2cac756c0731ce57.udagwebspace.de/7e08701fe7e22e7e0b0fabe1c449c468ZjZiZDNjMmQxYTNlNWI4MmU2NzRhNjk2NWFmOWIwNTM=/signin/ - on_mouseover 피처 완료
# https://tekoma-my.sharepoint.com/:o:/g/personal/jglorie_cryonorm_com/EkKk_u3bn1pIllAzGyJIo1oBt6TRaNZ2_nrTiHKiV1tW-Q?e=ksIEcu - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='instagramnotice-security.com', port=443): Max retries exceeded with url: /username.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62dd50>: Failed to resolve 'instagramnotice-security.com' ([Errno -2] Name or service not known)"))
# https://instagramnotice-security.com/username.php - on_mouseover 피처 완료
# http://www.choose-piano-lessons.com/electronic-keyboard.html - on_mouseover 피처 완료
# http://alpreco.ro/wp-content/uploads/attractionvk.html - on_mouseover 피처 완료
# http://www.dictionary.com/browse/tabloid - on_mouseover 피처 완료
# https://www.gradschools.com/programs/graphic-design-multimedia - on_mouseover 피처 완료
# http://www.thefreedictionary.com/compact+disc - on_mouseover 피처 완료
# http://fr.imsly.com/direct/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3RyLz9pZD05MjYzMjk2OTczODk4MTcmZXY9UGl4ZWxJbml0aWFsaXplZCZkbD1odHRwJTNBJTJGJTJGZnIuYmxld3Bhc3MuY29tJTJGZGlyZWN0JTJGYUhSMGNEb3ZMM2QzZHk1bllYcDZaWFIwWVM1bmNpOC0mcmw9JmlmPWZhbHNlJnRzPTE0NjY3NDUxNzQwOTE- - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='mereliverystables.com', port=80): Max retries exceeded with url: /user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62d8a0>: Failed to resolve 'mereliverystables.com' ([Errno -2] Name or service not known)"))
# http://mereliverystables.com/user1/alibaba/alibaba.com/login.php?cmd=login_submit&amp;amp - on_mouseover 피처 완료
# http://vki.vipcentr.ru - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='hotmailsecure.brilliantbokeh.com', port=80): Max retries exceeded with url: /HotmailNEW/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62de40>: Failed to resolve 'hotmailsecure.brilliantbokeh.com' ([Errno -2] Name or service not known)"))
# http://hotmailsecure.brilliantbokeh.com/HotmailNEW/ - on_mouseover 피처 완료
# https://7d54v.app.link/yEnzR6hnj8 - on_mouseover 피처 완료
# https://www.armstronggarden.com/?SID=k11lf2097p3d8ucjusrcidcle6 - on_mouseover 피처 완료
# http://www.chinadryer.cn/pa - on_mouseover 피처 완료
# https://drive.google.com/file/d/1u7ag3FepresW0JRZehtrU5hLGGltMq6P/view?usp=sharing/ - on_mouseover 피처 완료
# https://www.soul-flower.com/ - on_mouseover 피처 완료
# http://remontka.pro/mac-address/ - on_mouseover 피처 완료
# http://logln-office365-0nline.wm.r.appspot.com/wp-content/xp.php - on_mouseover 피처 완료
# https://www.haciserif.com.tr/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.strykertoyhaulers.com', port=80): Max retries exceeded with url: /wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fc40>: Failed to resolve 'www.strykertoyhaulers.com' ([Errno -2] Name or service not known)"))
# http://www.strykertoyhaulers.com/wp-admin/js/online/order.php?email%5Cu003dabuse@euroflightinternational.com - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='myppbilling-acount.link', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c62eda0>: Failed to resolve 'myppbilling-acount.link' ([Errno -2] Name or service not known)"))
# https://myppbilling-acount.link/ - on_mouseover 피처 완료
# https://www.w3schools.com/jsreF/jsref_obj_date.asp - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62fc10>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# http://beta.kenaidanceta.com/postamok/d39a2/source - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='chat.whatsapp.com.madsuka.com', port=80): Max retries exceeded with url: /invite (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62db70>: Failed to resolve 'chat.whatsapp.com.madsuka.com' ([Errno -2] Name or service not known)"))
# http://chat.whatsapp.com.madsuka.com/invite - on_mouseover 피처 완료
# http://www.excel-easy.com/examples/shortest-path-problem.html - on_mouseover 피처 완료
# https://twitter.com/mimosagrillclt - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='frankdiekman.com', port=443): Max retries exceeded with url: /wp-content/plugins/ubb/toda/webmail.php (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bd97460>: Failed to resolve 'frankdiekman.com' ([Errno -2] Name or service not known)"))
# https://frankdiekman.com/wp-content/plugins/ubb/toda/webmail.php - on_mouseover 피처 완료
# http://poligrafiapias.com/Secured-adobe/2b078be1175659f354b82191320e7c51/ - on_mouseover 피처 완료
# http://www.2345daohang.com/ - on_mouseover 피처 완료
# http://bakeri-net.blogfa.com - on_mouseover 피처 완료
# http://littlee.com.au/alibaba/login.alibaba.com.php - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru', port=80): Max retries exceeded with url: /signin/client-log (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f550>: Failed to resolve 'https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru' ([Errno -2] Name or service not known)"))
# http://https.www.paypal.com.ttlart2012ttcysu.aylandirow.tmf.org.ru/signin/client-log - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f010>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html - on_mouseover 피처 완료
# https://security.radware.com/ddos-knowledge-center/DDoSPedia/command-and-control-server/ - on_mouseover 피처 완료
# http://www.pcsvet.si/class/0a96ada9/center-h104588/login/index.php - on_mouseover 피처 완료
# http://owl.li/9KyR30pXOCN - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='secureupdate.appleld.com.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/88b142e778d73f7 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c4c0>: Failed to resolve 'secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://secureupdate.appleld.com.duilawyeryork.com/ap/88b142e778d73f7 - on_mouseover 피처 완료
# http://wiki.openstreetmap.org/wiki/Databases_and_data_access_APIs - on_mouseover 피처 완료
# http://dic.academic.ru/dic.nsf/ruwiki/1425594 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c070>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/36de3c415ce0bab?cmd=_update&dispatch=36de3c415ce0bab6f&locale=_us - on_mouseover 피처 완료
# https://www.luxuryloft.eu/ - on_mouseover 피처 완료
# https://www.sportsengine.com/solutions/ - on_mouseover 피처 완료
# http://www.audioenglish.org/dictionary/resolution.htm - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd941c0>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# http://www.j-net.cn/cms - on_mouseover 피처 완료
# https://www.researchgate.net/publication/271074231_The_Open_Source_Modelica_Project - on_mouseover 피처 완료
# https://www.iplocation.net/mac-address - on_mouseover 피처 완료
# http://www.henrikssonbygg.se/libraries/legacy/log/Update/ - on_mouseover 피처 완료
# http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531 - on_mouseover 피처 완료
# http://www.grafikerler.org/ - on_mouseover 피처 완료
# http://secure-login-portal-outlook.el.r.appspot.com/c:/users/user/downloads - on_mouseover 피처 완료
# https://www.metal-supply.dk/ - on_mouseover 피처 완료
# http://latinasonline09.webcindario.com/app/facebook.com/?lang=de - on_mouseover 피처 완료
# https://www.facebook.com/thekeyboardcat - on_mouseover 피처 완료
# https://www.weightworld.se/ - on_mouseover 피처 완료
# http://smallbusiness.chron.com/enabling-google-chrome-menu-bar-78783.html - on_mouseover 피처 완료
# http://www.myappwiz.com/home/redirect?targetUrl=https://livraisonspeed01.cloudaccess.host/wp-includes/DHMF0JCT17E1 - on_mouseover 피처 완료
# http://securkenya.com/wp-content/dh1 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='nagari.or.id', port=80): Max retries exceeded with url: /admin/crypt/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62caf0>: Failed to resolve 'nagari.or.id' ([Errno -2] Name or service not known)"))
# http://nagari.or.id/admin/crypt/ - on_mouseover 피처 완료
# https://immo.numeriklabs.com/region/CA-2.0/CA/ - on_mouseover 피처 완료
# http://www.gmfs.co.za/js/Gdocs/s/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='servicepaypal.serveirc.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f550>: Failed to resolve 'servicepaypal.serveirc.com' ([Errno -5] No address associated with hostname)"))
# http://servicepaypal.serveirc.com/ - on_mouseover 피처 완료
# http://sophie-world.com/games/port-and-starboard - on_mouseover 피처 완료
# https://learn.sparkfun.com/tutorials/16 - on_mouseover 피처 완료
# http://signin-store-ws.frontieroption.com/ - on_mouseover 피처 완료
# https://www.ablebits.com/office-addins-blog/2014/05/15/excel-insert-hyperlink/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: /?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/login.php?cmd=login_submit&amp;id=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8&amp;session=a699d331b0c43888ac3ced2190693fc8a699d331b0c43888ac3ced2190693fc8 - on_mouseover 피처 완료
# https://noreply-netelle.blogspot.com/ - on_mouseover 피처 완료
# https://www.off-the-road.de/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.shellyfergusonphotography.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd95840>: Failed to resolve 'www.shellyfergusonphotography.com' ([Errno -2] Name or service not known)"))
# http://www.shellyfergusonphotography.com - on_mouseover 피처 완료
# http://www.inbioma.pe/rechnung-376440790464490488&amp;cgi3-viewkontakt-376440790464490488-007acctpagetype-376440790464490488=4674720-&amp;info@s-und-s-shop.de.html - on_mouseover 피처 완료
# http://setaccess.webflow.io/ - on_mouseover 피처 완료
# http://skilful-courage-283714.nw.r.appspot.com/home.html - on_mouseover 피처 완료
# https://estacaoxxx.wordpress.com/ - on_mouseover 피처 완료
# http://www.arcanelegendsgame.com/ - on_mouseover 피처 완료
# https://www.ingame.de/ - on_mouseover 피처 완료
# https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/ - on_mouseover 피처 완료
# https://zmail221.appspot.com - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c850>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/581d6deb2e3e91e?cmd=_update&dispatch=581d6deb2e3e91efc&locale=_US - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='transcript.login.2016.getwetusa.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62d2d0>: Failed to resolve 'transcript.login.2016.getwetusa.com' ([Errno -2] Name or service not known)"))
# http://transcript.login.2016.getwetusa.com/ - on_mouseover 피처 완료
# https://www.evostore.com.np/IhrFall63417798752737518&cgi3-ViewKontakt-63417798752737518-007acctpagetype-63417798752737518=68119-problema&info@hoehne-buero.de.html&amp;data=02%7C01%7C%7C179ae50e4c144e3c228508d8170b3349%7C46326bff992841a0baca17c16c94ea99%7C0%7C0%7C637284684151373360&amp;sdata=T2/xt2zovdHmhQ/iQnm9NKstPU%206hPnRkQ4MGebgKZc=&amp - on_mouseover 피처 완료
# https://www.lifewire.com/free-memory-test-programs-2626178 - on_mouseover 피처 완료
# https://www.alteredgamer.com/ - on_mouseover 피처 완료
# http://phan.thuchao.free.fr/Hao/YouTube/ba.htm - on_mouseover 피처 완료
# http://www.storybookalpacas.com/account4/index2.html - on_mouseover 피처 완료
# http://www.imdb.com/Title?3682448 - on_mouseover 피처 완료
# https://www.workiva.com/ - on_mouseover 피처 완료
# https://www.internetslang.com/DNA-meaning-definition.asp - on_mouseover 피처 완료
# https://storage.cloud.google.com/prprhrhprc.appspot.com/index.htm#oncall-infra@eqiom.com - on_mouseover 피처 완료
# https://visitor.constantcontact.com/manage/update/genemail?v=001MDKVK-KV0oGx0m9pen7VfbkCi3JbQH6CxWt2KJR3Sl7ocoW5oVQfUoZzmwKGQRldBj3DIQx_njBG0dZpWmiUe3pcjeVlJWx69PrGVPLH5iJhUKaVM_65A10roateFGYI76L1_HFN7Js= - on_mouseover 피처 완료
# http://www.matrixlab-examples.com/line-segment.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62e500>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# http://www.motoincontroepoca.com/blog/profile/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://northstaradvisorygroup.com/att/sbc/sbc/sbcglobal.net.htm - on_mouseover 피처 완료
# https://groupmatrix-my.sharepoint.com/:b:/p/corey/ET6Ze1x7jpFDrDsE7epkx0QBw6CjjBu7eoewNkWP0Ho3mQ?e=Ql2oJS - on_mouseover 피처 완료
# http://shadetreetechnology.com/V4/validation/a111aedc8ae390eabcfa130e041a10a4 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62c850>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/61e468041e8a43b?cmd=_update&dispatch=61e468041e8a43b31&locale=_US - on_mouseover 피처 완료
# https://www.unmannedtechshop.co.uk/ - on_mouseover 피처 완료
# https://www.annabelle.com.cy - on_mouseover 피처 완료
# https://www.provenancevineyards.com/ - on_mouseover 피처 완료
# http://careers.stateuniversity.com/pages/100000947/Search-Engines-Future-User-Preferences-Artificial-Intelligence.html - on_mouseover 피처 완료
# http://www.answers.com/Q/Digital_media_salary - on_mouseover 피처 완료
# http://betasusgirsenesende.blogspot.com - on_mouseover 피처 완료
# https://www.provenancevineyards.com/our-wines - on_mouseover 피처 완료
# http://sharedpont77wwjxjx.df.r.appspot.com/wp-content/xp.php - on_mouseover 피처 완료
# http://centromusicalpaternense.es/wp-includes/css - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='103.75.1.198', port=80): Max retries exceeded with url: /ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c62e9e0>, 'Connection to 103.75.1.198 timed out. (connect timeout=10)'))
# http://103.75.1.198/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&openid.identity=http://specs.openid.net/auth/2.0/identifier_select&openid.assoc_handle=jpflex&openid.mode=checkid_setup&key=a@b.c&openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&openid.ns=http://specs.openid.net/auth/2.0&&ref_=nav_em_hd_clc_signin - on_mouseover 피처 완료
# https://useful-maxim-276319.uc.r.appspot.com/off365.html - on_mouseover 피처 완료
# https://drive.google.com/file/d/1_GGqmQXcOYjJZfvgg44cX-sWuaue8EdJ/edit - on_mouseover 피처 완료
# http://www.wikihow.com/Set-Up-a-Wireless-Router - on_mouseover 피처 완료
# http://computer.howstuffworks.com/bittorrent1.htm - on_mouseover 피처 완료
# https://mailserver67187.uc.r.appspot.com - on_mouseover 피처 완료
# http://www.astroresidential.co.uk/application/data/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='store.danoday.com', port=443): Max retries exceeded with url: /radio-hotclock/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://www.danoday.com/hotclock/ - on_mouseover 피처 완료
# https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA - on_mouseover 피처 완료
# https://www.iconfinder.com/icons/858729/computer_mouse_icon_computer_mouse_line_icon_mouse_mouse_icon_mouse_line_icon_icon - on_mouseover 피처 완료
# http://shadetreetechnology.com/V4/validation/99b5ee93abab802d934d4abaacfbbab6 - on_mouseover 피처 완료
# http://98.126.214.77/ap/signin?openid.pape.max_auth_age=0&amp;openid.return_to=https://www.amazon.co.jp/?ref_=nav_em_hd_re_signin&amp;openid.identity=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.assoc_handle=jpflex&amp;openid.mode=checkid_setup&amp;key=a@b.c&amp;openid.claimed_id=http://specs.openid.net/auth/2.0/identifier_select&amp;openid.ns=http://specs.openid.net/auth/2.0&amp;&amp;ref_=nav_em_hd_clc_signin - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='appleid.apple.com-app.es', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c62f0d0>: Failed to resolve 'appleid.apple.com-app.es' ([Errno -2] Name or service not known)"))
# http://appleid.apple.com-app.es/ - on_mouseover 피처 완료
# http://www.neutralsources.com/-/re.html - on_mouseover 피처 완료
# https://fas.org/sgp/crs/misc/R42078.pdf - on_mouseover 피처 완료
# http://judithleoni.com/telecom-de/index.php - on_mouseover 피처 완료
# http://www.definitions.net/definition/compact%20disc - on_mouseover 피처 완료
# http://press-preview.weebly.com - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.look.com.ua', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf01b70>: Failed to resolve 'www.look.com.ua' ([Errno -2] Name or service not known)"))
# https://www.look.com.ua/ - on_mouseover 피처 완료
# https://www.facebook.com/imdbpro/ - on_mouseover 피처 완료
# https://www.onecklace.com/fingerprint-jewelry/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='dick-of.cubehost.ru', port=80): Max retries exceeded with url: /archive/2015/1.php?n=25&id=128520 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf037f0>: Failed to resolve 'dick-of.cubehost.ru' ([Errno -2] Name or service not known)"))
# http://dick-of.cubehost.ru/archive/2015/1.php?n=25&id=128520 - on_mouseover 피처 완료
# http://www.mathsisfun.com/geometry/symbols.html - on_mouseover 피처 완료
# http://mlcrosoft-0nedrive-portal.el.r.appspot.com/favicon.ico - on_mouseover 피처 완료
# http://techland.time.com/2011/03/15/south-by-southwest-interactive-the-dawn-of-location-based-gaming/ - on_mouseover 피처 완료
# https://en.wikipedia.org/wiki/NIC_Bank - on_mouseover 피처 완료
# https://sites.google.com/view/dealsd/home?fbclid=IwAR2JJYu14sqA2gp31cX8lhEKvYkF-8EC51J4YYyOzXh25AaPmeKesPgd9dg - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c59e3b0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/ee636eeb7669742/?cmd=_update&dispatch=ee636eeb76697424b&locale=_ - on_mouseover 피처 완료
# http://www.brighthub.com/electronics/home-theater/articles/111893.aspx - on_mouseover 피처 완료
# http://www.scancity.am/tmp/ibxolb/ibxolb/login/index-html/login/ - on_mouseover 피처 완료
# https://www.markspcsolution.com/ - on_mouseover 피처 완료
# http://www.biology4kids.com/files/cell2_activetran.html - on_mouseover 피처 완료
# http://www.price2india.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.secureupdate.appleld.com.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf00bb0>: Failed to resolve 'www.secureupdate.appleld.com.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://www.secureupdate.appleld.com.duilawyeryork.com/ap/152754cc0f88cd0/?cmd=_update&dispatch=152754cc0f88cd081&locale=_US - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='sure.eligulinsaat.com', port=443): Max retries exceeded with url: /tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c59d870>: Failed to resolve 'sure.eligulinsaat.com' ([Errno -2] Name or service not known)"))
# https://sure.eligulinsaat.com/tz?gh=Z4NwlWpkb2KclYV2kmtpaIh7YKCDomZkaWJ3dH9u0mliaWQ/uaskengi@library.usask.ca - on_mouseover 피처 완료
# https://scenari.software/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='html.house', port=443): Max retries exceeded with url: /l7ceeid6.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# http://html.house/l7ceeid6.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# http://mno.naomigoff.com/Apollo/bc28a52c2070ca93176244f59e1f19c6 - on_mouseover 피처 완료
# http://goldcoastships.com/daum/daum/daaum/login.php - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='62.234.180.243', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73bf00550>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://62.234.180.243/ - on_mouseover 피처 완료
# http://cartetitolare-it.www1.biz/portaleTitolares15/ - on_mouseover 피처 완료
# http://elegant-meitner-d64348.netlify.app/ - on_mouseover 피처 완료
# https://www.drawdown.org/ - on_mouseover 피처 완료
# https://genius.com/Kendrick-lamar-dna-lyrics - on_mouseover 피처 완료
# https://chicowhitaker.wordpress.com/ - on_mouseover 피처 완료
# https://forums.geforce.com/default/topic/844027/?comment=4759331 - on_mouseover 피처 완료
# http://www.liveatspencer68.com/ - on_mouseover 피처 완료
# http://www.definitions.net/definition/STANDARD%20ERROR - on_mouseover 피처 완료
# http://animaldiversity.org/accounts/Mus_musculus/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com', port=80): Max retries exceeded with url: /update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73bf00070>, 'Connection to www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com timed out. (connect timeout=10)'))
# http://www.paypal.com.fr.cgi.bin.webscr.cmd.flow.session.ycwnzphbcryskgq9zzetmzxi8zg51bfu4zhgnlq2wntjgx8jlj7gdispatch.c70bbe4152786147242b0tb71efa252acz.waterdamagerestorationhouston.com/update/Tmpjd09UUXdOVGcxT1RBPQ%3D%3D/erreur.htm?cmd=_error_login-run&amp;disp - on_mouseover 피처 완료
# http://dorkdiaries.co.uk - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59d570>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1/?sec=Wolfgang%20Meyerle - on_mouseover 피처 완료
# https://www.voog.com/ - on_mouseover 피처 완료
# http://electricitypak.com/fakt/css/data/16/index.php - on_mouseover 피처 완료
# http://20759379-1808-4ca1-8f3a-3923cb555671.htmlcomponentservice.com/get_draft?id=96c871_39d1eee16c26eff7fabe1ba646529cb6.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='netarafta.com', port=80): Max retries exceeded with url: /fresh/onedri/one/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf003d0>: Failed to resolve 'netarafta.com' ([Errno -2] Name or service not known)"))
# http://netarafta.com/fresh/onedri/one/index.php - on_mouseover 피처 완료
# http://interimmanagement.uk.com/wp-includes/js/chronopost.fr/suivi/accueil/infos/ifram2.php?Code_Smserror_tapnovcodeSms - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf02620>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/bb14d7ff1fcbf29?cmd=_update&dispatch=bb14d7ff1fcbf29bb&locale=_us - on_mouseover 피처 완료
# http://www.extremetech.com/computing/179066-what-is-mesh-networking-and-why-apples-adoption-in-ios-7-could-change-the-world - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.bgcdecatur.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.bgcdecatur.com'. (_ssl.c:1007)")))
# http://www.decaturilbgc.com/ckeditor/themes/default/plwestern.ph.com/citingwast/welcome/welcome/step3.php - on_mouseover 피처 완료
# http://satkom.id/img/clpds/index.php - on_mouseover 피처 완료
# http://www.cwa4501.org/ControlPanel - on_mouseover 피처 완료
# https://www.discogs.com/artist/Linkin+Park - on_mouseover 피처 완료
# https://storage.cloud.google.com/user517497679326978.appspot.com/index.html#samsnow@tjsnow.com - on_mouseover 피처 완료
# https://www.ghacks.net/2010/04/13/setting-up-a-content-delivery-network-in-wordpress/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='icloud.com.find.support-lphone.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf03d00>: Failed to resolve 'icloud.com.find.support-lphone.co' ([Errno -2] Name or service not known)"))
# http://icloud.com.find.support-lphone.co/ - on_mouseover 피처 완료
# http://morganis.com.au/secure/rawfile/index.php - on_mouseover 피처 완료
# http://www.nairaland.com/1208097/meet-cnn-internationals-anchors-reporters - on_mouseover 피처 완료
# https://www.chiostrodelbramante.it/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='cns-international2.com', port=80): Max retries exceeded with url: /r.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf02d10>: Failed to resolve 'cns-international2.com' ([Errno -2] Name or service not known)"))
# http://cns-international2.com/r.htm - on_mouseover 피처 완료
# http://jeticdesigns.asia/wp-includes/js/tinymce/plugins/hr/content/update/webmail.php - on_mouseover 피처 완료
# http://www.noithatchauau.vn/1./db/box/ - on_mouseover 피처 완료
# https://www.computerhope.com/jargon/p/paraport.htm - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='magalu-crediarioluiza.com', port=443): Max retries exceeded with url: /Produto_20203/produto.php?sku=1962067 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf03f10>: Failed to resolve 'magalu-crediarioluiza.com' ([Errno -2] Name or service not known)"))
# https://magalu-crediarioluiza.com/Produto_20203/produto.php?sku=1962067 - on_mouseover 피처 완료
# https://www.gadgetzone.com.my/ - on_mouseover 피처 완료
# https://www.corbaraweb.com/shop/it/ - on_mouseover 피처 완료
# http://photographyspark.com/search-engine-optimization-for-photographers-seo-basics/ - on_mouseover 피처 완료
# https://www.techlahoma.org/ - on_mouseover 피처 완료
# https://apshop.vn/ - on_mouseover 피처 완료
# http://www.dictionary.com/browse/traffic - on_mouseover 피처 완료
# http://creditiperhabbogratissicuro100.blogspot.it/2011/02/habbo-crediti-gratis-sicuro-100.html - on_mouseover 피처 완료
# https://www.coursera.org/learn/algorithms-npcomplete - on_mouseover 피처 완료
# https://www.metropolitandecor.com - on_mouseover 피처 완료
# http://www.helpathome.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://www.crestonwood.com/router.php - on_mouseover 피처 완료
# https://vostbaddleschoi1973.blogspot.com/ - on_mouseover 피처 완료
# https://woodplc-com-dot-gl494903049.wl.r.appspot.com/ - on_mouseover 피처 완료
# http://computerbla3.blogspot.ru/2010/02/cd-rom.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.wwwxjj9988.com', port=80): Max retries exceeded with url: /index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c59dff0>: Failed to resolve 'www.wwwxjj9988.com' ([Errno -2] Name or service not known)"))
# http://www.wwwxjj9988.com/index.php - on_mouseover 피처 완료
# http://www.pracadarepublicaembeja.net/men - on_mouseover 피처 완료
# http://en.academic.ru/dic.nsf/enwiki/189565 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='vktheme.ru', port=443): Max retries exceeded with url: /auth (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73bf01f30>: Failed to resolve 'vktheme.ru' ([Errno -2] Name or service not known)"))
# https://vktheme.ru/auth - on_mouseover 피처 완료
# http://www.iracing.com/tracks/gateway-motorsports-park/ - on_mouseover 피처 완료
# http://vkaktivations23.bos.ru - on_mouseover 피처 완료
# http://batvrms.net/deliver/D2017HL/u.php - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.zerodollartips.com', port=443): Max retries exceeded with url: /best-search-engines-in-the-world/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.zerodollartips.com'. (_ssl.c:1007)")))
# http://www.zerodollartips.com/best-search-engines-in-the-world/ - on_mouseover 피처 완료
# https://www.astrologyonline.eu/Astro_MemoNew/Profilo.asp - on_mouseover 피처 완료
# http://vufd.hyperphp.com/amzn - on_mouseover 피처 완료
# http://www.apkhere.com/app/com.smartprojects.ramoptimization - on_mouseover 피처 완료
# http://p30banksoal.blogfa.com - on_mouseover 피처 완료
# https://bit.ly/39vDK97 - on_mouseover 피처 완료
# https://www.emploi-petrole.com/ - on_mouseover 피처 완료
# https://netorgft754307-my.sharepoint.com/:b:/g/personal/shelley_collegeadvisorsne_com/ETeAXwoP0Z9HqUfODpU5UJ8BmF7CVxm8NQun0hSVoB71yA - on_mouseover 피처 완료
# http://utrackafrica.com/administrator/help/en-GB/activation.php?email=abuse@domain.com - on_mouseover 피처 완료
# http://uniteddental.ca/new/trust/db/ - on_mouseover 피처 완료
# http://to-stromatadiko.gr/cache/ - on_mouseover 피처 완료
# http://enerclim.com/cs/ - on_mouseover 피처 완료
# http://www.history.com/topics/american-civil-war/gettysburg-address - on_mouseover 피처 완료
# on_mouseover 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://baby-lim.com/clovvy/ - on_mouseover 피처 완료
# https://www.gilderlehrman.org/sites/default/files/inline-pdfs/Gettysburg%20Address%20Analysis.pdf - on_mouseover 피처 완료
# http://www.metalinjection.net/reviews/album-review-lord-mantis-death-mask - on_mouseover 피처 완료
# https://www.quora.com/Where-can-I-find-the-Click-Through-Rate-CTR-industry-standards-for-healthcare-search-advertising-as-well-as-other-digital-averages - on_mouseover 피처 완료
# http://www.wikireality.ru/wiki/Keyboard_Cat - on_mouseover 피처 완료
# http://hello-d4cdd.firebaseapp.com/ - on_mouseover 피처 완료
# https://gpahb8bo-hbor35zkv.vercel.app/ - on_mouseover 피처 완료
# http://www.laviosaviaggi.com/ver/webapps/2635a/websrc - on_mouseover 피처 완료
# http://67.199.68.195/intservices.htm - on_mouseover 피처 완료
# http://taste-s.blogspot.com/ - on_mouseover 피처 완료
# https://www.youtube.com/user/PING - on_mouseover 피처 완료
# https://oki.si/pkginfo/change/sitekeyverification.php?origin=cob&check=yes&destination=authentication - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/78816aad8eccc21 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bf031f0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/78816aad8eccc21 - on_mouseover 피처 완료
# http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/ - on_mouseover 피처 완료
# https://tlook-off365-signin.el.r.appspot.com/ - on_mouseover 피처 완료
# http://grouper.ieee.org/groups/802/3/10G_study/public/july99/azadet_1_0799.pdf - on_mouseover 피처 완료
# https://www.pistolclothing.com.au/system/nitro/server/update/webmail.php?userid=tcanella@eqhs.org - on_mouseover 피처 완료
# https://www.namecheap.com/domains/registration.aspx - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='sma.naturealtree.com', port=80): Max retries exceeded with url: /mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42d0f0>: Failed to resolve 'sma.naturealtree.com' ([Errno -2] Name or service not known)"))
# http://sma.naturealtree.com/mot?jk=Z4NwlHBmcGKEmLqxy5qmnnx0YpGGjIx0fGBkaXy0j2lj/linda.todd7@nhs.net - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='202.77.121.186', port=80): Max retries exceeded with url: /kliping/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ec73c42d540>: Failed to establish a new connection: [Errno 113] No route to host'))
# http://202.77.121.186/kliping/ - on_mouseover 피처 완료
# https://technofizi.net/top-best-mp3-downloader-app-for-android-free-music-download/ - on_mouseover 피처 완료
# https://www.slideshare.net/ashamsvk/project-report-on-digital-media-marketing - on_mouseover 피처 완료
# http://www.enkiquotes.com/ - on_mouseover 피처 완료
# http://www.piano-play-it.com/layout-piano-keys.html - on_mouseover 피처 완료
# http://dasisko.sk - on_mouseover 피처 완료
# http://www.inquirelive.co.uk/ - on_mouseover 피처 완료
# http://whatsappchat.zyns.com/ - on_mouseover 피처 완료
# https://www.slant.co/topics/2404/~file-managers-for-windows - on_mouseover 피처 완료
# https://www.lebara.com.au/ - on_mouseover 피처 완료
# https://blog.roku.com/blog/2016/08/18/discovery-tlc-animal-planet-science-discovery-investigation-now-streaming-on-the-roku-platform/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.showplaceicon.com', port=443): Max retries exceeded with url: /Browsing/Cinemas/Details/8863 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ec73c42c040>: Failed to establish a new connection: [Errno 111] Connection refused'))
# https://www.showplaceicon.com/Browsing/Cinemas/Details/8863 - on_mouseover 피처 완료
# https://hublaalikes.com/login - on_mouseover 피처 완료
# https://www.sitepoint.com/the-blackletter-typeface-a-long-and-colored-history/ - on_mouseover 피처 완료
# http://www.instohelp.com/assets_flight/libs/bootstrap/cmcst-wl.html - on_mouseover 피처 완료
# https://www.chiefarchitect.com/ - on_mouseover 피처 완료
# http://securityxploded.com/router-password-kracker.php - on_mouseover 피처 완료
# http://showmore.a3579.com/2EFDC56ECF33816478A33B64D7A5B0D7/ - on_mouseover 피처 완료
# https://www.jobchannel.ch/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='maanprofessionals.nl', port=80): Max retries exceeded with url: /index.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42ec80>: Failed to resolve 'maanprofessionals.nl' ([Errno -5] No address associated with hostname)"))
# http://maanprofessionals.nl//index.html - on_mouseover 피처 완료
# http://internetserviceprovidersnyc.weebly.com/ - on_mouseover 피처 완료
# https://www.handshq.com/ - on_mouseover 피처 완료
# http://www.goodgame.hr/ - on_mouseover 피처 완료
# https://www.zeitschriften-abo.de/DE/NVG/ - on_mouseover 피처 완료
# http://www.ktplasmachinery.com/cs/ - on_mouseover 피처 완료
# https://www.recyclingcenters.org/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='mocabonitabresil.com', port=80): Max retries exceeded with url: /modules/We-Transfer/2020 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42fe20>: Failed to resolve 'mocabonitabresil.com' ([Errno -2] Name or service not known)"))
# http://mocabonitabresil.com/modules/We-Transfer/2020 - on_mouseover 피처 완료
# http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ - on_mouseover 피처 완료
# https://www.tulsapolice.org/police-report/collision-report.aspx - on_mouseover 피처 완료
# http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html - on_mouseover 피처 완료
# http://elexusbettgiris4.blogspot.com - on_mouseover 피처 완료
# https://coderwall.com/p/kvzbpa/don-t-use-array-foreach-use-for-instead - on_mouseover 피처 완료
# http://vamoaestudiarmedicina.blogspot.com/ - on_mouseover 피처 완료
# http://artemisbetguncel.blogspot.com - on_mouseover 피처 완료
# https://www.facebook.com/savers - on_mouseover 피처 완료
# http://www.songlyrics.com/lord-mantis/death-mask-lyrics/ - on_mouseover 피처 완료
# http://shadetreetechnology.com/V4/validation/ef60e2fdf10306f54afdd72d8d3ea6af - on_mouseover 피처 완료
# http://sjec.edu.in - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.nicaraguafood.org', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42ec80>: Failed to resolve 'www.nicaraguafood.org' ([Errno -2] Name or service not known)"))
# http://www.nicaraguafood.org/ - on_mouseover 피처 완료
# http://www.kuchyne-volf.com/obrazky/dinds/alibaba/index/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=80): Max retries exceeded with url: /ap/aa4d130de38808b (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42c550>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# http://support-appleld.com.secureupdate.duilawyeryork.com/ap/aa4d130de38808b - on_mouseover 피처 완료
# https://zipansion.com/3lqqn - on_mouseover 피처 완료
# http://www.speedcamupdates.com/ - on_mouseover 피처 완료
# http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002 - on_mouseover 피처 완료
# https://norecipes.com/japanese-curry-scratch - on_mouseover 피처 완료
# http://realestateinvestordatabase.com/wp-content/plugins/portfolio-cpt/tax/login.php - on_mouseover 피처 완료
# https://blog.hubspot.com/marketing/email-open-click-rate-benchmark - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='madeua.info', port=80): Max retries exceeded with url: /media/jsslider/drive/index.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42f490>: Failed to resolve 'madeua.info' ([Errno -2] Name or service not known)"))
# http://madeua.info/media/jsslider/drive/index.php - on_mouseover 피처 완료
# https://robotic-tide-275809.el.r.appspot.com/file-852/index.html?authwall=trk=ripf - on_mouseover 피처 완료
# https://www.101domain.com/ - on_mouseover 피처 완료
# https://www.hipertrofia.org/blog/ - on_mouseover 피처 완료
# https://www.intouchcrm.co.uk/app/settings/signupforms/v/Hosted.aspx?s=F01B6C73-FF67-42B2-A0FC-CB6D6A8F026A - on_mouseover 피처 완료
# https://www.handlestore.com/ - on_mouseover 피처 완료
# https://ru.wikipedia.org/wiki/MultiMedia_Card - on_mouseover 피처 완료
# https://jamthomp.weebly.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='itxuye.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7ec73c42fe80>, 'Connection to itxuye.com timed out. (connect timeout=10)'))
# https://itxuye.com/ - on_mouseover 피처 완료
# https://polarklimatsgserver.blogspot.com/ - on_mouseover 피처 완료
# http://www.srnonline.com/show-clocks - on_mouseover 피처 완료
# http://www.vpi.us/cat5-5e-6-standards.html - on_mouseover 피처 완료
# http://www.linfo.org/osi_model.html - on_mouseover 피처 완료
# https://lokandkingsupportiveme.blogspot.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='doc.google.share.pressurecookerindia.com', port=80): Max retries exceeded with url: /clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42c040>: Failed to resolve 'doc.google.share.pressurecookerindia.com' ([Errno -2] Name or service not known)"))
# http://doc.google.share.pressurecookerindia.com/clients/?7777772e646f632e676f6f676c652e73686172652e7072657373757265636f6f6b6572696e6469612e636f6d.php= - on_mouseover 피처 완료
# https://forums.digitalpoint.com/threads/how-to-convert-txt-files-to-csv.1446799/ - on_mouseover 피처 완료
# https://www.lovetheedit.com/postnewo/www.dropbox.com/1223/e7728ac72ee30a7cca85feca45595c67 - on_mouseover 피처 완료
# http://paypal-support-help-inc.blogspot.com/?REDACTED - on_mouseover 피처 완료
# http://www.aegisit.net/dhl/DHL%20REVENGE%20BY%20ALIBOBO/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42f4f0>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/ - on_mouseover 피처 완료
# http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php - on_mouseover 피처 완료
# http://www.flaticon.com/free-icons/parking_403 - on_mouseover 피처 완료
# http://www.condos-at-the-beach.com/home/cad.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='illitrading.ro', port=80): Max retries exceeded with url: /doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42f040>: Failed to resolve 'illitrading.ro' ([Errno -2] Name or service not known)"))
# http://illitrading.ro/doc/Doctgn/dc475aa73f27292d9e8c96db191c0d61/index2.php - on_mouseover 피처 완료
# http://hepsibahisgirisimiz4.blogspot.com - on_mouseover 피처 완료
# https://www.blindkids.org/ - on_mouseover 피처 완료
# https://en.wikipedia.org/wiki/Medium_shot - on_mouseover 피처 완료
# https://russeprofilering.no/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='justlookapp.com', port=80): Max retries exceeded with url: /blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42e7d0>: Failed to resolve 'justlookapp.com' ([Errno -2] Name or service not known)"))
# http://justlookapp.com/blog/wp-content/themes/storefront/assets/fonts/dda3de00eaa48d7d3027af0333a04afa - on_mouseover 피처 완료
# http://www.12yards.ru/wp-content/plugins/ups/ups/ups/UPS.htm - on_mouseover 피처 완료
# http://wave.progressfilm.co.uk/time3/?logon=myposte - on_mouseover 피처 완료
# http://www.graphic-design-employment.com/tabloid-paper-dimensions.html - on_mouseover 피처 완료
# ...
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiC2P6hqevYAhWBqaQKHbbxA4cQFggqMAA&url=http%3A%2F%2Fwww.skatteetaten.no%2Fen%2Fperson%2F&usg=AOvVaw27Bb-ElBmjNVWBcdUaMcxg - on_mouseover 피처 완료
# https://www.computerhope.com/jargon/m/memocard.htm - on_mouseover 피처 완료
# http://www.bobsplans.com/FreeDownloads/RouterTable.pdf - on_mouseover 피처 완료
# http://espace-client.net/canalsat-resiliation - on_mouseover 피처 완료
# https://www.merriam-webster.com/dictionary/tabloid - on_mouseover 피처 완료
# http://www.dictionary.com/browse/select-committee - on_mouseover 피처 완료
# http://afriquelemou.free.fr/templates/rhuk_milkyway/sdnconconsadf.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c42c850>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ - on_mouseover 피처 완료
# https://kywait.blogspot.com/ - on_mouseover 피처 완료
# http://sniz.porn - on_mouseover 피처 완료
# https://www.bls.gov/oes/current/oes292035.htm - on_mouseover 피처 완료
# http://02dfbe20-6956-4be6-ba22-36ae0e0d3053.htmlcomponentservice.com/get_draft?id=99ea0e_8eddaa8b0b3b6316a653bbd03eb5b48f.html - on_mouseover 피처 완료
# http://dichvuvnpt.com/home/components/com_user/bbtonline.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='78.143.96.35', port=80): Max retries exceeded with url: /wordpress/gam/index.php?bidderblocklogin= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c42e5c0>, 'Connection to 78.143.96.35 timed out. (connect timeout=10)'))
# http://78.143.96.35/wordpress/gam/index.php?bidderblocklogin= - on_mouseover 피처 완료
# https://www.russianlovematch.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='m.hf695.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42d1b0>: Failed to resolve 'm.hf695.com' ([Errno -2] Name or service not known)"))
# http://m.hf695.com/ - on_mouseover 피처 완료
# http://www.casinocitytimes.com/ - on_mouseover 피처 완료
# https://app66560000.blogspot.com/ - on_mouseover 피처 완료
# http://useful_english.enacademic.com/76401/latency_stage - on_mouseover 피처 완료
# http://toppave.com.sg - on_mouseover 피처 완료
# https://bologna.babyloweb.eu/info/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# http://twowheelcool.com/twitter.com/index759b.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='rastreomoderno.com', port=443): Max retries exceeded with url: /wp-content/plugins/akismet/br/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
# http://rastreomoderno.com/wp-content/plugins/akismet/br/ - on_mouseover 피처 완료
# http://science.howstuffworks.com/warp-speed2.htm - on_mouseover 피처 완료
# http://topprioritys.appspot.com/u?purl=b2Qubmlnb2wvU1UvbW9jLml0aWMuZW5pbG5vLy86c3B0dGg= - on_mouseover 피처 완료
# https://www.eliteprospects.com/ - on_mouseover 피처 완료
# http://utefilm.no/signin/lik/emailprovider/signin/ - on_mouseover 피처 완료
# https://raphaelhammoud.wordpress.com/ - on_mouseover 피처 완료
# http://fitnessista.com/the-perfect-protein-pancake/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='gov.taxclaim08.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42ef20>: Failed to resolve 'gov.taxclaim08.com' ([Errno -2] Name or service not known)"))
# http://gov.taxclaim08.com/ - on_mouseover 피처 완료
# https://www.sammonsfinancialgroup.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.networksorcery.com', port=80): Max retries exceeded with url: /enp/rfc/rfc2812.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c42fa30>, 'Connection to www.networksorcery.com timed out. (connect timeout=10)'))
# http://www.networksorcery.com/enp/rfc/rfc2812.txt - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='masterclimaespecialistas.com.br', port=443): Max retries exceeded with url: /wp-includes/off2/pod.php?warp=020202 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c42c0a0>: Failed to resolve 'masterclimaespecialistas.com.br' ([Errno -2] Name or service not known)"))
# https://masterclimaespecialistas.com.br/wp-includes/off2/pod.php?warp=020202 - on_mouseover 피처 완료
# http://bangla.plus - on_mouseover 피처 완료
# https://www.agri85.fr/V3/admin/red.php - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='179.185.89.94', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c42d030>, 'Connection to 179.185.89.94 timed out. (connect timeout=10)'))
# http://179.185.89.94/ - on_mouseover 피처 완료
# http://www.atmi.gr/ - on_mouseover 피처 완료
# http://botforbyks.blogspot.ru/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='andreacostafisio.com.br', port=443): Max retries exceeded with url: /wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c42f790>: Failed to resolve 'andreacostafisio.com.br' ([Errno -5] No address associated with hostname)"))
# https://andreacostafisio.com.br/wp-content/plugins/adob/login.php?cmd=login_submit&amp;id=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204&amp;session=9c127b2a76a05cb1ee8818971b2032049c127b2a76a05cb1ee8818971b203204 - on_mouseover 피처 완료
# https://en.wikibooks.org/wiki/Operating_System_Design/File_Systems/Allocation - on_mouseover 피처 완료
# http://www.abbreviations.com/term/16642 - on_mouseover 피처 완료
# https://www.walmart.com/c/ep/cat6-ethernet-cables - on_mouseover 피처 완료
# https://nozed-uname.firebaseapp.com/ - on_mouseover 피처 완료
# https://www.colgate.com/en-us/products/enamel-health - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.m9e4.com', port=80): Max retries exceeded with url: /labanquepostale.fr/service-mobile-pass/ac451/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c42d8d0>: Failed to resolve 'www.m9e4.com' ([Errno -2] Name or service not known)"))
# http://www.m9e4.com/labanquepostale.fr/service-mobile-pass/ac451/ - on_mouseover 피처 완료
# https://www.smart-wiki.net/ - on_mouseover 피처 완료
# https://www.cloudaccess.net/cloud-control-panel-ccp/157-dns-management/319-resolving-dns-http-redirect-issues.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c42c130>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# https://support-appleld.com.secureupdate.duilawyeryork.com/ap/c05f378d59c6ba8?cmd=_update&dispatch=c05f378d59c6ba805&locale=_US - on_mouseover 피처 완료
# https://en.wikipedia.org/wiki/Walnut_Creek_CDROM - on_mouseover 피처 완료
# http://energo-investment.hu - on_mouseover 피처 완료
# http://vaportotal.net/catalog/language/english/product/special/index.php?cid=474fe1ba8fa8cfd26e81532c7baac4a1&amp;SSID=d2b816c9e8292c96546684e342c2e77cd27f39cf - on_mouseover 피처 완료
# https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo - on_mouseover 피처 완료
# http://www.thefreedictionary.com/select+committee - on_mouseover 피처 완료
# http://barbo.sk - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.3.ly', port=443): Read timed out. (read timeout=10)
# http://3.ly/uja - on_mouseover 피처 완료
# http://support.brother.com/g/s/id/pdf_pub/faq/faq002478/en/Scan_To_FTP.pdf - on_mouseover 피처 완료
# http://yummy-cummy-in-my-tummy.tumblr.com - on_mouseover 피처 완료
# http://faceboook.bitballoon.com/ - on_mouseover 피처 완료
# http://searchnetworking.techtarget.com/tip/Comparisons-of-coaxial-cable-fiber-optic-cable-and-twisted-pair-cable - on_mouseover 피처 완료
# http://www.habitas.org.uk/nimars/mmusculush.htm - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.neudorf-ole.irv.cc', port=80): Max retries exceeded with url: /4B374AA12276932A9FA724E6142E9BD1 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c8554e0>: Failed to resolve 'www.neudorf-ole.irv.cc' ([Errno -2] Name or service not known)"))
# http://www.neudorf-ole.irv.cc/4B374AA12276932A9FA724E6142E9BD1 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c855e10>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# http://www.nakamistrad.com/aa/test.php - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='fredwilliams.publishpath.com', port=80): Max retries exceeded with url: /system-adminstrator (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c857070>, 'Connection to fredwilliams.publishpath.com timed out. (connect timeout=10)'))
# http://fredwilliams.publishpath.com/system-adminstrator - on_mouseover 피처 완료
# https://monovative-my.sharepoint.com:443/:o:/g/personal/user_monovative_onmicrosoft_com/EmCzKJnKZgxDtejtstZ67qQBlkNaRN4Da620KjAjE91eWQ?e=5:wesEg8&amp;at=9 - on_mouseover 피처 완료
# http://app66560000.blogspot.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='pay-pal-deutschland.zxc301.com', port=80): Max retries exceeded with url: /029188 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3fd00>: Failed to resolve 'pay-pal-deutschland.zxc301.com' ([Errno -2] Name or service not known)"))
# http://pay-pal-deutschland.zxc301.com/029188 - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='maria.sgpermata.com', port=80): Max retries exceeded with url: /Main.htm (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3d750>: Failed to resolve 'maria.sgpermata.com' ([Errno -2] Name or service not known)"))
# http://maria.sgpermata.com/Main.htm - on_mouseover 피처 완료
# https://simple.wikipedia.org/wiki/Gettysburg_Address - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='www.cnc-club.ru', port=443): Max retries exceeded with url: /forum/index.php (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cnc-club.ru'. (_ssl.c:1007)")))
# http://www.cnc-club.ru/forum/index.php - on_mouseover 피처 완료
# http://www.geocities.ws/steamcom/ - on_mouseover 피처 완료
# https://en.wikipedia.org/wiki/Ionosphere - on_mouseover 피처 완료
# http://www.mousebreaker.com/games/clicker - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='165.22.103.235', port=80): Max retries exceeded with url: /importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c8549d0>, 'Connection to 165.22.103.235 timed out. (connect timeout=10)'))
# http://165.22.103.235/importantnoticeclient=0952/directing/www.cibc.mobi/ebm-mobile-anp/ - on_mouseover 피처 완료
# https://eternityflooringcom-my.sharepoint.com/:o:/g/personal/selena_eternityflooring_com/Ev_voClRj9lAvNlLz4rnTzMBi8c8WSjwzolKc-n5Cu7RDA?e=BkedRb - on_mouseover 피처 완료
# http://mercolinvestment.com/wp-admin/webmail.hinet - on_mouseover 피처 완료
# http://u10084924.ct.sendgrid.net/ls/click?upn=SUr4b5585qbQyA5LBh0cprcX9yGxzuKRiPmK1eOyGjnFAjPT3peF3hZBU5GBT5LB-2F-2B8RQoVKizdN6jZII2WoXKREC-2F59ArXVRryxHjm0Vl4-3D2Nk5_adLR-2Bo5mfbjm7FG5I6PoQ1GVR6lgb9L5-2FnJ-2FDbcFMgYPbFVI6bxW0n-2BJlNZ-2FkSxprRH5HVbfGLu4f-2FOYZZcGyRV5V7XlMPiv3bPHgGjTFcQq69gZ82b-2Bu3aKRz2G4rbkTGBsATWHN-2B3T7ix5-2BOYOxqRVLPPnOm6Tvj7Y40BwgAW-2BV0wy5oLTvYyX0T6hcQz4S7FvFwReqce-2FiyfG4WApIQ-3D-3D - on_mouseover 피처 완료
# http://ht.ly/wPX430q3I2o - on_mouseover 피처 완료
# https://documentos.sfo2.digitaloceanspaces.com/ordem.html - on_mouseover 피처 완료
# https://en.wikipedia.org/wiki/Gateway - on_mouseover 피처 완료
# http://www.minus40.info/ice/dracula-old.html - on_mouseover 피처 완료
# https://www.missfiga.com/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73c854a30>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html - on_mouseover 피처 완료
# http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/ - on_mouseover 피처 완료
# http://www.kreport.com/tmp/ - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='www.ghbook.ir', port=80): Max retries exceeded with url: /index.php?lang=fa (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ec73c855090>, 'Connection to www.ghbook.ir timed out. (connect timeout=10)'))
# http://www.ghbook.ir/index.php?lang=fa - on_mouseover 피처 완료
# http://www.skm-eleksys.com/2011/02/transmission-tower-types.html - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPSConnectionPool(host='mauy.org', port=443): Max retries exceeded with url: /PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7ec73c8543a0>: Failed to resolve 'mauy.org' ([Errno -2] Name or service not known)"))
# https://mauy.org/PH/docusign/DocuSign/u.php?l=DHl-dTracking_=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHtoGYDw=_JeHFUq_VJOXK0QWHto= - on_mouseover 피처 완료
# https://www.lifewire.com/tcp-port-21-818146 - on_mouseover 피처 완료
# http://www.personalniyhoroskop.com/ - on_mouseover 피처 완료
# https://www.wordnik.com/words/blackletter - on_mouseover 피처 완료
# https://www.conceptcarz.com/ - on_mouseover 피처 완료
# https://sites.google.com/site/ilyasdxih - on_mouseover 피처 완료
# https://www.winxdvd.com/windows-10/movie-maker-download.htm - on_mouseover 피처 완료
# on_mouseover 요청 Error: HTTPConnectionPool(host='signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7ec73bd3e590>: Failed to resolve 'signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com' ([Errno -2] Name or service not known)"))
# http://signin.eday.co.uk.ws.edayisapi.dllsign.inusingsslpuseridcopartnerid2siteid.zdfxx949xyss1pnbh0soabfdzgdh2kppnu.reippl.com/ - on_mouseover 피처 완료
# http://www.calculate.co.il/ - on_mouseover 피처 완료
# http://www.codeboiler.net/ - on_mouseover 피처 완료
# http://www.orafaq.com/wiki/Roles_and_Responsibilities - on_mouseover 피처 완료
# https://www.hfunderground.com/wiki/Ionosphere - on_mouseover 피처 완료
# 피처 'on_mouseover' 추가 완료:
#    on_mouseover
# 0            -1
# 1            -1
# 2            -1
# 3             1
# 4             1

# %%
# 데이터프레임의 컬럼 순서를 재배치
# 'status'를 가장 마지막으로 이동
columns = [col for col in df.columns if col != 'status'] + ['status']
df_reordered = df[columns]

# 결과를 CSV 파일로 저장
df_reordered.to_csv('dataset_content_based_features.csv', index=False)
