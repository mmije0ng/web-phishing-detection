# %% [markdown]
# # 테스트 데이터셋으로 피처 판별 결과와 xgboost, mlp 모델의 피싱 판별 확률 및 판별 시간을 데이터셋으로 생성

# %%
# !pip install python-whois
# Out:
# Requirement already satisfied: python-whois in /usr/local/lib/python3.10/dist-packages (0.9.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from python-whois) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->python-whois) (1.16.0)

# %%
import asyncio
import pandas as pd
from features import short_url_features, url_based_feature, content_based_features, domainver1
import pickle
import numpy as np
import time

# 피처 이름 목록을 모델 학습 데이터의 피처 순서와 일치시킴
feature_order = [
    'having_IPhaving_IP_Address', 'URLURL_Length', 'having_At_Symbol', 'double_slash_redirecting',
    'Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length',
    'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor', 'Links_in_tags', 'SFH', 'Submitting_to_email',
    'Abnormal_URL', 'Redirect', 'popUpWidnow', 'age_of_domain', 'DNSRecord',
    'Google_Index'
]

# feature_order = [
#     'having_IPhaving_IP_Address', 'URLURL_Length', 'having_At_Symbol', 'double_slash_redirecting',
#     'Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length', 'Favicon',
#     'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor', 'Links_in_tags', 'SFH', 'Submitting_to_email',
#     'Abnormal_URL', 'Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe', 'age_of_domain', 'DNSRecord',
#     'Google_Index'
# ]

async def evaluate_url(url):
    # URL이 단축된 경우 복원
    url, is_shortened = await asyncio.to_thread(short_url_features.check_url, url)
    print(f'단축 URL 여부: {is_shortened}')

    # 컨텐츠 기반 피처용 URLData 객체 생성
    response = await asyncio.to_thread(content_based_features.get_request_url, url)

    # 비동기 함수로 개별 피처들을 동시에 실행
    tasks = {
        'URLURL_Length': asyncio.to_thread(url_based_feature.check_url_length, url),
        'port': asyncio.to_thread(url_based_feature.scan_non_standard_ports, url),
        'having_At_Symbol': asyncio.to_thread(url_based_feature.check_at_symbol, url),
        'double_slash_redirecting': asyncio.to_thread(url_based_feature.check_double_slash_redirecting, url),
        'Prefix_Suffix': asyncio.to_thread(url_based_feature.check_prefix_suffix, url),
        'Abnormal_URL': asyncio.to_thread(url_based_feature.check_abnormal_url, url),
        'popUpWidnow': asyncio.to_thread(content_based_features.popup_window_text, response),
        'having_IPhaving_IP_Address': asyncio.to_thread(content_based_features.using_ip, url),
        'Request_URL': asyncio.to_thread(content_based_features.check_request_url, url, response),
        'URL_of_Anchor': asyncio.to_thread(content_based_features.check_url_of_anchor, url, response),
        'Links_in_tags': asyncio.to_thread(content_based_features.has_meta_tags, response),
        'SFH': asyncio.to_thread(content_based_features.check_sfh, url, response),
        'Submitting_to_email': asyncio.to_thread(content_based_features.check_submit_email, url, response),
        'Redirect': asyncio.to_thread(content_based_features.check_redirect_count, response),
        'Google_Index': asyncio.to_thread(domainver1.google_index, url),
        'Domain_registeration_length': asyncio.to_thread(domainver1.domain_registration_period, url),
        'age_of_domain': asyncio.to_thread(domainver1.domain_age, url),
        'DNSRecord': asyncio.to_thread(domainver1.dns_record, url),
        'SSLfinal_State': asyncio.to_thread(domainver1.ssl_certificate_status, url),
        'having_Sub_Domain': asyncio.to_thread(domainver1.having_subdomain, url),
        'HTTPS_token': asyncio.to_thread(domainver1.https_token, url),

        # 'RightClick': asyncio.to_thread(content_based_features.use_right_click, response),
        # 'Iframe': asyncio.to_thread(content_based_features.iFrame_redirection, response),
        # 'Favicon': asyncio.to_thread(content_based_features.check_favicon, url, response),
        # 'on_mouseover': asyncio.to_thread(content_based_features.check_onmouseover_change, response),
    }

    # 모든 비동기 작업을 병렬로 실행
    feature_results = await asyncio.gather(*tasks.values())
    features = dict(zip(tasks.keys(), feature_results))

    # 피처 값을 올바른 순서로 정렬하여 단순 배열로 변환
    feature_values = [features[feature] for feature in feature_order]
    features_array = np.array(feature_values).reshape(1, -1)  # 2D 배열로 변환

    # 학습된 모델 로드 및 예측 수행
    # 다층퍼셉트론 모델 로드
    with open('model/mlp_model_column_drop.pkl', 'rb') as f:
        mlp_model = pickle.load(f)

    # XGBoost 모델 로드
    with open('model/xgboost_model_column_drop.pkl', 'rb') as f:
        xgboost_model = pickle.load(f)

    # MLP 모델 예측
    mlp_prediction = mlp_model.predict(features_array)[0]
    mlp_probability = mlp_model.predict_proba(features_array)[0]
    mlp_phishing_prob = round(mlp_probability[1] * 100, 4)  # 피싱일 확률을 퍼센트로 변환하고 소수점 네 자리로 반올림

    # XGBoost 모델 예측
    xgboost_prediction = xgboost_model.predict(features_array)[0]
    xgboost_probability = xgboost_model.predict_proba(features_array)[0]
    xgboost_phishing_prob = round(xgboost_probability[1] * 100, 4)  # 피싱일 확률을 퍼센트로 변환하고 소수점 네 자리로 반올림

    # 피싱 여부 및 상세 설명
    phishing_mlp = mlp_prediction == 1
    phishing_xgboost = xgboost_prediction == 1
    explanation = []

    for feature_name, feature_value in features.items():
        if feature_name != 'Google_Index' and (feature_value == 1 or feature_value == 0):
            explanation.append(f"{feature_name}: {feature_value}")

    return {
        "url": url,
        "mlp": {
            "phishing": phishing_mlp,
            "probability": mlp_phishing_prob
        },
        "XGBoost": {
            "phishing": phishing_xgboost,
            "probability": xgboost_phishing_prob
        },
        "features": features
    }

# %%
# 메인 함수에서 비동기 함수 실행
async def main():
    df = pd.read_csv('test_dataset.csv')  # 데이터셋의 경로를 지정
    test_urls = df['url'].tolist()
    statuses = df['status'].tolist()  # status 컬럼 값 추출

    # 분석 결과를 저장할 데이터 프레임 초기화
    columns = feature_order + ['MLP_Phishing', 'MLP_Probability', 'XGBoost_Phishing', 'XGBoost_Probability', 'status']
    results_df = pd.DataFrame(columns=columns)

    # 각 URL에 대해 평가 수행
    for url, status in zip(test_urls, statuses):
        start_time = time.time()
        result = await evaluate_url(url)
        end_time = time.time()

        # 평가 결과를 데이터 프레임에 추가
        row = {**result["features"]}
        row['url'] = url  # url 추가
        row['status'] = status  # status 값 추가
        row['time'] = end_time - start_time  # 분석 시간 추가
        row['MLP_Phishing'] = result["mlp"]["phishing"]
        row['MLP_Probability'] = result["mlp"]["probability"]
        row['XGBoost_Phishing'] = result["XGBoost"]["phishing"]
        row['XGBoost_Probability'] = result["XGBoost"]["probability"]


        row_df = pd.DataFrame([row])
        results_df = pd.concat([results_df, row_df], ignore_index=True)

        print(f"URL: {url}")
        print(f"분석 시간: {end_time - start_time:.2f} seconds")
        print("=" * 50)

    # 결과를 CSV 파일로 저장
    results_df.to_csv('url_analysis_results_not_content.csv', index=False)

# %%
await main()
# Out:
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPSConnectionPool(host='support-appleld.com.secureupdate.duilawyeryork.com', port=443): Max retries exceeded with url: /ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a2a36642ec0>: Failed to resolve 'support-appleld.com.secureupdate.duilawyeryork.com' ([Errno -2] Name or service not known)"))
# <ipython-input-20-6fdbd1ca1a57>:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, row_df], ignore_index=True)
# URL: https://support-appleld.com.secureupdate.duilawyeryork.com/ap/89e6a3b4b063b8d/?cmd=_update&dispatch=89e6a3b4b063b8d1b&locale=_
# 분석 시간: 0.57 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htmLinks_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htmSFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
#
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
#
# URL: http://phan.thuchao.free.fr/Hao/YouTube/ba.htm
# 분석 시간: 1.39 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is NoneSubmitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
#
# SSL Certificate Status Error: HTTPConnectionPool(host='taccs.hu', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7a2a36970f70>: Failed to establish a new connection: [Errno 111] Connection refused'))
# URL: http://taccs.hu
# 분석 시간: 1.93 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://en.wikipedia.org/wiki/NIC_Bank
# 분석 시간: 1.38 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.markspcsolution.com/
# 분석 시간: 2.17 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is NoneRequest_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
#
# SSL Certificate Status Error: HTTPConnectionPool(host='swallowthisbitchpics.com', port=80): Max retries exceeded with url: /jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a1eaf5de0>: Failed to resolve 'swallowthisbitchpics.com' ([Errno -2] Name or service not known)"))
# Domain Age Error: No match for "SWALLOWTHISBITCHPICS.COM".
# >>> Last update of whois database: 2024-08-26T12:14:13Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# DNS Record Error: No match for "SWALLOWTHISBITCHPICS.COM".
# >>> Last update of whois database: 2024-08-26T12:14:13Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Registration Period Error: No match for "SWALLOWTHISBITCHPICS.COM".
# >>> Last update of whois database: 2024-08-26T12:14:13Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# URL: http://swallowthisbitchpics.com/jpg/www.global.visa.com/myca/oce/emea/action/request_type=un_Activation/visa.html
# 분석 시간: 0.43 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.soul-flower.com/
# 분석 시간: 6.58 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://www.whio.com/news/local/thief-breaks-into-save-lot-steals-steaks-dayton/dX1YgaOZ7zmj18bPd4tU6L/
# 분석 시간: 3.90 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboardRequest_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
# Redirect 요청 Error: 403 Client Error: Forbidden for url: http://sophie-world.com/games/port-and-starboard
#
# URL: http://sophie-world.com/games/port-and-starboard
# 분석 시간: 2.12 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://en.wikipedia.org/wiki/Gateway
# 분석 시간: 1.15 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='www.courgeon-immobilier.fr', port=80): Max retries exceeded with url: /wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7a2a367149d0>, 'Connection to www.courgeon-immobilier.fr timed out. (connect timeout=5)'))
# URL: http://www.courgeon-immobilier.fr/wp-content/uploads/2019/07/tpg/9ac6ba30463d0fb7974c06843717284c/
# 분석 시간: 10.64 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.lifewire.com/tcp-port-21-818146
# 분석 시간: 1.59 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# Redirect 요청 Error: 404 Client Error: Not Found for url: https://www.online-tech-tips.com/how-to-change-mac-address/
# URL: http://www.online-tech-tips.com/computer-tips/how-to-change-mac-address/
# 분석 시간: 1.14 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
#
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://xh167894743.el.r.appspot.com/
# Domain Age Error: No match for "R.APPSPOT.COM".
# >>> Last update of whois database: 2024-08-26T12:14:42Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# DNS Record Error: No match for "R.APPSPOT.COM".
# >>> Last update of whois database: 2024-08-26T12:14:42Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Registration Period Error: No match for "R.APPSPOT.COM".
# >>> Last update of whois database: 2024-08-26T12:14:42Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# URL: http://xh167894743.el.r.appspot.com/
# 분석 시간: 3.33 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://stattrek.com/statistics/dictionary.aspx?definition=standard%20error
# 분석 시간: 1.54 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='www.motoincontroepoca.com', port=80): Max retries exceeded with url: /blog/profile/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a36f07bb0>: Failed to resolve 'www.motoincontroepoca.com' ([Errno -2] Name or service not known)"))
# URL: http://www.motoincontroepoca.com/blog/profile/
# 분석 시간: 4.61 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.merriam-webster.com/dictionary/tabloid
# 분석 시간: 7.68 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://vufd.hyperphp.com/amzn
# 분석 시간: 10.36 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://press-preview.weebly.com
# 분석 시간: 1.25 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# Redirect 요청 Error: 404 Client Error: Not Found for url: https://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# URL: http://www.bobsplans.com/FreeDownloads/RouterTable.pdf
# 분석 시간: 0.65 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# Redirect 요청 Error: 403 Client Error: Forbidden for url: https://www.hugedomains.com/domain_profile.cfm?d=storybookalpacas.com
# URL: http://www.storybookalpacas.com/account4/index2.html
# 분석 시간: 1.22 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# URL: http://www.shadetreetechnology.com/V4/validation/ba4b8bddd7958ecb8772c836c2969531
# 분석 시간: 1.17 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://grassform-my.sharepoint.com/:b:/g/personal/accounts_grassform_co_uk/EYsmX_DhwSVAlooW1ETKf50BIChCl1rrAfmqvTLvySTLQQ?e=UbjoWA
# 분석 시간: 2.23 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# Redirect 요청 Error: 403 Client Error: Forbidden for url: http://www.flaticon.com/free-icons/parking_403
# URL: http://www.flaticon.com/free-icons/parking_403
# 분석 시간: 1.12 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/Redirect 요청 Error: 404 Client Error: Not Found for url: https://www.iracing.com:443/tracks/gateway-motorsports-park/
#
# URL: http://www.iracing.com/tracks/gateway-motorsports-park/
# 분석 시간: 1.57 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://www.mutuo.it
# 분석 시간: 1.98 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.provenancevineyards.com/
# 분석 시간: 1.27 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# URL: http://www.shadetreetechnology.com/V4/validation/44ccd8b487c7fe797dc775e919236002
# 분석 시간: 1.10 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://www.history.com/topics/american-civil-war/gettysburg-address
# 분석 시간: 1.16 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.htmlURL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.htmlSFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
# Redirect 요청 Error: 403 Client Error: Forbidden for url: https://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
#
#
# URL: http://www.ilovefreesoftware.com/16/featured/5-best-free-network-packet-sniffer.html
# 분석 시간: 1.30 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# Request_URL HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSoURL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# Redirect 요청 Error: 403 Client Error: Forbidden for url: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
#
# URL: https://answers.yahoo.com/question/index?qid=20060914152716AAZTOSo
# 분석 시간: 1.20 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='hidayat.uz', port=80): Max retries exceeded with url: /928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a365aa080>: Failed to resolve 'hidayat.uz' ([Errno -2] Name or service not known)"))
# URL: http://hidayat.uz/928375602332311ochttp3A2F2F2Fws2FISAPIdllFM2MContact26item3B14276952031324requestePPd3DwolandgioielliPPP26qidQ-jlc@amahousse.com.html
# 분석 시간: 1.07 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is NoneRequest_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
#
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='beta.kenaidanceta.com', port=80): Max retries exceeded with url: /postamok/d39a2/source (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a1ce204c0>: Failed to resolve 'beta.kenaidanceta.com' ([Errno -2] Name or service not known)"))
# DNS Record Error: No match for "KENAIDANCETA.COM".
# >>> Last update of whois database: 2024-08-26T12:15:30Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Age Error: No match for "KENAIDANCETA.COM".
# >>> Last update of whois database: 2024-08-26T12:15:30Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Registration Period Error: No match for "KENAIDANCETA.COM".
# >>> Last update of whois database: 2024-08-26T12:15:30Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# URL: http://beta.kenaidanceta.com/postamok/d39a2/source
# 분석 시간: 0.43 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# Redirect 요청 Error: 404 Client Error: Not Found for url: https://www.prvwines.com/our-wines
# URL: https://www.provenancevineyards.com/our-wines
# 분석 시간: 1.79 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: https://www.chiefarchitect.com/
# 분석 시간: 1.31 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# Redirect 요청 Error: 404 Client Error: Not Found for url: https://dichvuvnpt.com/home/components/com_user/bbtonline.html
# URL: http://dichvuvnpt.com/home/components/com_user/bbtonline.html
# 분석 시간: 5.81 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://remontka.pro/mac-address/
# 분석 시간: 2.22 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# URL: http://enerclim.com/cs/
# 분석 시간: 1.37 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='www.j-net.cn', port=80): Max retries exceeded with url: /cms (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a1ce02560>: Failed to resolve 'www.j-net.cn' ([Errno -2] Name or service not known)"))
# 2024-08-26 12:15:51,833 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno 104] Connection reset by peer
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno 104] Connection reset by peer
# URL: http://www.j-net.cn/cms
# 분석 시간: 1.28 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/Redirect 요청 Error: 404 Client Error: Not Found for url: https://mailserver67187.uc.r.appspot.com/
#
#
# DNS Record Error: No match for "R.APPSPOT.COM".
# >>> Last update of whois database: 2024-08-26T12:15:46Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Registration Period Error: No match for "R.APPSPOT.COM".
# >>> Last update of whois database: 2024-08-26T12:15:46Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# ...
# URL_of_Anchor HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
#
# Links_in_tags HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# SFH HTTP 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# Submitting_to_email 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# Redirect 요청 Error: 403 Client Error: Forbidden for url: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# URL: https://parade.com/425836/joshwigler/the-amazing-race-host-phil-keoghan-previews-the-season-27-premiere/
# 분석 시간: 10.25 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# 2024-08-26 12:18:31,685 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# 2024-08-26 12:18:31,792 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# 2024-08-26 12:18:31,809 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# 2024-08-26 12:18:31,859 - whois.whois - ERROR - Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# ERROR:whois.whois:Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# URL: http://mne.edu.vn/wp-includes/Netflix/LoginID/index.php
# 분석 시간: 3.91 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is None
# Request_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='marketinghelper.com.au', port=80): Max retries exceeded with url: /themes/sports/wp-content/net/555183669058fb273008595a9393d628/ (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a365055a0>: Failed to resolve 'marketinghelper.com.au' ([Errno -2] Name or service not known)"))
# URL: http://marketinghelper.com.au/themes/sports/wp-content/net/555183669058fb273008595a9393d628/
# 분석 시간: 0.80 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# HTTP 요청 Error: {e}
# popUpWidnow HTTP 요청 Error: Response is NoneRequest_URL HTTP 요청 Error: Response is None
# URL_of_Anchor HTTP 요청 Error: Response is None
# Links_in_tags HTTP 요청 Error: Response is None
#
# SFH HTTP 요청 Error: Response is None
# Submitting_to_email 요청 Error: Response is None
# Redirect 요청 Error: Response is None
# SSL Certificate Status Error: HTTPConnectionPool(host='www.nakamistrad.com', port=80): Max retries exceeded with url: /aa/test.php (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a2a365074c0>: Failed to resolve 'www.nakamistrad.com' ([Errno -2] Name or service not known)"))
# Domain Registration Period Error: No match for "NAKAMISTRAD.COM".
# >>> Last update of whois database: 2024-08-26T12:18:15Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# DNS Record Error: No match for "NAKAMISTRAD.COM".
# >>> Last update of whois database: 2024-08-26T12:18:15Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# Domain Age Error: No match for "NAKAMISTRAD.COM".
# >>> Last update of whois database: 2024-08-26T12:18:15Z <<<
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
#
# URL: http://www.nakamistrad.com/aa/test.php
# 분석 시간: 0.43 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# Request_URL HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# URL_of_Anchor HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# Links_in_tags HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# SFH HTTP 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# Submitting_to_email 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# Redirect 요청 Error: 503 Server Error: Service Unavailable for url: http://www.astroresidential.co.uk/application/data/
# URL: http://www.astroresidential.co.uk/application/data/
# 분석 시간: 2.35 seconds
# ==================================================
# 일반 URL입니다.
# 단축 URL 여부: -1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://batvrms.net/deliver/D2017HL/u.php
# URL: http://batvrms.net/deliver/D2017HL/u.php
# 분석 시간: 3.43 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: http://coiinbaseexxtsion.webflow.io/
# 단축 URL 여부: 1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# Redirect 요청 Error: 404 Client Error: Not Found for url: http://coiinbaseexxtsion.webflow.io/
# URL: https://buly.kr/BITBije
# 분석 시간: 4.57 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://fopalined.top:443/payouts/
# 단축 URL 여부: 1
# URL: https://buly.kr/9BU5wxI
# 분석 시간: 5.01 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://scaling-fiesta1.vercel.app/
# 단축 URL 여부: 1
# URL: https://buly.kr/Gkqg82e
# 분석 시간: 3.92 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://oohop.webflow.io/
# 단축 URL 여부: 1
# popUpWidnow HTTP 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# Request_URL HTTP 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# URL_of_Anchor HTTP 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# Links_in_tags HTTP 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# SFH HTTP 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# Submitting_to_email 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# Redirect 요청 Error: 404 Client Error: Not Found for url: https://oohop.webflow.io/
# URL: https://buly.kr/GZvv9En
# 분석 시간: 3.92 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://allegro-online.ru/c/myagkaya-mebel
# 단축 URL 여부: 1
# Domain Registration Period Error: No entries found for the selected source(s).
#
# >>> Last update of WHOIS database: 2024.08.26T15:18:53Z <<<
#
# Domain Age Error: No entries found for the selected source(s).
#
# >>> Last update of WHOIS database: 2024.08.26T15:18:53Z <<<
#
# DNS Record Error: No entries found for the selected source(s).
#
# >>> Last update of WHOIS database: 2024.08.26T15:18:53Z <<<
#
# URL: https://buly.kr/jXirow
# 분석 시간: 5.94 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://www.naver.com/
# 단축 URL 여부: 1
# URL: https://buly.kr/2qWodcD
# 분석 시간: 4.72 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://www.hansung.ac.kr/sites/hansung/index.do
# 단축 URL 여부: 1
# URL: https://buly.kr/C08De2i
# 분석 시간: 9.39 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://www.youtube.com/
# 단축 URL 여부: 1
# URL: https://buly.kr/610SIJC
# 분석 시간: 68.84 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://tinyurl.com/preview/3z5h4h3w
# 단축 URL 여부: 1
# URL: https://tinyurl.com/3z5h4h3w
# 분석 시간: 1.57 seconds
# ==================================================
# 단축 URL입니다.
# 복원된 URL: https://www.google.co.kr/
# 단축 URL 여부: 1
# URL: https://url.kr/b2ecua
# 분석 시간: 5.37 seconds
# ==================================================
